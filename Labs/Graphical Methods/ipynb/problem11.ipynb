# %%
# C:\Users\wwsch\anaconda3\python.exe
# Name: William Schlough (wschloug)
# Group Members: Junmo, Mikey, Wenyu

# Given a genome Text, PathGraphk(Text) is the path consisting of |Text| - k + 1 edges,
# where the i-th edge of this path is labeled by the i-th k-mer in Text
# and the i-th node of the path is labeled by the i-th (k - 1)-mer in Text.
# The de Bruijn graph DeBruijnK(Text) is formed by gluing identically labeled nodes in PathGraphk(Text).


class deBruijn:
    '''
    contains methods used to construct the deBruijn graph from a string
    '''

    def __init__(self, k, text):
        '''
        initializes necessary vars
        '''

        self.k = k # houses kmer size, we will use (k-1)-mer
        self.text = text # houses input seq
        self.dbDict = {} # houses deBruijn dictionary

    def nodes(self):
        '''
        find (k-1)-mer, and for each (k-1)-mer next (k-1)-mer will be shifted once to the right
        all of these connecting (k-1)-mers are added to the deBruinDictionary (dbDict)

        "the i-th node of the path is labeled by the i-th (k - 1)-mer in Text"

        https://stackoverflow.com/questions/3199171/append-multiple-values-for-one-key-in-a-dictionary
        '''

        for i in range(len(self.text) - self.k + 1): # path consisting of |Text| - k + 1 edges
            node = self.text[i: i + self.k - 1] # node from seq cut from i to i plus length of (k-1)mer
            nodeNext = self.text[i + 1: i + self.k] # node from seq cut from i+1 (shift right once) to i plus length of (k-1)-mer --> when i was doing i + self.k -1 my output was only 2/3 characters . . .? --> im dumb its cuz i have to shift right once XD

            if node not in self.dbDict.keys(): # if node isn't yet seen in deBruijnDictionary
                self.dbDict[node] = [] # make it a key with value empty list

            self.dbDict[node].append(nodeNext) # at that key, append next node to the list


    def print(self):
        '''
        calls self.nodes() which will build the deBruijn dictionary
        deBruijn dictionary -- {'key' : ['value']} -- {'tail' : ['head']}
        then prints (key -> key's value) -- there are instances where a key could have more than 1 value, in which case the values are also printed in alphabetical order

        "the edges may be given in any order, as long as the tail of each edge is provided in column 1"

        https://www.geeksforgeeks.org/python-concatenate-dictionary-value-lists/
        https://www.learnbyexample.org/python-string-join-method/ --> join() on dictionary section is super useful
        '''

        self.nodes()

        for key in sorted(self.dbDict.keys()): # for each key in deBruijnDictionary (dbDict)
            print(key + ' -> ' + ', '.join(str(i) for i in sorted(self.dbDict[key]))) # only keys with multiple values separated by a comma will have the comma printed in output



def main():
    '''
    reads from input file and instantiates k-mer size and sequence into class deBruijn, then calls print()
    which in turn calls nodes() which builds the deBruijn dictionary, and then prints it in the specified
    format (tail->head)

    '''

    count = 0
    k = 0 # line 0 of given dataset is the kmer size
    seq = '' # line 1 is the string

    inputFile = open('rosalind_ba3d.txt', 'r') # open the input file for reading
    for line in inputFile:
        if count == 0: # line0
            k = int(line.strip()) # get the kmer number (which will dictate what size kmer we are finding in the seq)
        else: # line1
            seq = line.strip() # get the sequence
        count += 1

    db = deBruijn(k, seq)
    db.print()

if __name__ == '__main__':
    main()
# Out:
# AAAACACAACT -> AAACACAACTC
# AAAAGATCAGG -> AAAGATCAGGG
# AAAAGGCGAAG -> AAAGGCGAAGG
# AAAATTTTCCA -> AAATTTTCCAT
# AAACACAACTC -> AACACAACTCC
# AAACAGATATC -> AACAGATATCC
# AAACATAAACC -> AACATAAACCG
# AAACCCTTCCC -> AACCCTTCCCT
# AAACCGTGCAT -> AACCGTGCATT
# AAACGCCCGAC -> AACGCCCGACA
# AAAGAGTAGCA -> AAGAGTAGCAC
# AAAGATCAGGG -> AAGATCAGGGC
# AAAGGAGACAA -> AAGGAGACAAC
# AAAGGATCATA -> AAGGATCATAC
# AAAGGATTCGG -> AAGGATTCGGT
# AAAGGCGAAGG -> AAGGCGAAGGC
# AAAGGGAATCA -> AAGGGAATCAG
# AAAGGTCCCTA -> AAGGTCCCTAA
# AAATACGACTG -> AATACGACTGA
# AAATCCAATCC -> AATCCAATCCT
# AAATCCGGTAC -> AATCCGGTACC
# AAATGACACAG -> AATGACACAGC
# AAATTAATGTT -> AATTAATGTTA
# AAATTGATAGG -> AATTGATAGGA
# AAATTTTCCAT -> AATTTTCCATG
# AAATTTTTGGA -> AATTTTTGGAG
# AACACAACTCC -> ACACAACTCCC
# AACACCGATTT -> ACACCGATTTC
# AACACGCGGAC -> ACACGCGGACA
# AACAGATAGGC -> ACAGATAGGCC
# AACAGATATCC -> ACAGATATCCC
# AACAGGGGTTT -> ACAGGGGTTTC
# AACAGTTACGG -> ACAGTTACGGT
# AACATAAACCG -> ACATAAACCGT
# AACCACTACGG -> ACCACTACGGT
# AACCACTTTTG -> ACCACTTTTGC
# AACCATACAAA -> ACCATACAAAT
# AACCATCCAAC -> ACCATCCAACA
# AACCCATCGGC -> ACCCATCGGCT
# AACCCCTGTAT -> ACCCCTGTATC
# AACCCTTCCCT -> ACCCTTCCCTA
# AACCGGAACTC -> ACCGGAACTCA
# AACCGGGTCTC -> ACCGGGTCTCT
# AACCGTGCATT -> ACCGTGCATTG
# AACCGTTAATG -> ACCGTTAATGC
# AACCTATTAGA -> ACCTATTAGAC
# AACGAACCCCT -> ACGAACCCCTG
# AACGAGACAAA -> ACGAGACAAAC
# AACGCCATTGA -> ACGCCATTGAG
# AACGCCCGACA -> ACGCCCGACAA
# AACGTTTTCTA -> ACGTTTTCTAC
# AACTAGGACGA -> ACTAGGACGAC
# AACTATAAAGG -> ACTATAAAGGA
# AACTATCTAAT -> ACTATCTAATT
# AACTCAGCACG -> ACTCAGCACGC
# AACTCCCTCCG -> ACTCCCTCCGC
# AACTCGGCAAC -> ACTCGGCAACC
# AACTGAATACC -> ACTGAATACCG
# AACTGGCCAGG -> ACTGGCCAGGA
# AACTGGTAGAT -> ACTGGTAGATC
# AACTTCCTTTA -> ACTTCCTTTAA
# AACTTGATCCG -> ACTTGATCCGA
# AACTTGTGAGA -> ACTTGTGAGAA
# AAGAAAGGAGA -> AGAAAGGAGAC
# AAGAAGATGGT -> AGAAGATGGTC
# AAGAAGGGGCT -> AGAAGGGGCTA
# AAGACCTAGAA -> AGACCTAGAAG
# AAGAGTAGCAC -> AGAGTAGCACA
# AAGATCAGGGC -> AGATCAGGGCT
# AAGATGGTCCT -> AGATGGTCCTT
# AAGATTCCCGC -> AGATTCCCGCG
# AAGCAATCGAC -> AGCAATCGACG
# AAGCACGAATC -> AGCACGAATCC
# AAGCATTTTTG -> AGCATTTTTGC
# AAGCCAACCGG -> AGCCAACCGGA
# AAGCGGTTTTC -> AGCGGTTTTCC
# AAGCTGGACTA -> AGCTGGACTAG
# AAGGAGACAAC -> AGGAGACAACT
# AAGGAGCTGCG -> AGGAGCTGCGG
# AAGGATCATAC -> AGGATCATACA
# AAGGATTCGGT -> AGGATTCGGTG
# AAGGCGAAGGC -> AGGCGAAGGCG
# AAGGCGTACCC -> AGGCGTACCCG
# AAGGGAATCAG -> AGGGAATCAGG
# AAGGGGCTAGT -> AGGGGCTAGTC
# AAGGTAGGAAT -> AGGTAGGAATT
# AAGGTCCCTAA -> AGGTCCCTAAC
# AAGTACCATGA -> AGTACCATGAA
# AAGTCCTTTAC -> AGTCCTTTACG
# AAGTCGACTCT -> AGTCGACTCTG
# AATACCGCCGT -> ATACCGCCGTA
# AATACGACTGA -> ATACGACTGAA
# AATACTCGGAT -> ATACTCGGATA
# AATCAGGAACT -> ATCAGGAACTA
# AATCCAATCCT -> ATCCAATCCTC
# AATCCGGAAGG -> ATCCGGAAGGT
# AATCCGGTACC -> ATCCGGTACCT
# AATCCTCCTTT -> ATCCTCCTTTT
# AATCGACGCTG -> ATCGACGCTGC
# AATCGGTTCTG -> ATCGGTTCTGT
# AATCGTTGAAC -> ATCGTTGAACT
# AATCTCGGCCA -> ATCTCGGCCAG
# AATCTGGGTAT -> ATCTGGGTATT
# AATGACACAGC -> ATGACACAGCA
# AATGCTGGGTA -> ATGCTGGGTAC
# AATGCTGGTGT -> ATGCTGGTGTC
# AATGTCCGCTT -> ATGTCCGCTTC
# AATGTTAGCAG -> ATGTTAGCAGT
# AATTAATGTTA -> ATTAATGTTAG
# AATTACCGGTC -> ATTACCGGTCG
# AATTAGGTGTC -> ATTAGGTGTCT
# AATTATCAGGA -> ATTATCAGGAC
# AATTCGTTGAC -> ATTCGTTGACT
# AATTGATAGGA -> ATTGATAGGAC
# AATTGCACTTC -> ATTGCACTTCA
# AATTTTCCATG -> ATTTTCCATGC
# AATTTTTGGAG -> ATTTTTGGAGC
# ACAAAATTTTC -> CAAAATTTTCC
# ACAAACAGATA -> CAAACAGATAT
# ACAAACATAAA -> CAAACATAAAC
# ACAAAGGATTC -> CAAAGGATTCG
# ACAAAGGTCCC -> CAAAGGTCCCT
# ACAAATTAATG -> CAAATTAATGT
# ACAACAGATAG -> CAACAGATAGG
# ACAACGCCATT -> CAACGCCATTG
# ACAACTATAAA -> CAACTATAAAG
# ACAACTCCCTC -> CAACTCCCTCC
# ACAACTCGGCA -> CAACTCGGCAA
# ACAACTTGATC -> CAACTTGATCC
# ACAATGCTGGG -> CAATGCTGGGT
# ACAATGTCCGC -> CAATGTCCGCT
# ACACAACTCCC -> CACAACTCCCT
# ACACAGCAAGC -> CACAGCAAGCA
# ACACATCACAG -> CACATCACAGC
# ACACCGATTTC -> CACCGATTTCT
# ACACCTACCAA -> CACCTACCAAA
# ACACCTAGCAT -> CACCTAGCATA
# ACACGCCTCAT -> CACGCCTCATC
# ACACGCGGACA -> CACGCGGACAA
# ACACTGGAGAA -> CACTGGAGAAG
# ACAGAGACCCG -> CAGAGACCCGT
# ACAGATAGGCC -> CAGATAGGCCA
# ACAGATATCCC -> CAGATATCCCG
# ACAGCAAGCAT -> CAGCAAGCATT
# ACAGCCCGTGA -> CAGCCCGTGAT
# ACAGCGGGCCA -> CAGCGGGCCAG
# ACAGCTTCTTG -> CAGCTTCTTGA
# ACAGGGGTTTC -> CAGGGGTTTCG
# ACAGTTACGGT -> CAGTTACGGTT
# ACATAAACCGT -> CATAAACCGTG
# ACATACCACGA -> CATACCACGAA
# ACATACTTCGA -> CATACTTCGAA
# ACATCACAGCG -> CATCACAGCGG
# ACATGGAAACC -> CATGGAAACCC
# ACATGGCACTC -> CATGGCACTCA
# ACATTGGGCAT -> CATTGGGCATT
# ACCAAATGACA -> CCAAATGACAC
# ACCAACCACTA -> CCAACCACTAC
# ACCACACATCA -> CCACACATCAC
# ACCACCGATGT -> CCACCGATGTC
# ACCACGAATTA -> CCACGAATTAT
# ACCACTACGGT -> CCACTACGGTT
# ACCACTACTCC -> CCACTACTCCA
# ACCACTTTTGC -> CCACTTTTGCA
# ACCATACAAAT -> CCATACAAATT
# ACCATCCAACA -> CCATCCAACAC
# ACCATGAACCT -> CCATGAACCTA
# ACCCATCGGCT -> CCCATCGGCTC
# ACCCATCTATC -> CCCATCTATCC
# ACCCCTGTATC -> CCCCTGTATCG
# ACCCGAGCTAT -> CCCGAGCTATA
# ACCCGCTCACT -> CCCGCTCACTC
# ACCCGTAATCT -> CCCGTAATCTG
# ACCCGTCCCAA -> CCCGTCCCAAG
# ACCCTGGCAAC -> CCCTGGCAACC
# ACCCTTCCCTA -> CCCTTCCCTAA
# ACCCTTTCCAG -> CCCTTTCCAGA
# ACCGAGGTTTA -> CCGAGGTTTAC
# ACCGATGTCGA -> CCGATGTCGAA
# ACCGATTTCTG -> CCGATTTCTGG
# ACCGCACGGTA -> CCGCACGGTAA
# ACCGCCGTAGT -> CCGCCGTAGTC
# ACCGGAACTCA -> CCGGAACTCAG
# ACCGGGTCTCT -> CCGGGTCTCTC
# ACCGGTCGCTG -> CCGGTCGCTGC
# ACCGGTTGAAC -> CCGGTTGAACC
# ACCGTAACTTC -> CCGTAACTTCC
# ACCGTGCATTG -> CCGTGCATTGA
# ACCGTTAATGC -> CCGTTAATGCT
# ACCTACCAAAT -> CCTACCAAATG
# ACCTAGAAGCT -> CCTAGAAGCTG
# ACCTAGCATAG -> CCTAGCATAGC
# ACCTATTAGAC -> CCTATTAGACC
# ACCTGCGTGTT -> CCTGCGTGTTC
# ACCTGTACAAT -> CCTGTACAATG
# ACGAACCCCTG -> CGAACCCCTGT
# ACGAATCCGGA -> CGAATCCGGAA
# ACGAATTATCA -> CGAATTATCAG
# ACGACAACTAT -> CGACAACTATA
# ACGACACGCCT -> CGACACGCCTC
# ACGACATACCA -> CGACATACCAC
# ACGACGTCTAG -> CGACGTCTAGT
# ACGACGTTGAG -> CGACGTTGAGA
# ACGACTGAAGG -> CGACTGAAGGA
# ACGAGACAAAC -> CGAGACAAACA
# ACGCCATTGAG -> CGCCATTGAGA
# ACGCCCGACAA -> CGCCCGACAAC
# ACGCCGGCGTG -> CGCCGGCGTGG
# ACGCCTCATCC -> CGCCTCATCCT
# ACGCGGACAAA -> CGCGGACAAAC
# ACGCGGCAATC -> CGCGGCAATCG
# ACGCTGCCCCC -> CGCTGCCCCCT
# ACGCTTTTCGG -> CGCTTTTCGGA
# ACGGAAATACG -> CGGAAATACGA
# ACGGATATAGA -> CGGATATAGAG
# ACGGTAATCGT -> CGGTAATCGTT
# ACGGTGATGGG -> CGGTGATGGGC
# ACGGTGCCAGA -> CGGTGCCAGAA
# ACGGTTGAAAC -> CGGTTGAAACG
# ACGGTTGCCTA -> CGGTTGCCTAG
# ACGTATTACAT -> CGTATTACATG
# ACGTCGAACTA -> CGTCGAACTAT
# ACGTCTAGTCT -> CGTCTAGTCTC
# ACGTGTTAGCA -> CGTGTTAGCAG
# ACGTTGAGATG -> CGTTGAGATGT
# ACGTTTTCTAC -> CGTTTTCTACG
# ACTAACTGAAT -> CTAACTGAATA
# ACTACAACGCC -> CTACAACGCCA
# ACTACGGTTGA -> CTACGGTTGAA
# ACTACTCCAGC -> CTACTCCAGCT
# ACTAGGACGAC -> CTAGGACGACA
# ACTAGTTGGCT -> CTAGTTGGCTG
# ACTATAAAGGA -> CTATAAAGGAT
# ACTATCTAATT -> CTATCTAATTG
# ACTATGATCCT -> CTATGATCCTC
# ACTCAGCACGC -> CTCAGCACGCC
# ACTCATCTCCA -> CTCATCTCCAG
# ACTCCAGCTAG -> CTCCAGCTAGA
# ACTCCCTCCGC -> CTCCCTCCGCA
# ACTCCTGCGTC -> CTCCTGCGTCA
# ACTCGGATACG -> CTCGGATACGG
# ACTCGGCAACC -> CTCGGCAACCA
# ACTCGGCCGTG -> CTCGGCCGTGA
# ACTCTGTGACG -> CTCTGTGACGT
# ACTCTTTGTTA -> CTCTTTGTTAC
# ACTGAAGGAGC -> CTGAAGGAGCT
# ACTGAATACCG -> CTGAATACCGC
# ACTGACAAAAT -> CTGACAAAATT
# ACTGCCAAGAA -> CTGCCAAGAAG
# ACTGGAGAAGA -> CTGGAGAAGAA
# ACTGGCCAGGA -> CTGGCCAGGAT
# ACTGGTAGATC -> CTGGTAGATCG
# ACTTCACCGCA -> CTTCACCGCAC
# ACTTCCTTTAA -> CTTCCTTTAAA
# ACTTCGAAGTC -> CTTCGAAGTCC
# ACTTCGGTATC -> CTTCGGTATCC
# ACTTCTCCTAA -> CTTCTCCTAAG
# ACTTGATCCGA -> CTTGATCCGAA
# ACTTGTGAGAA -> CTTGTGAGAAT
# ACTTGTTTGTT -> CTTGTTTGTTA
# ACTTTTGCAAC -> CTTTTGCAACA
# AGAAAGAGTAG -> GAAAGAGTAGC
# AGAAAGGAGAC -> GAAAGGAGACA
# AGAACGAACCC -> GAACGAACCCC
# AGAAGAAGATG -> GAAGAAGATGG
# AGAAGATGGTC -> GAAGATGGTCC
# AGAAGCTGGAC -> GAAGCTGGACT
# AGAAGGGGCTA -> GAAGGGGCTAG
# AGAATTACCGG -> GAATTACCGGT
# AGACAAACAGA -> GACAAACAGAT
# AGACAACTCGG -> GACAACTCGGC
# AGACATACTTC -> GACATACTTCG
# AGACCCATCTA -> GACCCATCTAT
# AGACCCGTCCC -> GACCCGTCCCA
# AGACCCTGGCA -> GACCCTGGCAA
# AGACCGAGGTT -> GACCGAGGTTT
# AGACCTAGAAG -> GACCTAGAAGC
# AGACGACGTTG -> GACGACGTTGA
# AGACTCTTTGT -> GACTCTTTGTT
# AGACTGCCAAG -> GACTGCCAAGA
# AGACTTCGGTA -> GACTTCGGTAT
# AGAGACCCGTC -> GAGACCCGTCC
# AGAGACTCTTT -> GAGACTCTTTG
# AGAGATGTAGG -> GAGATGTAGGA
# AGAGCGGTCTC -> GAGCGGTCTCC
# AGAGCTCAACC -> GAGCTCAACCG
# AGAGGCGGTCT -> GAGGCGGTCTG
# AGAGTAGCACA -> GAGTAGCACAT
# AGAGTCGGCAA -> GAGTCGGCAAG
# AGATAGGCCAG -> GATAGGCCAGT
# AGATATCCCGT -> GATATCCCGTG
# AGATCAGGGCT -> GATCAGGGCTC
# AGATCGCTTAC -> GATCGCTTACG
# AGATGGGAGAT -> GATGGGAGATT
# AGATGGTCCTT -> GATGGTCCTTG
# AGATGTAATTC -> GATGTAATTCG
# AGATGTAGGAA -> GATGTAGGAAC
# AGATTCATTAG -> GATTCATTAGC
# AGATTCCCGCG -> GATTCCCGCGG
# AGATTTCGTTG -> GATTTCGTTGT
# AGCAACAGTTA -> GCAACAGTTAC
# AGCAAGCATTT -> GCAAGCATTTT
# AGCAATCGACG -> GCAATCGACGC
# AGCACATTGGG -> GCACATTGGGC
# AGCACGAATCC -> GCACGAATCCG
# AGCACGCCGGC -> GCACGCCGGCG
# AGCAGTATGTA -> GCAGTATGTAA
# AGCAGTCGTCC -> GCAGTCGTCCA
# AGCAGTCTTAG -> GCAGTCTTAGA
# AGCATAGCTGC -> GCATAGCTGCG
# AGCATCGCAGA -> GCATCGCAGAG
# AGCATTCCTAC -> GCATTCCTACG
# AGCATTTTTGC -> GCATTTTTGCC
# AGCCAACCGGA -> GCCAACCGGAA
# AGCCCGTGATG -> GCCCGTGATGC
# AGCCTCTTATG -> GCCTCTTATGT
# AGCGGGCCAGA -> GCGGGCCAGAC
# AGCGGTCTCCC -> GCGGTCTCCCG
# AGCGGTTTTCC -> GCGGTTTTCCA
# AGCTAGACCCT -> GCTAGACCCTG
# AGCTATAGGCG -> GCTATAGGCGT
# AGCTCAACCGG -> GCTCAACCGGG
# AGCTGACCCGA -> GCTGACCCGAG
# AGCTGCGGACG -> GCTGCGGACGT
# AGCTGCGGTTC -> GCTGCGGTTCG
# AGCTGGACTAG -> GCTGGACTAGT
# AGCTTCTTGAT -> GCTTCTTGATC
# AGGAACGAGAC -> GGAACGAGACA
# AGGAACTAGGA -> GGAACTAGGAC
# AGGAATTAGGT -> GGAATTAGGTG
# AGGACAACAGA -> GGACAACAGAT
# AGGACATGGAA -> GGACATGGAAA
# AGGACGACAAC -> GGACGACAACT
# AGGAGACAACT -> GGAGACAACTC
# AGGAGCTGCGG -> GGAGCTGCGGT
# AGGATCATACA -> GGATCATACAC
# AGGATTCGGTG -> GGATTCGGTGG
# AGGATTGAGTG -> GGATTGAGTGC
# AGGCCAGTACA -> GGCCAGTACAG
# AGGCCATCTCG -> GGCCATCTCGG
# AGGCGAAGGCG -> GGCGAAGGCGT
# AGGCGGTCTGA -> GGCGGTCTGAC
# AGGCGTACCCG -> GGCGTACCCGC
# AGGCGTTTCCT -> GGCGTTTCCTC
# AGGCTCGGTCT -> GGCTCGGTCTC
# AGGGAATCAGG -> GGGAATCAGGA
# AGGGCATCGGG -> GGGCATCGGGC
# AGGGCGCGAAG -> GGGCGCGAAGA
# AGGGCTCACCC -> GGGCTCACCCG
# AGGGGCTAGTC -> GGGGCTAGTCC
# AGGGGTTTCGG -> GGGGTTTCGGG
# AGGTAGGAATT -> GGTAGGAATTA
# AGGTCCCTAAC -> GGTCCCTAACT
# AGGTGTCTTTG -> GGTGTCTTTGA
# AGGTTTACAGA -> GGTTTACAGAG
# AGTACAGCTTC -> GTACAGCTTCT
# AGTACCATGAA -> GTACCATGAAC
# AGTAGCACATT -> GTAGCACATTG
# AGTATACGGTG -> GTATACGGTGA
# AGTATGTAAAT -> GTATGTAAATT
# AGTCAACTGGT -> GTCAACTGGTA
# AGTCATTGTGT -> GTCATTGTGTA
# AGTCATTTGGC -> GTCATTTGGCC
# AGTCCCCTAGA -> GTCCCCTAGAC
# AGTCCTGCTCA -> GTCCTGCTCAG
# AGTCCTTTACG -> GTCCTTTACGA
# AGTCGACTCTG -> GTCGACTCTGT
# AGTCGGCAAGT -> GTCGGCAAGTC
# AGTCGTCCACC -> GTCGTCCACCA
# AGTCTCACTAT -> GTCTCACTATG
# AGTCTCGTCCT -> GTCTCGTCCTA
# AGTCTTAAATC -> GTCTTAAATCC
# AGTCTTACAAA -> GTCTTACAAAG
# AGTCTTAGAAC -> GTCTTAGAACG
# AGTGCAGCTGA -> GTGCAGCTGAC
# AGTGCCGCCCG -> GTGCCGCCCGG
# AGTTACGGTTG -> GTTACGGTTGC
# AGTTGACCACT -> GTTGACCACTA
# AGTTGGATCTA -> GTTGGATCTAT
# AGTTGGCTGTC -> GTTGGCTGTCT
# ATAAACCGTGC -> TAAACCGTGCA
# ATAAAGGATCA -> TAAAGGATCAT
# ATACAAATTAA -> TACAAATTAAT
# ATACACCTACC -> TACACCTACCA
# ATACCACGAAT -> TACCACGAATT
# ATACCGCCGTA -> TACCGCCGTAG
# ATACGACTGAA -> TACGACTGAAG
# ATACGGAAATA -> TACGGAAATAC
# ATACGGTGATG -> TACGGTGATGG
# ATACTCGGATA -> TACTCGGATAC
# ATACTTCGAAG -> TACTTCGAAGT
# ATACTTCTCCT -> TACTTCTCCTA
# ATAGAGATGTA -> TAGAGATGTAG
# ATAGATGGGAG -> TAGATGGGAGA
# ATAGCTGCGGA -> TAGCTGCGGAC
# ATAGGACATGG -> TAGGACATGGA
# ATAGGCCAGTA -> TAGGCCAGTAC
# ATAGGCGTTTC -> TAGGCGTTTCC
# ATAGTCTTACA -> TAGTCTTACAA
# ATAGTTGGATC -> TAGTTGGATCT
# ATATAGAGATG -> TATAGAGATGT
# ATATCCCGTGG -> TATCCCGTGGT
# ATATTGCCTCA -> TATTGCCTCAA
# ATCACAGCGGG -> TCACAGCGGGC
# ATCAGGAACTA -> TCAGGAACTAG
# ATCAGGACAAC -> TCAGGACAACA
# ATCAGGGCTCA -> TCAGGGCTCAC
# ATCATACACCT -> TCATACACCTA
# ATCCAACACCG -> TCCAACACCGA
# ATCCAATCCTC -> TCCAATCCTCC
# ATCCAATCTCG -> TCCAATCTCGG
# ATCCAGCATTC -> TCCAGCATTCC
# ATCCCGTGGTG -> TCCCGTGGTGC
# ATCCGAAGCAA -> TCCGAAGCAAT
# ATCCGGAAGGT -> TCCGGAAGGTA
# ATCCGGTACCT -> TCCGGTACCTG
# ATCCTATGGAC -> TCCTATGGACA
# ATCCTCCTTTT -> TCCTCCTTTTT
# ATCCTCTTGGG -> TCCTCTTGGGA
# ATCCTTAAAAG -> TCCTTAAAAGA
# ATCGACGCTGC -> TCGACGCTGCC
# ATCGCAGAGCG -> TCGCAGAGCGG
# ATCGCGACGGA -> TCGCGACGGAT
# ATCGCTTACGA -> TCGCTTACGAC
# ATCGGCTCTCC -> TCGGCTCTCCA
# ATCGGGCAACG -> TCGGGCAACGT
# ATCGGTTCTGT -> TCGGTTCTGTC
# ATCGTGTCTCA -> TCGTGTCTCAT
# ATCGTTGAACT -> TCGTTGAACTT
# ATCTAATTGCA -> TCTAATTGCAC
# ATCTATCCAAT -> TCTATCCAATC
# ATCTATCCTTA -> TCTATCCTTAA
# ATCTCCAGATT -> TCTCCAGATTT
# ATCTCGGCCAG -> TCTCGGCCAGT
# ATCTCGGTAAA -> TCTCGGTAAAG
# ATCTGGGTATT -> TCTGGGTATTT
# ATGAAAACACA -> TGAAAACACAA
# ATGAACCTATT -> TGAACCTATTA
# ATGACACAGCA -> TGACACAGCAA
# ATGATCCTCTT -> TGATCCTCTTG
# ATGATGGTTAA -> TGATGGTTAAT
# ATGCATAGTTG -> TGCATAGTTGG
# ATGCATGATGG -> TGCATGATGGT
# ATGCCATGAAA -> TGCCATGAAAA
# ATGCCCTCCTA -> TGCCCTCCTAT
# ATGCTCAGCAA -> TGCTCAGCAAC
# ATGCTGGGTAC -> TGCTGGGTACA
# ATGCTGGTGTC -> TGCTGGTGTCA
# ATGGAAACCCT -> TGGAAACCCTT
# ATGGACAATGC -> TGGACAATGCT
# ATGGCACTCAT -> TGGCACTCATC
# ATGGCGCGTAC -> TGGCGCGTACG
# ATGGGAGATTC -> TGGGAGATTCA
# ATGGGCGAAAT -> TGGGCGAAATT
# ATGGTCCTTGC -> TGGTCCTTGCG
# ATGGTGGAAGT -> TGGTGGAAGTA
# ATGGTTAATAC -> TGGTTAATACT
# ATGTAAATTTT -> TGTAAATTTTT
# ATGTAATTCGT -> TGTAATTCGTT
# ATGTAGGAACG -> TGTAGGAACGA
# ATGTCCGCTTC -> TGTCCGCTTCC
# ATGTCGAAGCG -> TGTCGAAGCGG
# ATGTGGACGCG -> TGTGGACGCGG
# ATGTTAGCAGT -> TGTTAGCAGTC
# ATGTTTTATGC -> TGTTTTATGCT
# ATTAATGTTAG -> TTAATGTTAGC
# ATTACATGGCA -> TTACATGGCAC
# ATTACCGGTCG -> TTACCGGTCGC
# ATTAGACCCAT -> TTAGACCCATC
# ATTAGACTTCG -> TTAGACTTCGG
# ATTAGCAGTAT -> TTAGCAGTATG
# ATTAGGTGTCT -> TTAGGTGTCTT
# ATTATCAGGAC -> TTATCAGGACA
# ATTCATTAGCA -> TTCATTAGCAG
# ATTCCCGCGGC -> TTCCCGCGGCT
# ATTCCTACGAC -> TTCCTACGACG
# ATTCGGTGGTT -> TTCGGTGGTTA
# ATTCGTTGACT -> TTCGTTGACTT
# ATTGACCGTAA -> TTGACCGTAAC
# ATTGAGAGACT -> TTGAGAGACTC
# ATTGAGAGCTC -> TTGAGAGCTCA
# ATTGAGTGCCG -> TTGAGTGCCGC
# ATTGATAGGAC -> TTGATAGGACA
# ATTGCACTTCA -> TTGCACTTCAC
# ATTGCCTCAAA -> TTGCCTCAAAT
# ATTGGATGTTT -> TTGGATGTTTT
# ATTGGGCATTG -> TTGGGCATTGG
# ATTGTGTACAC -> TTGTGTACACC
# ATTGTTGTATA -> TTGTTGTATAG
# ATTTCGTTGTA -> TTTCGTTGTAG
# ATTTCTGGGGT -> TTTCTGGGGTT
# ATTTGCTATTG -> TTTGCTATTGA
# ATTTGGCCACA -> TTTGGCCACAG
# ATTTTCCATGC -> TTTTCCATGCA
# ATTTTTGCCCG -> TTTTTGCCCGA
# ATTTTTGGAGC -> TTTTTGGAGCA
# CAAAATTTTCC -> AAAATTTTCCA
# CAAACAGATAT -> AAACAGATATC
# CAAACATAAAC -> AAACATAAACC
# CAAAGGATTCG -> AAAGGATTCGG
# CAAAGGTCCCT -> AAAGGTCCCTA
# CAAATCCAATC -> AAATCCAATCC
# CAAATGACACA -> AAATGACACAG
# CAAATTAATGT -> AAATTAATGTT
# CAACACCGATT -> AACACCGATTT
# CAACAGATAGG -> AACAGATAGGC
# CAACAGGGGTT -> AACAGGGGTTT
# CAACAGTTACG -> AACAGTTACGG
# CAACCACTACG -> AACCACTACGG
# CAACCACTTTT -> AACCACTTTTG
# CAACCCATCGG -> AACCCATCGGC
# CAACCGGAACT -> AACCGGAACTC
# CAACCGGGTCT -> AACCGGGTCTC
# CAACCGTTAAT -> AACCGTTAATG
# CAACGCCATTG -> AACGCCATTGA
# CAACGTTTTCT -> AACGTTTTCTA
# CAACTATAAAG -> AACTATAAAGG
# CAACTCCCTCC -> AACTCCCTCCG
# CAACTCGGCAA -> AACTCGGCAAC
# CAACTGGTAGA -> AACTGGTAGAT
# CAACTTGATCC -> AACTTGATCCG
# CAAGAAGGGGC -> AAGAAGGGGCT
# CAAGCACGAAT -> AAGCACGAATC
# CAAGCATTTTT -> AAGCATTTTTG
# CAAGCCAACCG -> AAGCCAACCGG
# CAAGTCGACTC -> AAGTCGACTCT
# CAATCCTCCTT -> AATCCTCCTTT
# CAATCGACGCT -> AATCGACGCTG
# CAATCGGTTCT -> AATCGGTTCTG
# CAATCTCGGCC -> AATCTCGGCCA
# CAATGCTGGGT -> AATGCTGGGTA
# CAATGTCCGCT -> AATGTCCGCTT
# CACAAAGGTCC -> ACAAAGGTCCC
# CACAACTCCCT -> ACAACTCCCTC
# CACACATCACA -> ACACATCACAG
# CACAGCAAGCA -> ACAGCAAGCAT
# CACAGCCCGTG -> ACAGCCCGTGA
# CACAGCGGGCC -> ACAGCGGGCCA
# CACATCACAGC -> ACATCACAGCG
# CACATTGGGCA -> ACATTGGGCAT
# CACCAACCACT -> ACCAACCACTA
# CACCCGTAATC -> ACCCGTAATCT
# CACCCTTTCCA -> ACCCTTTCCAG
# CACCGATGTCG -> ACCGATGTCGA
# CACCGATTTCT -> ACCGATTTCTG
# CACCGCACGGT -> ACCGCACGGTA
# CACCGGTTGAA -> ACCGGTTGAAC
# CACCTACCAAA -> ACCTACCAAAT
# CACCTAGCATA -> ACCTAGCATAG
# CACCTGCGTGT -> ACCTGCGTGTT
# CACGAATCCGG -> ACGAATCCGGA
# CACGAATTATC -> ACGAATTATCA
# CACGCCGGCGT -> ACGCCGGCGTG
# CACGCCTCATC -> ACGCCTCATCC
# CACGCGGACAA -> ACGCGGACAAA
# CACGGTAATCG -> ACGGTAATCGT
# CACTAACTGAA -> ACTAACTGAAT
# CACTACGGTTG -> ACTACGGTTGA
# CACTACTCCAG -> ACTACTCCAGC
# CACTATGATCC -> ACTATGATCCT
# CACTCATCTCC -> ACTCATCTCCA
# CACTCCTGCGT -> ACTCCTGCGTC
# CACTCGGCCGT -> ACTCGGCCGTG
# CACTGGAGAAG -> ACTGGAGAAGA
# CACTTCACCGC -> ACTTCACCGCA
# CACTTTTGCAA -> ACTTTTGCAAC
# CAGAAAGAGTA -> AGAAAGAGTAG
# CAGACTGCCAA -> AGACTGCCAAG
# CAGAGACCCGT -> AGAGACCCGTC
# CAGAGCGGTCT -> AGAGCGGTCTC
# CAGAGGCGGTC -> AGAGGCGGTCT
# CAGAGTCGGCA -> AGAGTCGGCAA
# CAGATAGGCCA -> AGATAGGCCAG
# CAGATATCCCG -> AGATATCCCGT
# CAGATTTCGTT -> AGATTTCGTTG
# CAGCAACAGTT -> AGCAACAGTTA
# CAGCAAGCATT -> AGCAAGCATTT
# CAGCACGCCGG -> AGCACGCCGGC
# CAGCATTCCTA -> AGCATTCCTAC
# CAGCCCGTGAT -> AGCCCGTGATG
# CAGCGGGCCAG -> AGCGGGCCAGA
# CAGCTAGACCC -> AGCTAGACCCT
# CAGCTGACCCG -> AGCTGACCCGA
# CAGCTTCTTGA -> AGCTTCTTGAT
# CAGGAACTAGG -> AGGAACTAGGA
# CAGGACAACAG -> AGGACAACAGA
# CAGGATTGAGT -> AGGATTGAGTG
# CAGGGCATCGG -> AGGGCATCGGG
# CAGGGCTCACC -> AGGGCTCACCC
# CAGGGGTTTCG -> AGGGGTTTCGG
# CAGTACAGCTT -> AGTACAGCTTC
# CAGTATACGGT -> AGTATACGGTG
# CAGTATGTAAA -> AGTATGTAAAT
# CAGTCAACTGG -> AGTCAACTGGT
# CAGTCATTTGG -> AGTCATTTGGC
# CAGTCCTGCTC -> AGTCCTGCTCA
# CAGTCGTCCAC -> AGTCGTCCACC
# CAGTCTCGTCC -> AGTCTCGTCCT
# CAGTCTTAGAA -> AGTCTTAGAAC
# CAGTGCAGCTG -> AGTGCAGCTGA
# CAGTTACGGTT -> AGTTACGGTTG
# CATAAACCGTG -> ATAAACCGTGC
# CATACAAATTA -> ATACAAATTAA
# CATACACCTAC -> ATACACCTACC
# CATACCACGAA -> ATACCACGAAT
# CATACTTCGAA -> ATACTTCGAAG
# CATACTTCTCC -> ATACTTCTCCT
# CATAGCTGCGG -> ATAGCTGCGGA
# CATAGTTGGAT -> ATAGTTGGATC
# CATATTGCCTC -> ATATTGCCTCA
# CATCACAGCGG -> ATCACAGCGGG
# CATCCAACACC -> ATCCAACACCG
# CATCCTATGGA -> ATCCTATGGAC
# CATCGCAGAGC -> ATCGCAGAGCG
# CATCGGCTCTC -> ATCGGCTCTCC
# CATCGGGCAAC -> ATCGGGCAACG
# CATCTATCCTT -> ATCTATCCTTA
# CATCTCCAGAT -> ATCTCCAGATT
# CATCTCGGTAA -> ATCTCGGTAAA
# CATGAAAACAC -> ATGAAAACACA
# CATGAACCTAT -> ATGAACCTATT
# CATGATGGTTA -> ATGATGGTTAA
# CATGCATGATG -> ATGCATGATGG
# CATGGAAACCC -> ATGGAAACCCT
# CATGGCACTCA -> ATGGCACTCAT
# CATTAGCAGTA -> ATTAGCAGTAT
# CATTCCTACGA -> ATTCCTACGAC
# CATTGACCGTA -> ATTGACCGTAA
# CATTGAGAGAC -> ATTGAGAGACT
# CATTGGATGTT -> ATTGGATGTTT
# CATTGGGCATT -> ATTGGGCATTG
# CATTGTGTACA -> ATTGTGTACAC
# CATTTGGCCAC -> ATTTGGCCACA
# CATTTTTGCCC -> ATTTTTGCCCG
# CCAAATGACAC -> CAAATGACACA
# CCAACACCGAT -> CAACACCGATT
# CCAACCACTAC -> CAACCACTACG
# CCAACCGGAAC -> CAACCGGAACT
# CCAAGAAGGGG -> CAAGAAGGGGC
# CCAAGCACGAA -> CAAGCACGAAT
# CCAAGCCAACC -> CAAGCCAACCG
# CCAATCCTCCT -> CAATCCTCCTT
# CCAATCTCGGC -> CAATCTCGGCC
# CCACACATCAC -> CACACATCACA
# CCACAGCCCGT -> CACAGCCCGTG
# CCACCAACCAC -> CACCAACCACT
# CCACCCTTTCC -> CACCCTTTCCA
# CCACCGATGTC -> CACCGATGTCG
# CCACGAATTAT -> CACGAATTATC
# CCACTACGGTT -> CACTACGGTTG
# CCACTACTCCA -> CACTACTCCAG
# CCACTCCTGCG -> CACTCCTGCGT
# CCACTTTTGCA -> CACTTTTGCAA
# CCAGAAAGAGT -> CAGAAAGAGTA
# CCAGACTGCCA -> CAGACTGCCAA
# CCAGAGGCGGT -> CAGAGGCGGTC
# CCAGATTTCGT -> CAGATTTCGTT
# CCAGCATTCCT -> CAGCATTCCTA
# CCAGCTAGACC -> CAGCTAGACCC
# CCAGGATTGAG -> CAGGATTGAGT
# CCAGTACAGCT -> CAGTACAGCTT
# CCAGTCATTTG -> CAGTCATTTGG
# CCAGTCTCGTC -> CAGTCTCGTCC
# CCAGTGCAGCT -> CAGTGCAGCTG
# CCATACAAATT -> CATACAAATTA
# CCATCCAACAC -> CATCCAACACC
# CCATCGGCTCT -> CATCGGCTCTC
# CCATCTATCCT -> CATCTATCCTT
# CCATCTCGGTA -> CATCTCGGTAA
# CCATGAAAACA -> CATGAAAACAC
# CCATGAACCTA -> CATGAACCTAT
# CCATGCATGAT -> CATGCATGATG
# CCATTGAGAGA -> CATTGAGAGAC
# CCCAAGCACGA -> CCAAGCACGAA
# CCCATCGGCTC -> CCATCGGCTCT
# CCCATCTATCC -> CCATCTATCCT
# CCCCCTTACGG -> CCCCTTACGGT
# CCCCTAGACGA -> CCCTAGACGAC
# CCCCTGTATCG -> CCCTGTATCGC
# CCCCTTACGGT -> CCCTTACGGTG
# CCCGACAACTT -> CCGACAACTTG
# CCCGAGCTATA -> CCGAGCTATAG
# CCCGAGTCATT -> CCGAGTCATTG
# CCCGATGGTGG -> CCGATGGTGGA
# CCCGCGGCTCA -> CCGCGGCTCAC
# CCCGCTCACTC -> CCGCTCACTCG
# CCCGGGGGATT -> CCGGGGGATTG
# CCCGTAATCTG -> CCGTAATCTGG
# CCCGTCCCAAG -> CCGTCCCAAGC
# CCCGTGATGCC -> CCGTGATGCCC
# CCCGTGGTGCG -> CCGTGGTGCGC
# CCCTAACTGGC -> CCTAACTGGCC
# CCCTAAGATTC -> CCTAAGATTCC
# CCCTAGACGAC -> CCTAGACGACG
# CCCTCCGCACC -> CCTCCGCACCG
# CCCTCCTATGC -> CCTCCTATGCA
# CCCTGGCAACC -> CCTGGCAACCC
# CCCTGTATCGC -> CCTGTATCGCG
# CCCTTACGGTG -> CCTTACGGTGC
# CCCTTCCCTAA -> CCTTCCCTAAG
# CCCTTTCCAGA -> CCTTTCCAGAG
# CCGAAGCAATC -> CGAAGCAATCG
# CCGACAACTTG -> CGACAACTTGA
# CCGAGCTATAG -> CGAGCTATAGG
# CCGAGGTTTAC -> CGAGGTTTACA
# CCGAGTCATTG -> CGAGTCATTGT
# CCGATGGTGGA -> CGATGGTGGAA
# CCGATGTCGAA -> CGATGTCGAAG
# CCGATTTCTGG -> CGATTTCTGGG
# CCGCACCGGTT -> CGCACCGGTTG
# CCGCACGGTAA -> CGCACGGTAAT
# CCGCCCGGGGG -> CGCCCGGGGGA
# CCGCCGTAGTC -> CGCCGTAGTCT
# CCGCGGCTCAC -> CGCGGCTCACC
# CCGCTCACTCG -> CGCTCACTCGG
# CCGCTTCCACT -> CGCTTCCACTC
# CCGGAACTCAG -> CGGAACTCAGC
# CCGGAAGGTAG -> CGGAAGGTAGG
# CCGGCGTGGCA -> CGGCGTGGCAG
# CCGGGGGATTG -> CGGGGGATTGT
# CCGGGTCTCTC -> CGGGTCTCTCG
# CCGGTACCTGT -> CGGTACCTGTA
# CCGGTCGCTGC -> CGGTCGCTGCG
# CCGGTTGAACC -> CGGTTGAACCA
# CCGTAACTTCC -> CGTAACTTCCT
# CCGTAATCTGG -> CGTAATCTGGG
# CCGTAGTCTTA -> CGTAGTCTTAA
# CCGTCCCAAGC -> CGTCCCAAGCA
# CCGTGAGACAT -> CGTGAGACATA
# CCGTGATGCCC -> CGTGATGCCCT
# CCGTGCATTGA -> CGTGCATTGAC
# CCGTGGTGCGC -> CGTGGTGCGCG
# CCGTTAATGCT -> CGTTAATGCTG
# CCTAACTGGCC -> CTAACTGGCCA
# CCTAAGAAAGG -> CTAAGAAAGGA
# CCTAAGATTCC -> CTAAGATTCCC
# CCTACCAAATG -> CTACCAAATGA
# CCTACGACGTC -> CTACGACGTCT
# CCTAGAAGCTG -> CTAGAAGCTGG
# CCTAGACGACG -> CTAGACGACGT
# CCTAGCATAGC -> CTAGCATAGCT
# CCTAGCCTCTT -> CTAGCCTCTTA
# CCTAGGCCATC -> CTAGGCCATCT
# CCTATGCATAG -> CTATGCATAGT
# CCTATGGACAA -> CTATGGACAAT
# CCTATTAGACC -> CTATTAGACCC
# CCTCAAATCCA -> CTCAAATCCAA
# CCTCACTAACT -> CTCACTAACTG
# CCTCATCCTAT -> CTCATCCTATG
# CCTCCGCACCG -> CTCCGCACCGG
# CCTCCTATGCA -> CTCCTATGCAT
# CCTCCTTTTTT -> CTCCTTTTTTA
# CCTCGGGATGC -> CTCGGGATGCC
# CCTCTTATGTG -> CTCTTATGTGG
# CCTCTTGGGAA -> CTCTTGGGAAC
# CCTGCGTCATA -> CTGCGTCATAC
# CCTGCGTGTTC -> CTGCGTGTTCT
# CCTGCTCAGAG -> CTGCTCAGAGT
# CCTGGCAACCC -> CTGGCAACCCA
# CCTGTACAATG -> CTGTACAATGT
# CCTGTATCGCG -> CTGTATCGCGA
# CCTTAAAAGAT -> CTTAAAAGATC
# CCTTACGGTGC -> CTTACGGTGCC
# CCTTCCCTAAG -> CTTCCCTAAGA
# CCTTGCGCTGC -> CTTGCGCTGCC
# CCTTTAAAAGG -> CTTTAAAAGGC
# CCTTTCCAGAG -> CTTTCCAGAGG
# CCTTTTTTAAC -> CTTTTTTAACA
# CGAAATTGATA -> GAAATTGATAG
# CGAACCCCTGT -> GAACCCCTGTA
# CGAACTATCTA -> GAACTATCTAA
# CGAAGACCTAG -> GAAGACCTAGA
# CGAAGCAATCG -> GAAGCAATCGA
# CGAAGCGGTTT -> GAAGCGGTTTT
# CGAAGGCGTAC -> GAAGGCGTACC
# CGAAGTCCTTT -> GAAGTCCTTTA
# CGAATCCGGAA -> GAATCCGGAAG
# CGAATTATCAG -> GAATTATCAGG
# CGACAACTATA -> GACAACTATAA
# CGACAACTTGA -> GACAACTTGAT
# CGACACGCCTC -> GACACGCCTCA
# CGACATACCAC -> GACATACCACG
# CGACGCTGCCC -> GACGCTGCCCC
# CGACGGATATA -> GACGGATATAG
# CGACGTCTAGT -> GACGTCTAGTC
# CGACGTTGAGA -> GACGTTGAGAT
# CGACTCTGTGA -> GACTCTGTGAC
# CGACTGAAGGA -> GACTGAAGGAG
# CGAGACAAACA -> GAGACAAACAG
# CGAGCTATAGG -> GAGCTATAGGC
# CGAGGTTTACA -> GAGGTTTACAG
# CGAGTCATTGT -> GAGTCATTGTG
# CGATGGTGGAA -> GATGGTGGAAG
# CGATGTCGAAG -> GATGTCGAAGC
# CGATTTCTGGG -> GATTTCTGGGG
# CGCACCGGTTG -> GCACCGGTTGA
# CGCACGGTAAT -> GCACGGTAATC
# CGCAGAGCGGT -> GCAGAGCGGTC
# CGCAGTCAACT -> GCAGTCAACTG
# CGCCATTGAGA -> GCCATTGAGAG
# CGCCCGACAAC -> GCCCGACAACT
# CGCCCGGGGGA -> GCCCGGGGGAT
# CGCCGGCGTGG -> GCCGGCGTGGC
# CGCCGTAGTCT -> GCCGTAGTCTT
# CGCCTCATCCT -> GCCTCATCCTA
# CGCGAAGACCT -> GCGAAGACCTA
# CGCGACGGATA -> GCGACGGATAT
# CGCGCAGTCAA -> GCGCAGTCAAC
# CGCGGACAAAC -> GCGGACAAACA
# CGCGGCAATCG -> GCGGCAATCGG
# CGCGGCTCACC -> GCGGCTCACCT
# CGCGTACGTGT -> GCGTACGTGTT
# CGCTCACTCGG -> GCTCACTCGGC
# CGCTCTTATAG -> GCTCTTATAGT
# CGCTGCCCCCT -> GCTGCCCCCTT
# CGCTGCCTCGG -> GCTGCCTCGGG
# CGCTGCGTCGT -> GCTGCGTCGTT
# CGCTTACGACA -> GCTTACGACAC
# CGCTTCCACTC -> GCTTCCACTCC
# CGCTTTTCGGA -> GCTTTTCGGAC
# CGGAAATACGA -> GGAAATACGAC
# CGGAACTCAGC -> GGAACTCAGCA
# CGGAAGGTAGG -> GGAAGGTAGGA
# CGGACAAACAT -> GGACAAACATA
# CGGACGTATTA -> GGACGTATTAC
# CGGACTACAAC -> GGACTACAACG
# CGGATACGGAA -> GGATACGGAAA
# CGGATATAGAG -> GGATATAGAGA
# CGGCAACCACT -> GGCAACCACTT
# CGGCAAGTCGA -> GGCAAGTCGAC
# CGGCAATCGGT -> GGCAATCGGTT
# CGGCCAGTCTC -> GGCCAGTCTCG
# CGGCCGTGAGA -> GGCCGTGAGAC
# CGGCGTGGCAG -> GGCGTGGCAGT
# CGGCTCACCTG -> GGCTCACCTGC
# CGGCTCTCCAC -> GGCTCTCCACC
# CGGGACCACAC -> GGGACCACACA
# CGGGATGCCAT -> GGGATGCCATG
# CGGGCAACGTT -> GGGCAACGTTT
# CGGGCCAGACT -> GGGCCAGACTG
# CGGGGGATTGT -> GGGGGATTGTT
# CGGGTCTCTCG -> GGGTCTCTCGG
# CGGGTGAGGGC -> GGGTGAGGGCG
# CGGTAAAGGGA -> GGTAAAGGGAA
# CGGTAATCGTT -> GGTAATCGTTG
# CGGTACCTGTA -> GGTACCTGTAC
# CGGTATCCAGC -> GGTATCCAGCA
# CGGTCGCTGCG -> GGTCGCTGCGT
# CGGTCTCAGGG -> GGTCTCAGGGC
# CGGTCTCCCGA -> GGTCTCCCGAT
# CGGTCTGACGC -> GGTCTGACGCT
# CGGTGATGGGC -> GGTGATGGGCG
# CGGTGCCAGAA -> GGTGCCAGAAA
# CGGTGGTTATT -> GGTGGTTATTA
# CGGTTCGCTCT -> GGTTCGCTCTT
# CGGTTCTGTCA -> GGTTCTGTCAA
# CGGTTGAAACG -> GGTTGAAACGC
# CGGTTGAACCA -> GGTTGAACCAT
# CGGTTGCCTAG -> GGTTGCCTAGC
# CGGTTTTCCAG -> GGTTTTCCAGT
# CGTAACTTCCT -> GTAACTTCCTT
# CGTAATCTGGG -> GTAATCTGGGT
# CGTACCCGCTC -> GTACCCGCTCA
# CGTACGTGTTA -> GTACGTGTTAG
# CGTAGTCTTAA -> GTAGTCTTAAA
# CGTATTACATG -> GTATTACATGG
# CGTCATACTTC -> GTCATACTTCT
# CGTCCACCAAC -> GTCCACCAACC
# CGTCCCAAGCA -> GTCCCAAGCAC
# CGTCCTAGGCC -> GTCCTAGGCCA
# CGTCGAACTAT -> GTCGAACTATC
# CGTCGTTGCAC -> GTCGTTGCACA
# CGTCTAGTCTC -> GTCTAGTCTCA
# CGTGAGACATA -> GTGAGACATAC
# CGTGATGCCCT -> GTGATGCCCTC
# CGTGCATTGAC -> GTGCATTGACC
# CGTGGCAGTAT -> GTGGCAGTATA
# CGTGGTGCGCG -> GTGGTGCGCGC
# CGTGTCTCATA -> GTGTCTCATAT
# CGTGTTAGCAG -> GTGTTAGCAGT
# CGTGTTCTTGG -> GTGTTCTTGGA
# CGTTAATGCTG -> GTTAATGCTGG
# CGTTGAACTTG -> GTTGAACTTGT
# CGTTGACTTGT -> GTTGACTTGTT
# CGTTGAGATGT -> GTTGAGATGTA
# CGTTGCACAAA -> GTTGCACAAAG
# CGTTGTAGGCT -> GTTGTAGGCTC
# CGTTTCCTCAC -> GTTTCCTCACT
# CGTTTTCTACG -> GTTTTCTACGA
# CTAACTGAATA -> TAACTGAATAC
# CTAACTGGCCA -> TAACTGGCCAG
# CTAAGAAAGGA -> TAAGAAAGGAG
# CTAAGATTCCC -> TAAGATTCCCG
# CTAATTGCACT -> TAATTGCACTT
# CTACAACGCCA -> TACAACGCCAT
# CTACCAAATGA -> TACCAAATGAC
# CTACGACATAC -> TACGACATACC
# CTACGACGTCT -> TACGACGTCTA
# CTACGGTTGAA -> TACGGTTGAAA
# CTACTCCAGCT -> TACTCCAGCTA
# CTAGAAGCTGG -> TAGAAGCTGGA
# CTAGACCCTGG -> TAGACCCTGGC
# CTAGACGACGT -> TAGACGACGTT
# CTAGCATAGCT -> TAGCATAGCTG
# CTAGCCTCTTA -> TAGCCTCTTAT
# CTAGGACGACA -> TAGGACGACAA
# CTAGGCCATCT -> TAGGCCATCTC
# CTAGTCCCCTA -> TAGTCCCCTAG
# CTAGTCTCACT -> TAGTCTCACTA
# CTAGTTGGCTG -> TAGTTGGCTGT
# CTATAAAGGAT -> TATAAAGGATC
# CTATAGGCGTT -> TATAGGCGTTT
# CTATCCAATCT -> TATCCAATCTC
# CTATCCTTAAA -> TATCCTTAAAA
# CTATCTAATTG -> TATCTAATTGC
# CTATGATCCTC -> TATGATCCTCT
# CTATGCATAGT -> TATGCATAGTT
# CTATGGACAAT -> TATGGACAATG
# CTATTAGACCC -> TATTAGACCCA
# CTATTGAGAGC -> TATTGAGAGCT
# CTCAAATCCAA -> TCAAATCCAAT
# CTCAACCGGGT -> TCAACCGGGTC
# CTCACCCGTAA -> TCACCCGTAAT
# CTCACCTGCGT -> TCACCTGCGTG
# CTCACTAACTG -> TCACTAACTGA
# CTCACTATGAT -> TCACTATGATC
# CTCACTCGGCC -> TCACTCGGCCG
# CTCAGAGTCGG -> TCAGAGTCGGC
# CTCAGCAACAG -> TCAGCAACAGT
# CTCAGCACGCC -> TCAGCACGCCG
# CTCAGGGCATC -> TCAGGGCATCG
# CTCATATTGCC -> TCATATTGCCT
# CTCATCCTATG -> TCATCCTATGG
# CTCATCTCCAG -> TCATCTCCAGA
# CTCCACCCTTT -> TCCACCCTTTC
# CTCCAGATTTC -> TCCAGATTTCG
# CTCCAGCTAGA -> TCCAGCTAGAC
# CTCCAGTGCAG -> TCCAGTGCAGC
# CTCCCGATGGT -> TCCCGATGGTG
# CTCCCTCCGCA -> TCCCTCCGCAC
# CTCCGCACCGG -> TCCGCACCGGT
# CTCCTAAGAAA -> TCCTAAGAAAG
# CTCCTATGCAT -> TCCTATGCATA
# CTCCTGCGTCA -> TCCTGCGTCAT
# CTCCTTTTTTA -> TCCTTTTTTAA
# CTCGGATACGG -> TCGGATACGGA
# CTCGGCAACCA -> TCGGCAACCAC
# CTCGGCCAGTC -> TCGGCCAGTCT
# CTCGGCCGTGA -> TCGGCCGTGAG
# CTCGGGATGCC -> TCGGGATGCCA
# CTCGGGTGAGG -> TCGGGTGAGGG
# CTCGGTAAAGG -> TCGGTAAAGGG
# CTCGGTCTCAG -> TCGGTCTCAGG
# CTCGTCCTAGG -> TCGTCCTAGGC
# CTCTCCACCCT -> TCTCCACCCTT
# CTCTCCAGTGC -> TCTCCAGTGCA
# CTCTCGGGTGA -> TCTCGGGTGAG
# CTCTGTGACGT -> TCTGTGACGTC
# CTCTTATAGTC -> TCTTATAGTCT
# CTCTTATGTGG -> TCTTATGTGGA
# CTCTTGGGAAC -> TCTTGGGAACC
# CTCTTTGTTAC -> TCTTTGTTACT
# CTGAAGGAGCT -> TGAAGGAGCTG
# CTGAATACCGC -> TGAATACCGCC
# CTGACAAAATT -> TGACAAAATTT
# CTGACCCGAGC -> TGACCCGAGCT
# CTGACGCTTTT -> TGACGCTTTTC
# CTGCCAAGAAG -> TGCCAAGAAGG
# CTGCCCCCTTA -> TGCCCCCTTAC
# CTGCCTCGGGA -> TGCCTCGGGAT
# CTGCGGACGTA -> TGCGGACGTAT
# CTGCGGTTCGC -> TGCGGTTCGCT
# CTGCGTCATAC -> TGCGTCATACT
# CTGCGTCGTTG -> TGCGTCGTTGC
# CTGCGTGTTCT -> TGCGTGTTCTT
# CTGCTCAGAGT -> TGCTCAGAGTC
# CTGGACTAGTT -> TGGACTAGTTG
# CTGGAGAAGAA -> TGGAGAAGAAG
# CTGGCAACCCA -> TGGCAACCCAT
# CTGGCCAGGAT -> TGGCCAGGATT
# CTGGGGTTACC -> TGGGGTTACCA
# CTGGGTACACT -> TGGGTACACTG
# CTGGGTATTTG -> TGGGTATTTGC
# CTGGTAGATCG -> TGGTAGATCGC
# CTGGTGTCAGT -> TGGTGTCAGTC
# CTGTACAATGT -> TGTACAATGTC
# CTGTATCGCGA -> TGTATCGCGAC
# CTGTCAACCGT -> TGTCAACCGTT
# CTGTCTCTCCA -> TGTCTCTCCAG
# CTGTGACGTCG -> TGTGACGTCGA
# CTTAAAAGATC -> TTAAAAGATCA
# CTTAAATCCGG -> TTAAATCCGGT
# CTTACAAAGGA -> TTACAAAGGAT
# CTTACGACACG -> TTACGACACGC
# CTTACGGTGCC -> TTACGGTGCCA
# CTTAGAACGAA -> TTAGAACGAAC
# CTTATAGTCTT -> TTATAGTCTTA
# CTTATGTGGAC -> TTATGTGGACG
# CTTCACCGCAC -> TTCACCGCACG
# CTTCCACTCCT -> TTCCACTCCTG
# CTTCCCTAAGA -> TTCCCTAAGAT
# CTTCCTTTAAA -> TTCCTTTAAAA
# CTTCGAAGTCC -> TTCGAAGTCCT
# CTTCGGTATCC -> TTCGGTATCCA
# CTTCTCCTAAG -> TTCTCCTAAGA
# CTTCTTGATCG -> TTCTTGATCGT
# CTTGATCCGAA -> TTGATCCGAAG
# CTTGATCGTGT -> TTGATCGTGTC
# CTTGCGCTGCC -> TTGCGCTGCCT
# CTTGGATGGCG -> TTGGATGGCGC
# CTTGGGAACCA -> TTGGGAACCAT
# CTTGTGAGAAT -> TTGTGAGAATT
# CTTGTTTGTTA -> TTGTTTGTTAG
# CTTTAAAAGGC -> TTTAAAAGGCG
# CTTTCCAGAGG -> TTTCCAGAGGC
# CTTTGAGTTGA -> TTTGAGTTGAC
# CTTTGTTACTG -> TTTGTTACTGA
# CTTTTCGGACT -> TTTTCGGACTA
# CTTTTGCAACA -> TTTTGCAACAG
# CTTTTTTAACA -> TTTTTTAACAC
# GAAAACACAAC -> AAAACACAACT
# GAAACCCTTCC -> AAACCCTTCCC
# GAAACGCCCGA -> AAACGCCCGAC
# GAAAGAGTAGC -> AAAGAGTAGCA
# GAAAGGAGACA -> AAAGGAGACAA
# GAAATACGACT -> AAATACGACTG
# GAAATTGATAG -> AAATTGATAGG
# GAACCATACAA -> AACCATACAAA
# GAACCATCCAA -> AACCATCCAAC
# GAACCCCTGTA -> AACCCCTGTAT
# GAACCTATTAG -> AACCTATTAGA
# GAACGAACCCC -> AACGAACCCCT
# GAACGAGACAA -> AACGAGACAAA
# GAACTAGGACG -> AACTAGGACGA
# GAACTATCTAA -> AACTATCTAAT
# GAACTCAGCAC -> AACTCAGCACG
# GAACTTGTGAG -> AACTTGTGAGA
# GAAGAAGATGG -> AAGAAGATGGT
# GAAGACCTAGA -> AAGACCTAGAA
# GAAGATGGTCC -> AAGATGGTCCT
# GAAGCAATCGA -> AAGCAATCGAC
# GAAGCGGTTTT -> AAGCGGTTTTC
# GAAGCTGGACT -> AAGCTGGACTA
# GAAGGAGCTGC -> AAGGAGCTGCG
# GAAGGCGTACC -> AAGGCGTACCC
# GAAGGGGCTAG -> AAGGGGCTAGT
# GAAGGTAGGAA -> AAGGTAGGAAT
# GAAGTACCATG -> AAGTACCATGA
# GAAGTCCTTTA -> AAGTCCTTTAC
# GAATACCGCCG -> AATACCGCCGT
# GAATCAGGAAC -> AATCAGGAACT
# GAATCCGGAAG -> AATCCGGAAGG
# GAATTACCGGT -> AATTACCGGTC
# GAATTAGGTGT -> AATTAGGTGTC
# GAATTATCAGG -> AATTATCAGGA
# GACAAAATTTT -> ACAAAATTTTC
# GACAAACAGAT -> ACAAACAGATA
# GACAAACATAA -> ACAAACATAAA
# GACAACAGATA -> ACAACAGATAG
# GACAACTATAA -> ACAACTATAAA
# GACAACTCGGC -> ACAACTCGGCA
# GACAACTTGAT -> ACAACTTGATC
# GACAATGCTGG -> ACAATGCTGGG
# GACACAGCAAG -> ACACAGCAAGC
# GACACGCCTCA -> ACACGCCTCAT
# GACATACCACG -> ACATACCACGA
# GACATACTTCG -> ACATACTTCGA
# GACATGGAAAC -> ACATGGAAACC
# GACCACACATC -> ACCACACATCA
# GACCACTACTC -> ACCACTACTCC
# GACCCATCTAT -> ACCCATCTATC
# GACCCGAGCTA -> ACCCGAGCTAT
# GACCCGTCCCA -> ACCCGTCCCAA
# GACCCTGGCAA -> ACCCTGGCAAC
# GACCGAGGTTT -> ACCGAGGTTTA
# GACCGTAACTT -> ACCGTAACTTC
# GACCTAGAAGC -> ACCTAGAAGCT
# GACGACAACTA -> ACGACAACTAT
# GACGACGTTGA -> ACGACGTTGAG
# GACGCGGCAAT -> ACGCGGCAATC
# GACGCTGCCCC -> ACGCTGCCCCC
# GACGCTTTTCG -> ACGCTTTTCGG
# GACGGATATAG -> ACGGATATAGA
# GACGTATTACA -> ACGTATTACAT
# GACGTCGAACT -> ACGTCGAACTA
# GACGTCTAGTC -> ACGTCTAGTCT
# GACGTTGAGAT -> ACGTTGAGATG
# GACTACAACGC -> ACTACAACGCC
# GACTAGTTGGC -> ACTAGTTGGCT
# GACTCTGTGAC -> ACTCTGTGACG
# GACTCTTTGTT -> ACTCTTTGTTA
# GACTGAAGGAG -> ACTGAAGGAGC
# GACTGCCAAGA -> ACTGCCAAGAA
# GACTTCGGTAT -> ACTTCGGTATC
# GACTTGTTTGT -> ACTTGTTTGTT
# GAGAAGAAGAT -> AGAAGAAGATG
# GAGAATTACCG -> AGAATTACCGG
# GAGACAAACAG -> AGACAAACAGA
# GAGACAACTCG -> AGACAACTCGG
# GAGACATACTT -> AGACATACTTC
# GAGACCCGTCC -> AGACCCGTCCC
# GAGACTCTTTG -> AGACTCTTTGT
# GAGAGACTCTT -> AGAGACTCTTT
# GAGAGCTCAAC -> AGAGCTCAACC
# GAGATGTAATT -> AGATGTAATTC
# GAGATGTAGGA -> AGATGTAGGAA
# GAGATTCATTA -> AGATTCATTAG
# GAGCATCGCAG -> AGCATCGCAGA
# GAGCGGTCTCC -> AGCGGTCTCCC
# GAGCTATAGGC -> AGCTATAGGCG
# GAGCTCAACCG -> AGCTCAACCGG
# GAGCTGCGGTT -> AGCTGCGGTTC
# GAGGCGGTCTG -> AGGCGGTCTGA
# GAGGGCGCGAA -> AGGGCGCGAAG
# GAGGTTTACAG -> AGGTTTACAGA
# GAGTAGCACAT -> AGTAGCACATT
# GAGTCATTGTG -> AGTCATTGTGT
# GAGTCGGCAAG -> AGTCGGCAAGT
# GAGTGCCGCCC -> AGTGCCGCCCG
# GAGTTGACCAC -> AGTTGACCACT
# GATACGGAAAT -> ATACGGAAATA
# GATAGGACATG -> ATAGGACATGG
# GATAGGCCAGT -> ATAGGCCAGTA
# GATATAGAGAT -> ATATAGAGATG
# GATATCCCGTG -> ATATCCCGTGG
# GATCAGGGCTC -> ATCAGGGCTCA
# GATCATACACC -> ATCATACACCT
# GATCCGAAGCA -> ATCCGAAGCAA
# GATCCTCTTGG -> ATCCTCTTGGG
# GATCGCTTACG -> ATCGCTTACGA
# GATCGTGTCTC -> ATCGTGTCTCA
# GATCTATCCAA -> ATCTATCCAAT
# GATGCCATGAA -> ATGCCATGAAA
# GATGCCCTCCT -> ATGCCCTCCTA
# GATGGCGCGTA -> ATGGCGCGTAC
# GATGGGAGATT -> ATGGGAGATTC
# GATGGGCGAAA -> ATGGGCGAAAT
# GATGGTCCTTG -> ATGGTCCTTGC
# GATGGTGGAAG -> ATGGTGGAAGT
# GATGGTTAATA -> ATGGTTAATAC
# GATGTAATTCG -> ATGTAATTCGT
# GATGTAGGAAC -> ATGTAGGAACG
# GATGTCGAAGC -> ATGTCGAAGCG
# GATGTTTTATG -> ATGTTTTATGC
# GATTCATTAGC -> ATTCATTAGCA
# GATTCCCGCGG -> ATTCCCGCGGC
# GATTCGGTGGT -> ATTCGGTGGTT
# GATTGAGTGCC -> ATTGAGTGCCG
# GATTGTTGTAT -> ATTGTTGTATA
# GATTTCGTTGT -> ATTTCGTTGTA
# GATTTCTGGGG -> ATTTCTGGGGT
# GCAACAGGGGT -> CAACAGGGGTT
# GCAACAGTTAC -> CAACAGTTACG
# GCAACCACTTT -> CAACCACTTTT
# GCAACCCATCG -> CAACCCATCGG
# GCAACGTTTTC -> CAACGTTTTCT
# GCAAGCATTTT -> CAAGCATTTTT
# GCAAGTCGACT -> CAAGTCGACTC
# GCAATCGACGC -> CAATCGACGCT
# GCAATCGGTTC -> CAATCGGTTCT
# GCACAAAGGTC -> CACAAAGGTCC
# GCACATTGGGC -> CACATTGGGCA
# GCACCGGTTGA -> CACCGGTTGAA
# GCACGAATCCG -> CACGAATCCGG
# GCACGCCGGCG -> CACGCCGGCGT
# GCACGGTAATC -> CACGGTAATCG
# GCACTCATCTC -> CACTCATCTCC
# GCACTTCACCG -> CACTTCACCGC
# GCAGAGCGGTC -> CAGAGCGGTCT
# GCAGCTGACCC -> CAGCTGACCCG
# GCAGTATACGG -> CAGTATACGGT
# GCAGTATGTAA -> CAGTATGTAAA
# GCAGTCAACTG -> CAGTCAACTGG
# GCAGTCGTCCA -> CAGTCGTCCAC
# GCAGTCTTAGA -> CAGTCTTAGAA
# GCATAGCTGCG -> CATAGCTGCGG
# GCATAGTTGGA -> CATAGTTGGAT
# GCATCGCAGAG -> CATCGCAGAGC
# GCATCGGGCAA -> CATCGGGCAAC
# GCATGATGGTT -> CATGATGGTTA
# GCATTCCTACG -> CATTCCTACGA
# GCATTGACCGT -> CATTGACCGTA
# GCATTGGATGT -> CATTGGATGTT
# GCATTTTTGCC -> CATTTTTGCCC
# GCCAACCGGAA -> CCAACCGGAAC
# GCCAAGAAGGG -> CCAAGAAGGGG
# GCCAAGCCAAC -> CCAAGCCAACC
# GCCACAGCCCG -> CCACAGCCCGT
# GCCAGAAAGAG -> CCAGAAAGAGT
# GCCAGACTGCC -> CCAGACTGCCA
# GCCAGGATTGA -> CCAGGATTGAG
# GCCAGTACAGC -> CCAGTACAGCT
# GCCAGTCTCGT -> CCAGTCTCGTC
# GCCATCTCGGT -> CCATCTCGGTA
# GCCATGAAAAC -> CCATGAAAACA
# GCCATTGAGAG -> CCATTGAGAGA
# GCCCCCTTACG -> CCCCCTTACGG
# GCCCGACAACT -> CCCGACAACTT
# GCCCGAGTCAT -> CCCGAGTCATT
# GCCCGGGGGAT -> CCCGGGGGATT
# GCCCGTGATGC -> CCCGTGATGCC
# GCCCTCCTATG -> CCCTCCTATGC
# GCCGCCCGGGG -> CCGCCCGGGGG
# GCCGGCGTGGC -> CCGGCGTGGCA
# GCCGTAGTCTT -> CCGTAGTCTTA
# GCCGTGAGACA -> CCGTGAGACAT
# GCCTAGCCTCT -> CCTAGCCTCTT
# GCCTCAAATCC -> CCTCAAATCCA
# GCCTCATCCTA -> CCTCATCCTAT
# GCCTCGGGATG -> CCTCGGGATGC
# GCCTCTTATGT -> CCTCTTATGTG
# GCGAAATTGAT -> CGAAATTGATA
# GCGAAGACCTA -> CGAAGACCTAG
# GCGAAGGCGTA -> CGAAGGCGTAC
# GCGACGGATAT -> CGACGGATATA
# GCGCAGTCAAC -> CGCAGTCAACT
# GCGCGAAGACC -> CGCGAAGACCT
# GCGCGCAGTCA -> CGCGCAGTCAA
# GCGCGTACGTG -> CGCGTACGTGT
# GCGCTGCCTCG -> CGCTGCCTCGG
# GCGGACAAACA -> CGGACAAACAT
# GCGGACGTATT -> CGGACGTATTA
# GCGGCAATCGG -> CGGCAATCGGT
# GCGGCTCACCT -> CGGCTCACCTG
# GCGGGCCAGAC -> CGGGCCAGACT
# GCGGTCTCCCG -> CGGTCTCCCGA
# GCGGTCTGACG -> CGGTCTGACGC
# GCGGTTCGCTC -> CGGTTCGCTCT
# GCGGTTTTCCA -> CGGTTTTCCAG
# GCGTACCCGCT -> CGTACCCGCTC
# GCGTACGTGTT -> CGTACGTGTTA
# GCGTCATACTT -> CGTCATACTTC
# GCGTCGTTGCA -> CGTCGTTGCAC
# GCGTGGCAGTA -> CGTGGCAGTAT
# GCGTGTTCTTG -> CGTGTTCTTGG
# GCGTTTCCTCA -> CGTTTCCTCAC
# GCTAGACCCTG -> CTAGACCCTGG
# GCTAGTCCCCT -> CTAGTCCCCTA
# GCTATAGGCGT -> CTATAGGCGTT
# GCTATTGAGAG -> CTATTGAGAGC
# GCTCAACCGGG -> CTCAACCGGGT
# GCTCACCCGTA -> CTCACCCGTAA
# GCTCACCTGCG -> CTCACCTGCGT
# GCTCACTCGGC -> CTCACTCGGCC
# GCTCAGAGTCG -> CTCAGAGTCGG
# GCTCAGCAACA -> CTCAGCAACAG
# GCTCGGTCTCA -> CTCGGTCTCAG
# GCTCTCCACCC -> CTCTCCACCCT
# GCTCTTATAGT -> CTCTTATAGTC
# GCTGACCCGAG -> CTGACCCGAGC
# GCTGCCCCCTT -> CTGCCCCCTTA
# GCTGCCTCGGG -> CTGCCTCGGGA
# GCTGCGGACGT -> CTGCGGACGTA
# GCTGCGGTTCG -> CTGCGGTTCGC
# GCTGCGTCGTT -> CTGCGTCGTTG
# GCTGGACTAGT -> CTGGACTAGTT
# GCTGGGTACAC -> CTGGGTACACT
# GCTGGTGTCAG -> CTGGTGTCAGT
# GCTGTCTCTCC -> CTGTCTCTCCA
# GCTTACGACAC -> CTTACGACACG
# GCTTCCACTCC -> CTTCCACTCCT
# GCTTCTTGATC -> CTTCTTGATCG
# GCTTTTCGGAC -> CTTTTCGGACT
# GGAAACCCTTC -> GAAACCCTTCC
# GGAAATACGAC -> GAAATACGACT
# GGAACCATCCA -> GAACCATCCAA
# GGAACGAGACA -> GAACGAGACAA
# GGAACTAGGAC -> GAACTAGGACG
# GGAACTCAGCA -> GAACTCAGCAC
# GGAAGGTAGGA -> GAAGGTAGGAA
# GGAAGTACCAT -> GAAGTACCATG
# GGAATCAGGAA -> GAATCAGGAAC
# GGAATTAGGTG -> GAATTAGGTGT
# GGACAAACATA -> GACAAACATAA
# GGACAACAGAT -> GACAACAGATA
# GGACAATGCTG -> GACAATGCTGG
# GGACATGGAAA -> GACATGGAAAC
# GGACCACACAT -> GACCACACATC
# GGACGACAACT -> GACGACAACTA
# GGACGCGGCAA -> GACGCGGCAAT
# GGACGTATTAC -> GACGTATTACA
# GGACTACAACG -> GACTACAACGC
# GGACTAGTTGG -> GACTAGTTGGC
# GGAGAAGAAGA -> GAGAAGAAGAT
# GGAGACAACTC -> GAGACAACTCG
# GGAGATTCATT -> GAGATTCATTA
# GGAGCATCGCA -> GAGCATCGCAG
# GGAGCTGCGGT -> GAGCTGCGGTT
# GGATACGGAAA -> GATACGGAAAT
# GGATATAGAGA -> GATATAGAGAT
# GGATCATACAC -> GATCATACACC
# GGATCTATCCA -> GATCTATCCAA
# GGATGCCATGA -> GATGCCATGAA
# GGATGGCGCGT -> GATGGCGCGTA
# GGATGTTTTAT -> GATGTTTTATG
# GGATTCGGTGG -> GATTCGGTGGT
# GGATTGAGTGC -> GATTGAGTGCC
# GGATTGTTGTA -> GATTGTTGTAT
# GGCAACCACTT -> GCAACCACTTT
# GGCAACCCATC -> GCAACCCATCG
# GGCAACGTTTT -> GCAACGTTTTC
# GGCAAGTCGAC -> GCAAGTCGACT
# GGCAATCGGTT -> GCAATCGGTTC
# GGCACTCATCT -> GCACTCATCTC
# GGCAGTATACG -> GCAGTATACGG
# GGCATCGGGCA -> GCATCGGGCAA
# GGCATTGGATG -> GCATTGGATGT
# GGCCACAGCCC -> GCCACAGCCCG
# GGCCAGACTGC -> GCCAGACTGCC
# GGCCAGGATTG -> GCCAGGATTGA
# GGCCAGTACAG -> GCCAGTACAGC
# GGCCAGTCTCG -> GCCAGTCTCGT
# GGCCATCTCGG -> GCCATCTCGGT
# GGCCGTGAGAC -> GCCGTGAGACA
# GGCGAAATTGA -> GCGAAATTGAT
# GGCGAAGGCGT -> GCGAAGGCGTA
# GGCGCGAAGAC -> GCGCGAAGACC
# GGCGCGTACGT -> GCGCGTACGTG
# GGCGGTCTGAC -> GCGGTCTGACG
# GGCGTACCCGC -> GCGTACCCGCT
# GGCGTGGCAGT -> GCGTGGCAGTA
# GGCGTTTCCTC -> GCGTTTCCTCA
# GGCTAGTCCCC -> GCTAGTCCCCT
# GGCTCACCCGT -> GCTCACCCGTA
# GGCTCACCTGC -> GCTCACCTGCG
# GGCTCGGTCTC -> GCTCGGTCTCA
# GGCTCTCCACC -> GCTCTCCACCC
# GGCTGTCTCTC -> GCTGTCTCTCC
# GGGAACCATCC -> GGAACCATCCA
# GGGAATCAGGA -> GGAATCAGGAA
# GGGACCACACA -> GGACCACACAT
# GGGAGATTCAT -> GGAGATTCATT
# GGGATGCCATG -> GGATGCCATGA
# GGGATTGTTGT -> GGATTGTTGTA
# GGGCAACGTTT -> GGCAACGTTTT
# GGGCATCGGGC -> GGCATCGGGCA
# GGGCATTGGAT -> GGCATTGGATG
# GGGCCAGACTG -> GGCCAGACTGC
# GGGCGAAATTG -> GGCGAAATTGA
# GGGCGCGAAGA -> GGCGCGAAGAC
# GGGCTAGTCCC -> GGCTAGTCCCC
# GGGCTCACCCG -> GGCTCACCCGT
# GGGGATTGTTG -> GGGATTGTTGT
# GGGGCTAGTCC -> GGGCTAGTCCC
# GGGGGATTGTT -> GGGGATTGTTG
# GGGGTTACCAC -> GGGTTACCACC
# GGGGTTTCGGG -> GGGTTTCGGGA
# GGGTACACTGG -> GGTACACTGGA
# GGGTATTTGCT -> GGTATTTGCTA
# GGGTCTCTCGG -> GGTCTCTCGGG
# GGGTGAGGGCG -> GGTGAGGGCGC
# GGGTTACCACC -> GGTTACCACCG
# GGGTTTCGGGA -> GGTTTCGGGAC
# GGTAAAGGGAA -> GTAAAGGGAAT
# GGTAATCGTTG -> GTAATCGTTGA
# GGTACACTGGA -> GTACACTGGAG
# GGTACCTGTAC -> GTACCTGTACA
# GGTAGATCGCT -> GTAGATCGCTT
# GGTAGGAATTA -> GTAGGAATTAG
# GGTATCCAGCA -> GTATCCAGCAT
# GGTATTTGCTA -> GTATTTGCTAT
# GGTCCCTAACT -> GTCCCTAACTG
# GGTCCTTGCGC -> GTCCTTGCGCT
# GGTCGCTGCGT -> GTCGCTGCGTC
# GGTCTCAGGGC -> GTCTCAGGGCA
# GGTCTCCCGAT -> GTCTCCCGATG
# GGTCTCTCGGG -> GTCTCTCGGGT
# GGTCTGACGCT -> GTCTGACGCTT
# GGTGAGGGCGC -> GTGAGGGCGCG
# GGTGATGGGCG -> GTGATGGGCGA
# GGTGCCAGAAA -> GTGCCAGAAAG
# GGTGCGCGCAG -> GTGCGCGCAGT
# GGTGGAAGTAC -> GTGGAAGTACC
# GGTGGTTATTA -> GTGGTTATTAG
# GGTGTCAGTCC -> GTGTCAGTCCT
# GGTGTCTTTGA -> GTGTCTTTGAG
# GGTTAATACTC -> GTTAATACTCG
# GGTTACCACCG -> GTTACCACCGA
# GGTTATTAGAC -> GTTATTAGACT
# GGTTCGCTCTT -> GTTCGCTCTTA
# GGTTCTGTCAA -> GTTCTGTCAAC
# GGTTGAAACGC -> GTTGAAACGCC
# GGTTGAACCAT -> GTTGAACCATA
# GGTTGCCTAGC -> GTTGCCTAGCC
# GGTTTACAGAG -> GTTTACAGAGA
# GGTTTCGGGAC -> GTTTCGGGACC
# GGTTTTCCAGT -> GTTTTCCAGTC
# GTAAAGGGAAT -> TAAAGGGAATC
# GTAAATTTTTG -> TAAATTTTTGG
# GTAACTTCCTT -> TAACTTCCTTT
# GTAATCGTTGA -> TAATCGTTGAA
# GTAATCTGGGT -> TAATCTGGGTA
# GTAATTCGTTG -> TAATTCGTTGA
# GTACAATGTCC -> TACAATGTCCG
# GTACACCTAGC -> TACACCTAGCA
# GTACACTGGAG -> TACACTGGAGA
# GTACAGCTTCT -> TACAGCTTCTT
# GTACCATGAAC -> TACCATGAACC
# GTACCCGCTCA -> TACCCGCTCAC
# GTACCTGTACA -> TACCTGTACAA
# GTACGTGTTAG -> TACGTGTTAGC
# GTAGATCGCTT -> TAGATCGCTTA
# GTAGCACATTG -> TAGCACATTGG
# GTAGGAACGAG -> TAGGAACGAGA
# GTAGGAATTAG -> TAGGAATTAGG
# GTAGGCTCGGT -> TAGGCTCGGTC
# GTAGTCTTAAA -> TAGTCTTAAAT
# GTATACGGTGA -> TATACGGTGAT
# GTATAGATGGG -> TATAGATGGGA
# GTATCCAGCAT -> TATCCAGCATT
# GTATCGCGACG -> TATCGCGACGG
# GTATGTAAATT -> TATGTAAATTT
# GTATTACATGG -> TATTACATGGC
# GTATTTGCTAT -> TATTTGCTATT
# GTCAACCGTTA -> TCAACCGTTAA
# GTCAACTGGTA -> TCAACTGGTAG
# GTCAGTCCTGC -> TCAGTCCTGCT
# GTCATACTTCT -> TCATACTTCTC
# GTCATTGTGTA -> TCATTGTGTAC
# GTCATTTGGCC -> TCATTTGGCCA
# GTCCACCAACC -> TCCACCAACCA
# GTCCCAAGCAC -> TCCCAAGCACG
# GTCCCCTAGAC -> TCCCCTAGACG
# GTCCCTAACTG -> TCCCTAACTGG
# GTCCGCTTCCA -> TCCGCTTCCAC
# GTCCTAGGCCA -> TCCTAGGCCAT
# GTCCTGCTCAG -> TCCTGCTCAGA
# GTCCTTGCGCT -> TCCTTGCGCTG
# GTCCTTTACGA -> TCCTTTACGAT
# GTCGAACTATC -> TCGAACTATCT
# GTCGAAGCGGT -> TCGAAGCGGTT
# GTCGACTCTGT -> TCGACTCTGTG
# GTCGCTGCGTC -> TCGCTGCGTCG
# GTCGGCAAGTC -> TCGGCAAGTCG
# GTCGTCCACCA -> TCGTCCACCAA
# GTCGTTGCACA -> TCGTTGCACAA
# GTCTAGTCTCA -> TCTAGTCTCAC
# GTCTCACTATG -> TCTCACTATGA
# GTCTCAGGGCA -> TCTCAGGGCAT
# GTCTCATATTG -> TCTCATATTGC
# GTCTCCCGATG -> TCTCCCGATGG
# GTCTCGTCCTA -> TCTCGTCCTAG
# GTCTCTCCAGT -> TCTCTCCAGTG
# GTCTCTCGGGT -> TCTCTCGGGTG
# GTCTGACGCTT -> TCTGACGCTTT
# GTCTTAAATCC -> TCTTAAATCCG
# GTCTTACAAAG -> TCTTACAAAGG
# GTCTTAGAACG -> TCTTAGAACGA
# GTCTTTGAGTT -> TCTTTGAGTTG
# GTGACGTCGAA -> TGACGTCGAAC
# GTGAGAATTAC -> TGAGAATTACC
# GTGAGACATAC -> TGAGACATACT
# GTGAGGGCGCG -> TGAGGGCGCGA
# GTGATGCCCTC -> TGATGCCCTCC
# GTGATGGGCGA -> TGATGGGCGAA
# GTGCAGCTGAC -> TGCAGCTGACC
# GTGCATTGACC -> TGCATTGACCG
# GTGCCAGAAAG -> TGCCAGAAAGA
# GTGCCGCCCGG -> TGCCGCCCGGG
# GTGCGCGCAGT -> TGCGCGCAGTC
# GTGGAAGTACC -> TGGAAGTACCA
# GTGGACGCGGC -> TGGACGCGGCA
# GTGGCAGTATA -> TGGCAGTATAC
# GTGGTGCGCGC -> TGGTGCGCGCA
# GTGGTTATTAG -> TGGTTATTAGA
# GTGTACACCTA -> TGTACACCTAG
# GTGTCAGTCCT -> TGTCAGTCCTG
# GTGTCTCATAT -> TGTCTCATATT
# GTGTCTTTGAG -> TGTCTTTGAGT
# GTGTTAGCAGT -> TGTTAGCAGTC
# GTGTTCTTGGA -> TGTTCTTGGAT
# GTTAATACTCG -> TTAATACTCGG
# GTTAATGCTGG -> TTAATGCTGGT
# GTTACCACCGA -> TTACCACCGAT
# GTTACGGTTGC -> TTACGGTTGCC
# GTTACTGACAA -> TTACTGACAAA
# GTTAGACCGAG -> TTAGACCGAGG
# GTTAGCAGTCG -> TTAGCAGTCGT
# GTTAGCAGTCT -> TTAGCAGTCTT
# GTTATTAGACT -> TTATTAGACTT
# GTTCGCTCTTA -> TTCGCTCTTAT
# GTTCTGTCAAC -> TTCTGTCAACC
# GTTCTTGGATG -> TTCTTGGATGG
# GTTGAAACGCC -> TTGAAACGCCC
# GTTGAACCATA -> TTGAACCATAC
# GTTGAACTTGT -> TTGAACTTGTG
# GTTGACCACTA -> TTGACCACTAC
# GTTGACTTGTT -> TTGACTTGTTT
# GTTGAGATGTA -> TTGAGATGTAA
# GTTGCACAAAG -> TTGCACAAAGG
# GTTGCCTAGCC -> TTGCCTAGCCT
# GTTGGATCTAT -> TTGGATCTATC
# GTTGGCTGTCT -> TTGGCTGTCTC
# GTTGTAGGCTC -> TTGTAGGCTCG
# GTTGTATAGAT -> TTGTATAGATG
# GTTTACAGAGA -> TTTACAGAGAC
# GTTTCCTCACT -> TTTCCTCACTA
# GTTTCGGGACC -> TTTCGGGACCA
# GTTTGTTAGAC -> TTTGTTAGACC
# GTTTTATGCTC -> TTTTATGCTCA
# GTTTTCCAGTC -> TTTTCCAGTCA
# GTTTTCTACGA -> TTTTCTACGAC
# TAAAAGATCAG -> AAAAGATCAGG
# TAAAAGGCGAA -> AAAAGGCGAAG
# TAAACCGTGCA -> AAACCGTGCAT
# TAAAGGATCAT -> AAAGGATCATA
# TAAAGGGAATC -> AAAGGGAATCA
# TAAATCCGGTA -> AAATCCGGTAC
# TAAATTTTTGG -> AAATTTTTGGA
# TAACACGCGGA -> AACACGCGGAC
# TAACTGAATAC -> AACTGAATACC
# TAACTGGCCAG -> AACTGGCCAGG
# TAACTTCCTTT -> AACTTCCTTTA
# TAAGAAAGGAG -> AAGAAAGGAGA
# TAAGATTCCCG -> AAGATTCCCGC
# TAATACTCGGA -> AATACTCGGAT
# TAATCGTTGAA -> AATCGTTGAAC
# TAATCTGGGTA -> AATCTGGGTAT
# TAATGCTGGTG -> AATGCTGGTGT
# TAATGTTAGCA -> AATGTTAGCAG
# TAATTCGTTGA -> AATTCGTTGAC
# TAATTGCACTT -> AATTGCACTTC
# TACAAAGGATT -> ACAAAGGATTC
# TACAAATTAAT -> ACAAATTAATG
# TACAACGCCAT -> ACAACGCCATT
# TACAATGTCCG -> ACAATGTCCGC
# TACACCTACCA -> ACACCTACCAA
# TACACCTAGCA -> ACACCTAGCAT
# TACACTGGAGA -> ACACTGGAGAA
# TACAGAGACCC -> ACAGAGACCCG
# TACAGCTTCTT -> ACAGCTTCTTG
# TACATGGCACT -> ACATGGCACTC
# TACCAAATGAC -> ACCAAATGACA
# TACCACCGATG -> ACCACCGATGT
# TACCACGAATT -> ACCACGAATTA
# TACCATGAACC -> ACCATGAACCT
# TACCCGCTCAC -> ACCCGCTCACT
# TACCGCCGTAG -> ACCGCCGTAGT
# TACCGGTCGCT -> ACCGGTCGCTG
# TACCTGTACAA -> ACCTGTACAAT
# TACGACACGCC -> ACGACACGCCT
# TACGACATACC -> ACGACATACCA
# TACGACGTCTA -> ACGACGTCTAG
# TACGACTGAAG -> ACGACTGAAGG
# TACGGAAATAC -> ACGGAAATACG
# TACGGTGATGG -> ACGGTGATGGG
# TACGGTGCCAG -> ACGGTGCCAGA
# TACGGTTGAAA -> ACGGTTGAAAC
# TACGGTTGCCT -> ACGGTTGCCTA
# TACGTGTTAGC -> ACGTGTTAGCA
# TACTCCAGCTA -> ACTCCAGCTAG
# TACTCGGATAC -> ACTCGGATACG
# TACTGACAAAA -> ACTGACAAAAT
# TACTTCGAAGT -> ACTTCGAAGTC
# TACTTCTCCTA -> ACTTCTCCTAA
# TAGAACGAACC -> AGAACGAACCC
# TAGAAGCTGGA -> AGAAGCTGGAC
# TAGACCCATCT -> AGACCCATCTA
# TAGACCCTGGC -> AGACCCTGGCA
# TAGACCGAGGT -> AGACCGAGGTT
# TAGACGACGTT -> AGACGACGTTG
# TAGACTTCGGT -> AGACTTCGGTA
# TAGAGATGTAG -> AGAGATGTAGG
# TAGATCGCTTA -> AGATCGCTTAC
# TAGATGGGAGA -> AGATGGGAGAT
# TAGCACATTGG -> AGCACATTGGG
# TAGCAGTATGT -> AGCAGTATGTA
# TAGCAGTCGTC -> AGCAGTCGTCC
# TAGCAGTCTTA -> AGCAGTCTTAG
# TAGCATAGCTG -> AGCATAGCTGC
# TAGCCTCTTAT -> AGCCTCTTATG
# TAGCTGCGGAC -> AGCTGCGGACG
# TAGGAACGAGA -> AGGAACGAGAC
# TAGGAATTAGG -> AGGAATTAGGT
# TAGGACATGGA -> AGGACATGGAA
# TAGGACGACAA -> AGGACGACAAC
# TAGGCCAGTAC -> AGGCCAGTACA
# TAGGCCATCTC -> AGGCCATCTCG
# TAGGCGTTTCC -> AGGCGTTTCCT
# TAGGCTCGGTC -> AGGCTCGGTCT
# TAGGTGTCTTT -> AGGTGTCTTTG
# TAGTCCCCTAG -> AGTCCCCTAGA
# TAGTCTCACTA -> AGTCTCACTAT
# TAGTCTTAAAT -> AGTCTTAAATC
# TAGTCTTACAA -> AGTCTTACAAA
# TAGTTGGATCT -> AGTTGGATCTA
# TAGTTGGCTGT -> AGTTGGCTGTC
# TATAAAGGATC -> ATAAAGGATCA
# TATACGGTGAT -> ATACGGTGATG
# TATAGAGATGT -> ATAGAGATGTA
# TATAGATGGGA -> ATAGATGGGAG
# TATAGGCGTTT -> ATAGGCGTTTC
# TATAGTCTTAC -> ATAGTCTTACA
# TATCAGGACAA -> ATCAGGACAAC
# TATCCAATCTC -> ATCCAATCTCG
# TATCCAGCATT -> ATCCAGCATTC
# TATCCCGTGGT -> ATCCCGTGGTG
# TATCCTTAAAA -> ATCCTTAAAAG
# TATCGCGACGG -> ATCGCGACGGA
# TATCTAATTGC -> ATCTAATTGCA
# TATGATCCTCT -> ATGATCCTCTT
# TATGCATAGTT -> ATGCATAGTTG
# TATGCTCAGCA -> ATGCTCAGCAA
# TATGGACAATG -> ATGGACAATGC
# TATGTAAATTT -> ATGTAAATTTT
# TATGTGGACGC -> ATGTGGACGCG
# TATTACATGGC -> ATTACATGGCA
# TATTAGACCCA -> ATTAGACCCAT
# TATTAGACTTC -> ATTAGACTTCG
# TATTGAGAGCT -> ATTGAGAGCTC
# TATTGCCTCAA -> ATTGCCTCAAA
# TATTTGCTATT -> ATTTGCTATTG
# TCAAATCCAAT -> CAAATCCAATC
# TCAACCGGGTC -> CAACCGGGTCT
# TCAACCGTTAA -> CAACCGTTAAT
# TCAACTGGTAG -> CAACTGGTAGA
# TCACAGCGGGC -> CACAGCGGGCC
# TCACCCGTAAT -> CACCCGTAATC
# TCACCGCACGG -> CACCGCACGGT
# TCACCTGCGTG -> CACCTGCGTGT
# TCACTAACTGA -> CACTAACTGAA
# TCACTATGATC -> CACTATGATCC
# TCACTCGGCCG -> CACTCGGCCGT
# TCAGAGTCGGC -> CAGAGTCGGCA
# TCAGCAACAGT -> CAGCAACAGTT
# TCAGCACGCCG -> CAGCACGCCGG
# TCAGGAACTAG -> CAGGAACTAGG
# TCAGGACAACA -> CAGGACAACAG
# TCAGGGCATCG -> CAGGGCATCGG
# TCAGGGCTCAC -> CAGGGCTCACC
# TCAGTCCTGCT -> CAGTCCTGCTC
# TCATACACCTA -> CATACACCTAC
# TCATACTTCTC -> CATACTTCTCC
# TCATATTGCCT -> CATATTGCCTC
# TCATCCTATGG -> CATCCTATGGA
# TCATCTCCAGA -> CATCTCCAGAT
# TCATTAGCAGT -> CATTAGCAGTA
# TCATTGTGTAC -> CATTGTGTACA
# TCATTTGGCCA -> CATTTGGCCAC
# TCCAACACCGA -> CCAACACCGAT
# TCCAATCCTCC -> CCAATCCTCCT
# TCCAATCTCGG -> CCAATCTCGGC
# TCCACCAACCA -> CCACCAACCAC
# TCCACCCTTTC -> CCACCCTTTCC
# TCCACTCCTGC -> CCACTCCTGCG
# TCCAGAGGCGG -> CCAGAGGCGGT
# TCCAGATTTCG -> CCAGATTTCGT
# TCCAGCATTCC -> CCAGCATTCCT
# TCCAGCTAGAC -> CCAGCTAGACC
# TCCAGTCATTT -> CCAGTCATTTG
# TCCAGTGCAGC -> CCAGTGCAGCT
# TCCATGCATGA -> CCATGCATGAT
# TCCCAAGCACG -> CCCAAGCACGA
# TCCCCTAGACG -> CCCCTAGACGA
# TCCCGATGGTG -> CCCGATGGTGG
# TCCCGCGGCTC -> CCCGCGGCTCA
# TCCCGTGGTGC -> CCCGTGGTGCG
# TCCCTAACTGG -> CCCTAACTGGC
# TCCCTAAGATT -> CCCTAAGATTC
# TCCCTCCGCAC -> CCCTCCGCACC
# TCCGAAGCAAT -> CCGAAGCAATC
# TCCGCACCGGT -> CCGCACCGGTT
# TCCGCTTCCAC -> CCGCTTCCACT
# TCCGGAAGGTA -> CCGGAAGGTAG
# TCCGGTACCTG -> CCGGTACCTGT
# TCCTAAGAAAG -> CCTAAGAAAGG
# TCCTACGACGT -> CCTACGACGTC
# TCCTAGGCCAT -> CCTAGGCCATC
# TCCTATGCATA -> CCTATGCATAG
# TCCTATGGACA -> CCTATGGACAA
# TCCTCACTAAC -> CCTCACTAACT
# TCCTCCTTTTT -> CCTCCTTTTTT
# TCCTCTTGGGA -> CCTCTTGGGAA
# TCCTGCGTCAT -> CCTGCGTCATA
# TCCTGCTCAGA -> CCTGCTCAGAG
# TCCTTAAAAGA -> CCTTAAAAGAT
# TCCTTGCGCTG -> CCTTGCGCTGC
# TCCTTTAAAAG -> CCTTTAAAAGG
# TCCTTTTTTAA -> CCTTTTTTAAC
# TCGAACTATCT -> CGAACTATCTA
# TCGAAGCGGTT -> CGAAGCGGTTT
# TCGAAGTCCTT -> CGAAGTCCTTT
# TCGACGCTGCC -> CGACGCTGCCC
# TCGACTCTGTG -> CGACTCTGTGA
# TCGCAGAGCGG -> CGCAGAGCGGT
# TCGCGACGGAT -> CGCGACGGATA
# TCGCTCTTATA -> CGCTCTTATAG
# TCGCTGCGTCG -> CGCTGCGTCGT
# TCGCTTACGAC -> CGCTTACGACA
# TCGGACTACAA -> CGGACTACAAC
# TCGGATACGGA -> CGGATACGGAA
# TCGGCAACCAC -> CGGCAACCACT
# TCGGCAAGTCG -> CGGCAAGTCGA
# TCGGCCAGTCT -> CGGCCAGTCTC
# TCGGCCGTGAG -> CGGCCGTGAGA
# TCGGCTCTCCA -> CGGCTCTCCAC
# TCGGGACCACA -> CGGGACCACAC
# TCGGGATGCCA -> CGGGATGCCAT
# TCGGGCAACGT -> CGGGCAACGTT
# TCGGGTGAGGG -> CGGGTGAGGGC
# TCGGTAAAGGG -> CGGTAAAGGGA
# TCGGTATCCAG -> CGGTATCCAGC
# TCGGTCTCAGG -> CGGTCTCAGGG
# TCGGTGGTTAT -> CGGTGGTTATT
# TCGGTTCTGTC -> CGGTTCTGTCA
# TCGTCCACCAA -> CGTCCACCAAC
# TCGTCCTAGGC -> CGTCCTAGGCC
# TCGTGTCTCAT -> CGTGTCTCATA
# TCGTTGAACTT -> CGTTGAACTTG
# TCGTTGACTTG -> CGTTGACTTGT
# TCGTTGCACAA -> CGTTGCACAAA
# TCGTTGTAGGC -> CGTTGTAGGCT
# TCTAATTGCAC -> CTAATTGCACT
# TCTACGACATA -> CTACGACATAC
# TCTAGTCTCAC -> CTAGTCTCACT
# TCTATCCAATC -> CTATCCAATCT
# TCTATCCTTAA -> CTATCCTTAAA
# TCTCACTATGA -> CTCACTATGAT
# TCTCAGGGCAT -> CTCAGGGCATC
# TCTCATATTGC -> CTCATATTGCC
# TCTCCACCCTT -> CTCCACCCTTT
# TCTCCAGATTT -> CTCCAGATTTC
# TCTCCAGTGCA -> CTCCAGTGCAG
# TCTCCCGATGG -> CTCCCGATGGT
# TCTCCTAAGAA -> CTCCTAAGAAA
# TCTCGGCCAGT -> CTCGGCCAGTC
# TCTCGGGTGAG -> CTCGGGTGAGG
# TCTCGGTAAAG -> CTCGGTAAAGG
# TCTCGTCCTAG -> CTCGTCCTAGG
# TCTCTCCAGTG -> CTCTCCAGTGC
# TCTCTCGGGTG -> CTCTCGGGTGA
# TCTGACGCTTT -> CTGACGCTTTT
# TCTGGGGTTAC -> CTGGGGTTACC
# TCTGGGTATTT -> CTGGGTATTTG
# TCTGTCAACCG -> CTGTCAACCGT
# TCTGTGACGTC -> CTGTGACGTCG
# TCTTAAATCCG -> CTTAAATCCGG
# TCTTACAAAGG -> CTTACAAAGGA
# TCTTAGAACGA -> CTTAGAACGAA
# TCTTATAGTCT -> CTTATAGTCTT
# TCTTATGTGGA -> CTTATGTGGAC
# TCTTGATCGTG -> CTTGATCGTGT
# TCTTGGATGGC -> CTTGGATGGCG
# TCTTGGGAACC -> CTTGGGAACCA
# TCTTTGAGTTG -> CTTTGAGTTGA
# TCTTTGTTACT -> CTTTGTTACTG
# TGAAAACACAA -> GAAAACACAAC
# TGAAACGCCCG -> GAAACGCCCGA
# TGAACCATACA -> GAACCATACAA
# TGAACCTATTA -> GAACCTATTAG
# TGAACTTGTGA -> GAACTTGTGAG
# TGAAGGAGCTG -> GAAGGAGCTGC
# TGAATACCGCC -> GAATACCGCCG
# TGACAAAATTT -> GACAAAATTTT
# TGACACAGCAA -> GACACAGCAAG
# TGACCACTACT -> GACCACTACTC
# TGACCCGAGCT -> GACCCGAGCTA
# TGACCGTAACT -> GACCGTAACTT
# TGACGCTTTTC -> GACGCTTTTCG
# TGACGTCGAAC -> GACGTCGAACT
# TGACTTGTTTG -> GACTTGTTTGT
# TGAGAATTACC -> GAGAATTACCG
# TGAGACATACT -> GAGACATACTT
# TGAGAGACTCT -> GAGAGACTCTT
# TGAGAGCTCAA -> GAGAGCTCAAC
# TGAGATGTAAT -> GAGATGTAATT
# TGAGGGCGCGA -> GAGGGCGCGAA
# TGAGTGCCGCC -> GAGTGCCGCCC
# TGAGTTGACCA -> GAGTTGACCAC
# TGATAGGACAT -> GATAGGACATG
# TGATCCGAAGC -> GATCCGAAGCA
# TGATCCTCTTG -> GATCCTCTTGG
# TGATCGTGTCT -> GATCGTGTCTC
# TGATGCCCTCC -> GATGCCCTCCT
# TGATGGGCGAA -> GATGGGCGAAA
# TGATGGTTAAT -> GATGGTTAATA
# TGCAACAGGGG -> GCAACAGGGGT
# TGCACAAAGGT -> GCACAAAGGTC
# TGCACTTCACC -> GCACTTCACCG
# TGCAGCTGACC -> GCAGCTGACCC
# TGCATAGTTGG -> GCATAGTTGGA
# TGCATGATGGT -> GCATGATGGTT
# TGCATTGACCG -> GCATTGACCGT
# TGCCAAGAAGG -> GCCAAGAAGGG
# TGCCAGAAAGA -> GCCAGAAAGAG
# TGCCATGAAAA -> GCCATGAAAAC
# TGCCCCCTTAC -> GCCCCCTTACG
# TGCCCGAGTCA -> GCCCGAGTCAT
# TGCCCTCCTAT -> GCCCTCCTATG
# TGCCGCCCGGG -> GCCGCCCGGGG
# TGCCTAGCCTC -> GCCTAGCCTCT
# TGCCTCAAATC -> GCCTCAAATCC
# TGCCTCGGGAT -> GCCTCGGGATG
# TGCGCGCAGTC -> GCGCGCAGTCA
# TGCGCTGCCTC -> GCGCTGCCTCG
# TGCGGACGTAT -> GCGGACGTATT
# TGCGGTTCGCT -> GCGGTTCGCTC
# TGCGTCATACT -> GCGTCATACTT
# TGCGTCGTTGC -> GCGTCGTTGCA
# TGCGTGTTCTT -> GCGTGTTCTTG
# TGCTATTGAGA -> GCTATTGAGAG
# TGCTCAGAGTC -> GCTCAGAGTCG
# TGCTCAGCAAC -> GCTCAGCAACA
# TGCTGGGTACA -> GCTGGGTACAC
# TGCTGGTGTCA -> GCTGGTGTCAG
# TGGAAACCCTT -> GGAAACCCTTC
# TGGAAGTACCA -> GGAAGTACCAT
# TGGACAATGCT -> GGACAATGCTG
# TGGACGCGGCA -> GGACGCGGCAA
# TGGACTAGTTG -> GGACTAGTTGG
# TGGAGAAGAAG -> GGAGAAGAAGA
# TGGAGCATCGC -> GGAGCATCGCA
# TGGATCTATCC -> GGATCTATCCA
# TGGATGGCGCG -> GGATGGCGCGT
# TGGATGTTTTA -> GGATGTTTTAT
# TGGCAACCCAT -> GGCAACCCATC
# TGGCACTCATC -> GGCACTCATCT
# TGGCAGTATAC -> GGCAGTATACG
# TGGCCACAGCC -> GGCCACAGCCC
# TGGCCAGGATT -> GGCCAGGATTG
# TGGCGCGTACG -> GGCGCGTACGT
# TGGCTGTCTCT -> GGCTGTCTCTC
# TGGGAACCATC -> GGGAACCATCC
# TGGGAGATTCA -> GGGAGATTCAT
# TGGGCATTGGA -> GGGCATTGGAT
# TGGGCGAAATT -> GGGCGAAATTG
# TGGGGTTACCA -> GGGGTTACCAC
# TGGGTACACTG -> GGGTACACTGG
# TGGGTATTTGC -> GGGTATTTGCT
# TGGTAGATCGC -> GGTAGATCGCT
# TGGTCCTTGCG -> GGTCCTTGCGC
# TGGTGCGCGCA -> GGTGCGCGCAG
# TGGTGGAAGTA -> GGTGGAAGTAC
# TGGTGTCAGTC -> GGTGTCAGTCC
# TGGTTAATACT -> GGTTAATACTC
# TGGTTATTAGA -> GGTTATTAGAC
# TGTAAATTTTT -> GTAAATTTTTG
# TGTAATTCGTT -> GTAATTCGTTG
# TGTACAATGTC -> GTACAATGTCC
# TGTACACCTAG -> GTACACCTAGC
# TGTAGGAACGA -> GTAGGAACGAG
# TGTAGGCTCGG -> GTAGGCTCGGT
# TGTATAGATGG -> GTATAGATGGG
# TGTATCGCGAC -> GTATCGCGACG
# TGTCAACCGTT -> GTCAACCGTTA
# TGTCAGTCCTG -> GTCAGTCCTGC
# TGTCCGCTTCC -> GTCCGCTTCCA
# TGTCGAAGCGG -> GTCGAAGCGGT
# TGTCTCATATT -> GTCTCATATTG
# TGTCTCTCCAG -> GTCTCTCCAGT
# TGTCTTTGAGT -> GTCTTTGAGTT
# TGTGACGTCGA -> GTGACGTCGAA
# TGTGAGAATTA -> GTGAGAATTAC
# TGTGGACGCGG -> GTGGACGCGGC
# TGTGTACACCT -> GTGTACACCTA
# TGTTACTGACA -> GTTACTGACAA
# TGTTAGACCGA -> GTTAGACCGAG
# TGTTAGCAGTC -> GTTAGCAGTCG, GTTAGCAGTCT
# TGTTCTTGGAT -> GTTCTTGGATG
# TGTTGTATAGA -> GTTGTATAGAT
# TGTTTGTTAGA -> GTTTGTTAGAC
# TGTTTTATGCT -> GTTTTATGCTC
# TTAAAAGATCA -> TAAAAGATCAG
# TTAAAAGGCGA -> TAAAAGGCGAA
# TTAAATCCGGT -> TAAATCCGGTA
# TTAACACGCGG -> TAACACGCGGA
# TTAATACTCGG -> TAATACTCGGA
# TTAATGCTGGT -> TAATGCTGGTG
# TTAATGTTAGC -> TAATGTTAGCA
# TTACAAAGGAT -> TACAAAGGATT
# TTACAGAGACC -> TACAGAGACCC
# TTACATGGCAC -> TACATGGCACT
# TTACCACCGAT -> TACCACCGATG
# TTACCGGTCGC -> TACCGGTCGCT
# TTACGACACGC -> TACGACACGCC
# TTACGGTGCCA -> TACGGTGCCAG
# TTACGGTTGCC -> TACGGTTGCCT
# TTACTGACAAA -> TACTGACAAAA
# TTAGAACGAAC -> TAGAACGAACC
# TTAGACCCATC -> TAGACCCATCT
# TTAGACCGAGG -> TAGACCGAGGT
# TTAGACTTCGG -> TAGACTTCGGT
# TTAGCAGTATG -> TAGCAGTATGT
# TTAGCAGTCGT -> TAGCAGTCGTC
# TTAGCAGTCTT -> TAGCAGTCTTA
# TTAGGTGTCTT -> TAGGTGTCTTT
# TTATAGTCTTA -> TATAGTCTTAC
# TTATCAGGACA -> TATCAGGACAA
# TTATGCTCAGC -> TATGCTCAGCA
# TTATGTGGACG -> TATGTGGACGC
# TTATTAGACTT -> TATTAGACTTC
# TTCACCGCACG -> TCACCGCACGG
# TTCATTAGCAG -> TCATTAGCAGT
# TTCCACTCCTG -> TCCACTCCTGC
# TTCCAGAGGCG -> TCCAGAGGCGG
# TTCCAGTCATT -> TCCAGTCATTT
# TTCCATGCATG -> TCCATGCATGA
# TTCCCGCGGCT -> TCCCGCGGCTC
# TTCCCTAAGAT -> TCCCTAAGATT
# TTCCTACGACG -> TCCTACGACGT
# TTCCTCACTAA -> TCCTCACTAAC
# TTCCTTTAAAA -> TCCTTTAAAAG
# TTCGAAGTCCT -> TCGAAGTCCTT
# TTCGCTCTTAT -> TCGCTCTTATA
# TTCGGACTACA -> TCGGACTACAA
# TTCGGGACCAC -> TCGGGACCACA
# TTCGGTATCCA -> TCGGTATCCAG
# TTCGGTGGTTA -> TCGGTGGTTAT
# TTCGTTGACTT -> TCGTTGACTTG
# TTCGTTGTAGG -> TCGTTGTAGGC
# TTCTACGACAT -> TCTACGACATA
# TTCTCCTAAGA -> TCTCCTAAGAA
# TTCTGGGGTTA -> TCTGGGGTTAC
# TTCTGTCAACC -> TCTGTCAACCG
# TTCTTGATCGT -> TCTTGATCGTG
# TTCTTGGATGG -> TCTTGGATGGC
# TTGAAACGCCC -> TGAAACGCCCG
# TTGAACCATAC -> TGAACCATACA
# TTGAACTTGTG -> TGAACTTGTGA
# TTGACCACTAC -> TGACCACTACT
# TTGACCGTAAC -> TGACCGTAACT
# TTGACTTGTTT -> TGACTTGTTTG
# TTGAGAGACTC -> TGAGAGACTCT
# TTGAGAGCTCA -> TGAGAGCTCAA
# TTGAGATGTAA -> TGAGATGTAAT
# TTGAGTGCCGC -> TGAGTGCCGCC
# TTGAGTTGACC -> TGAGTTGACCA
# TTGATAGGACA -> TGATAGGACAT
# TTGATCCGAAG -> TGATCCGAAGC
# TTGATCGTGTC -> TGATCGTGTCT
# TTGCAACAGGG -> TGCAACAGGGG
# TTGCACAAAGG -> TGCACAAAGGT
# TTGCACTTCAC -> TGCACTTCACC
# TTGCCCGAGTC -> TGCCCGAGTCA
# TTGCCTAGCCT -> TGCCTAGCCTC
# TTGCCTCAAAT -> TGCCTCAAATC
# TTGCGCTGCCT -> TGCGCTGCCTC
# TTGCTATTGAG -> TGCTATTGAGA
# TTGGAGCATCG -> TGGAGCATCGC
# TTGGATCTATC -> TGGATCTATCC
# TTGGATGGCGC -> TGGATGGCGCG
# TTGGATGTTTT -> TGGATGTTTTA
# TTGGCCACAGC -> TGGCCACAGCC
# TTGGCTGTCTC -> TGGCTGTCTCT
# TTGGGAACCAT -> TGGGAACCATC
# TTGGGCATTGG -> TGGGCATTGGA
# TTGTAGGCTCG -> TGTAGGCTCGG
# TTGTATAGATG -> TGTATAGATGG
# TTGTGAGAATT -> TGTGAGAATTA
# TTGTGTACACC -> TGTGTACACCT
# TTGTTACTGAC -> TGTTACTGACA
# TTGTTAGACCG -> TGTTAGACCGA
# TTGTTGTATAG -> TGTTGTATAGA
# TTGTTTGTTAG -> TGTTTGTTAGA
# TTTAAAAGGCG -> TTAAAAGGCGA
# TTTAACACGCG -> TTAACACGCGG
# TTTACAGAGAC -> TTACAGAGACC
# TTTATGCTCAG -> TTATGCTCAGC
# TTTCCAGAGGC -> TTCCAGAGGCG
# TTTCCAGTCAT -> TTCCAGTCATT
# TTTCCATGCAT -> TTCCATGCATG
# TTTCCTCACTA -> TTCCTCACTAA
# TTTCGGACTAC -> TTCGGACTACA
# TTTCGGGACCA -> TTCGGGACCAC
# TTTCGTTGTAG -> TTCGTTGTAGG
# TTTCTACGACA -> TTCTACGACAT
# TTTCTGGGGTT -> TTCTGGGGTTA
# TTTGAGTTGAC -> TTGAGTTGACC
# TTTGCAACAGG -> TTGCAACAGGG
# TTTGCCCGAGT -> TTGCCCGAGTC
# TTTGCTATTGA -> TTGCTATTGAG
# TTTGGAGCATC -> TTGGAGCATCG
# TTTGGCCACAG -> TTGGCCACAGC
# TTTGTTACTGA -> TTGTTACTGAC
# TTTGTTAGACC -> TTGTTAGACCG
# TTTTAACACGC -> TTTAACACGCG
# TTTTATGCTCA -> TTTATGCTCAG
# TTTTCCAGTCA -> TTTCCAGTCAT
# TTTTCCATGCA -> TTTCCATGCAT
# TTTTCGGACTA -> TTTCGGACTAC
# TTTTCTACGAC -> TTTCTACGACA
# TTTTGCAACAG -> TTTGCAACAGG
# TTTTGCCCGAG -> TTTGCCCGAGT
# TTTTGGAGCAT -> TTTGGAGCATC
# TTTTTAACACG -> TTTTAACACGC
# TTTTTGCCCGA -> TTTTGCCCGAG
# TTTTTGGAGCA -> TTTTGGAGCAT
# TTTTTTAACAC -> TTTTTAACACG

# %% [markdown]
# __CODE MARKDOWN CELL__
#
# problem11 contains class deBruijn and a main
#
# class deBruijn contains:
#
# def __ __init__ __(self, k, text) -- initializes necessary variables
#
# def __nodes__(self) -- builds the deBruijn dictionary
#
# def __print__(self) -- prints the deBruijn dictionary
#
# __main__() reads from an input file and calls necessary methods

# %% [markdown]
# __INSPECTION MARKDOWN CELL__
#
# Junmo:
# Q8 ~ 12. Well written codes. They are readable and neat. I can easliy follow the codes. No other inspections are needed.
