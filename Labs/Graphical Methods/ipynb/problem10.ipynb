# %%
# C:\Users\wwsch\anaconda3\python.exe
# Name: William Schlough (wschloug)
# Group Members: Junmo, Mikey, Wenyu

# In this chapter, we use the terms prefix and suffix to refer to the first k − 1 nucleotides and last k − 1 nucleotides of a k-mer, respectively.
# Given an arbitrary collection of k-mers Patterns, we form a graph having a node for each k-mer in Patterns and connect k-mers Pattern and Pattern' by a directed edge if Suffix(Pattern) is equal to Prefix(Pattern').
# The resulting graph is called the overlap graph on these k-mers, denoted Overlap(Patterns).

class overlapGraph:
    '''
    contains methods used to form an adjacency list (overlap graph) from a collection of k-mers
    '''

    def __init__(self, kmers):
        '''
        initializes necessary vars
        '''

        self.kmer = kmers
        self.adjacencyList = []

    def suffix(self, pattern):
        '''
        last k − 1 nucleotides of k-mer
        '''

        return pattern[1:len(pattern)] # cut from 2nd element up to last element, not including 1st element (in this case element 0)

    def prefix(self, pattern):
        '''
        first k − 1 nucleotides of k-mer
        '''

        return pattern[:len(pattern) - 1] # cut from start up to but not including last element

    def graph(self):
        '''
        we form a graph having a node for each k-mer in Patterns
        and connect k-mers Pattern and Pattern' by a directed edge if Suffix(Pattern) is equal to Prefix(Pattern')
        '''

        for k1 in self.kmer: # kmer
            for k2 in self.kmer: # kmer'
                if self.suffix(k1) == self.prefix(k2): # if suffix(pattern) == prefix(pattern')
                    self.adjacencyList.append((k1, k2)) # add it to list

    def print(self):
        '''
        calls self.graph to build the adjacency list
        adjacency list is then sorted so that it's in alphabetical order
        adjacency list is then printed as -- (tail -> head), sorted in alphabetical order
        '''

        self.graph()
        self.adjacencyList.sort(key=lambda x: x[0]) # sort adj list in order of descending element 0 (so it starts w/ 'aaaaaaaaaaaaaaaaa')
        for i in self.adjacencyList: # for element in adj list
            print(i[0] + ' -> ' + i[1]) # print contents of adjacency list in the form of an adjacency list (node -> node)



def main():
    '''
    reads from input file and instantiates patterns into class overlapGraph, then calls print() which in turn calls
    graph(), which builds the graph from the given patterns (nodes), and finally prints a sorted list in the
    specified format (tail->head)

    rosalind prompt --
    "Given: A collection Patterns of k-mers."
    "Return: The overlap graph Overlap(Patterns), in the form of an adjacency list."
    '''

    p = []
    inputFile = open('rosalind_ba3c.txt', 'r') # open the input file for reading
    for line in inputFile: # for each line in input file, append it as an element of list 'p' (patterns)
        p.append(line.strip())

    oGraph = overlapGraph(p)
    oGraph.print()

if __name__ == '__main__':
    main()
# Out:
# AAAATTATCGCGTCCGCTCC -> AAATTATCGCGTCCGCTCCG
# AAAGATGTCGGCAACCGCCC -> AAGATGTCGGCAACCGCCCC
# AAAGCAGGCTCGCCCAGGGG -> AAGCAGGCTCGCCCAGGGGC
# AAAGTCCGCTCGCCACCCGA -> AAGTCCGCTCGCCACCCGAA
# AAATCGGGCTCAGCTTCCAC -> AATCGGGCTCAGCTTCCACA
# AAATGCACGGCGTGGAAGGC -> AATGCACGGCGTGGAAGGCC
# AAATGTGACAACGGACATCG -> AATGTGACAACGGACATCGG
# AAATTATCGCGTCCGCTCCG -> AATTATCGCGTCCGCTCCGC
# AACAATTGTTGCCCATATAG -> ACAATTGTTGCCCATATAGA
# AACACGAAATGTGACAACGG -> ACACGAAATGTGACAACGGA
# AACAGTCACGTATATTTTTC -> ACAGTCACGTATATTTTTCA
# AACCGCCCCGCGTGACATCA -> ACCGCCCCGCGTGACATCAT
# AACCGTAGTGCCAGCCCATT -> ACCGTAGTGCCAGCCCATTG
# AACGATCCCAAATCGGGCTC -> ACGATCCCAAATCGGGCTCA
# AACGCAGTACTATGCCTAAC -> ACGCAGTACTATGCCTAACT
# AACGCTAATAGAGCTAAATG -> ACGCTAATAGAGCTAAATGC
# AACGGACATCGGGAGATCGG -> ACGGACATCGGGAGATCGGG
# AACGGTCGTAACAATTGTTG -> ACGGTCGTAACAATTGTTGC
# AACGTAGAAGCTAAGCTAAC -> ACGTAGAAGCTAAGCTAACG
# AACTCCCGCTATTCAACTGA -> ACTCCCGCTATTCAACTGAT
# AACTGATTGTACATGCGTCA -> ACTGATTGTACATGCGTCAA
# AACTGCCATTATCTCTAGCT -> ACTGCCATTATCTCTAGCTA
# AACTGGGGCAGCTGAACGTA -> ACTGGGGCAGCTGAACGTAG
# AACTTATTGATCAATTGAAC -> ACTTATTGATCAATTGAACT
# AACTTCGTGGCTGGACACTT -> ACTTCGTGGCTGGACACTTC
# AAGACGTAACTCCCGCTATT -> AGACGTAACTCCCGCTATTC
# AAGAGGGAGGACGACGGGGG -> AGAGGGAGGACGACGGGGGG
# AAGATCCATTATCTGGCACT -> AGATCCATTATCTGGCACTG
# AAGATGTCGGCAACCGCCCC -> AGATGTCGGCAACCGCCCCG
# AAGCAGGCTCGCCCAGGGGC -> AGCAGGCTCGCCCAGGGGCC
# AAGCGAATCATTGCATTCAT -> AGCGAATCATTGCATTCATA
# AAGCTAACGGTCGTAACAAT -> AGCTAACGGTCGTAACAATT
# AAGCTAAGCTAACGGTCGTA -> AGCTAAGCTAACGGTCGTAA
# AAGCTAGCTTAGATAGAAGA -> AGCTAGCTTAGATAGAAGAT
# AAGGCCAATTGAGCCCGTGG -> AGGCCAATTGAGCCCGTGGT
# AAGGGTTGTGGTATGTCCCG -> AGGGTTGTGGTATGTCCCGC
# AAGGTCGGACCCATCCTCAG -> AGGTCGGACCCATCCTCAGA
# AAGTATACCGAGCTGGATTT -> AGTATACCGAGCTGGATTTC
# AAGTCCGATACTGCCTACGA -> AGTCCGATACTGCCTACGAA
# AAGTCCGCTCGCCACCCGAA -> AGTCCGCTCGCCACCCGAAC
# AAGTTGGGAAGGTCGGACCC -> AGTTGGGAAGGTCGGACCCA
# AATAAGCTAGCTTAGATAGA -> ATAAGCTAGCTTAGATAGAA
# AATAATGTACGGCCTTCTTT -> ATAATGTACGGCCTTCTTTA
# AATAGAGCTAAATGCACGGC -> ATAGAGCTAAATGCACGGCG
# AATATGGCACGTTCACAGGT -> ATATGGCACGTTCACAGGTC
# AATCATTGCATTCATAGGGC -> ATCATTGCATTCATAGGGCT
# AATCGGGCTCAGCTTCCACA -> ATCGGGCTCAGCTTCCACAA
# AATGCACGGCGTGGAAGGCC -> ATGCACGGCGTGGAAGGCCA
# AATGTACGGCCTTCTTTAGA -> ATGTACGGCCTTCTTTAGAG
# AATGTGACAACGGACATCGG -> ATGTGACAACGGACATCGGG
# AATTATCGCGTCCGCTCCGC -> ATTATCGCGTCCGCTCCGCG
# AATTGAACTTCGTGGCTGGA -> ATTGAACTTCGTGGCTGGAC
# AATTGAGCCCGTGGTCCAAA -> ATTGAGCCCGTGGTCCAAAG
# AATTGTTGCCCATATAGATT -> ATTGTTGCCCATATAGATTA
# ACAACGGACATCGGGAGATC -> CAACGGACATCGGGAGATCG
# ACAAGTATACCGAGCTGGAT -> CAAGTATACCGAGCTGGATT
# ACAATTGTTGCCCATATAGA -> CAATTGTTGCCCATATAGAT
# ACACGAAATGTGACAACGGA -> CACGAAATGTGACAACGGAC
# ACACTTCTTTAGTTCTTGAG -> CACTTCTTTAGTTCTTGAGC
# ACAGCACCTGCGGTGGAAGA -> CAGCACCTGCGGTGGAAGAC
# ACAGGTCAACACGAAATGTG -> CAGGTCAACACGAAATGTGA
# ACAGTCACGTATATTTTTCA -> CAGTCACGTATATTTTTCAA
# ACATCATAGTCGCTTTTCTG -> CATCATAGTCGCTTTTCTGC
# ACATCGGGAGATCGGGGCGG -> CATCGGGAGATCGGGGCGGG
# ACATGCGTCAACGCTAATAG -> CATGCGTCAACGCTAATAGA
# ACATTCTTGCCTCGTAGCGA -> CATTCTTGCCTCGTAGCGAA
# ACCAGATATCAGGGGGGGTC -> CCAGATATCAGGGGGGGTCG
# ACCATAGCCAGTGTGACTAC -> CCATAGCCAGTGTGACTACT
# ACCCATCCTCAGATTAGATC -> CCCATCCTCAGATTAGATCT
# ACCCCCCTTTCTTCGCAGTT -> CCCCCCTTTCTTCGCAGTTT
# ACCCGAACTGCCATTATCTC -> CCCGAACTGCCATTATCTCT
# ACCGAGCTGGATTTCTGACA -> CCGAGCTGGATTTCTGACAG
# ACCGCCCCGCGTGACATCAT -> CCGCCCCGCGTGACATCATA
# ACCGTAGTGCCAGCCCATTG -> CCGTAGTGCCAGCCCATTGG
# ACCTGCGGTGGAAGACGTAA -> CCTGCGGTGGAAGACGTAAC
# ACCTTATTCCGTTACCATAG -> CCTTATTCCGTTACCATAGC
# ACGAAATGTGACAACGGACA -> CGAAATGTGACAACGGACAT
# ACGAAGCGAATCATTGCATT -> CGAAGCGAATCATTGCATTC
# ACGACGGGGGGCTGGACGGA -> CGACGGGGGGCTGGACGGAT
# ACGATCCCAAATCGGGCTCA -> CGATCCCAAATCGGGCTCAG
# ACGCAGTACTATGCCTAACT -> CGCAGTACTATGCCTAACTT
# ACGCCGCAAGAGGGAGGACG -> CGCCGCAAGAGGGAGGACGA
# ACGCTAATAGAGCTAAATGC -> CGCTAATAGAGCTAAATGCA
# ACGGACATCGGGAGATCGGG -> CGGACATCGGGAGATCGGGG
# ACGGATAGTGTCCCTACTAG -> CGGATAGTGTCCCTACTAGT
# ACGGCCTTCTTTAGAGGGAA -> CGGCCTTCTTTAGAGGGAAC
# ACGGCGTGGAAGGCCAATTG -> CGGCGTGGAAGGCCAATTGA
# ACGGGGGGCTGGACGGATAG -> CGGGGGGCTGGACGGATAGT
# ACGGTCGTAACAATTGTTGC -> CGGTCGTAACAATTGTTGCC
# ACGTAACTCCCGCTATTCAA -> CGTAACTCCCGCTATTCAAC
# ACGTAGAAGCTAAGCTAACG -> CGTAGAAGCTAAGCTAACGG
# ACGTATATTTTTCAACTGGG -> CGTATATTTTTCAACTGGGG
# ACGTTCACAGGTCAACACGA -> CGTTCACAGGTCAACACGAA
# ACTACTGAGCGGGCAATATG -> CTACTGAGCGGGCAATATGG
# ACTAGTATTGTGGGAGACGG -> CTAGTATTGTGGGAGACGGT
# ACTATGCCTAACTTATTGAT -> CTATGCCTAACTTATTGATC
# ACTCCCGCTATTCAACTGAT -> CTCCCGCTATTCAACTGATT
# ACTCTGAGGAAGTTGGGAAG -> CTCTGAGGAAGTTGGGAAGG
# ACTGAGCGGGCAATATGGCA -> CTGAGCGGGCAATATGGCAC
# ACTGATTGTACATGCGTCAA -> CTGATTGTACATGCGTCAAC
# ACTGCCATTATCTCTAGCTA -> CTGCCATTATCTCTAGCTAT
# ACTGCCTACGAAGCGAATCA -> CTGCCTACGAAGCGAATCAT
# ACTGGGGACGCCGCAAGAGG -> CTGGGGACGCCGCAAGAGGG
# ACTGGGGCAGCTGAACGTAG -> CTGGGGCAGCTGAACGTAGA
# ACTTATTGATCAATTGAACT -> CTTATTGATCAATTGAACTT
# ACTTCGTGGCTGGACACTTC -> CTTCGTGGCTGGACACTTCT
# ACTTCTCGCACCTTATTCCG -> CTTCTCGCACCTTATTCCGT
# ACTTCTTTAGTTCTTGAGCT -> CTTCTTTAGTTCTTGAGCTA
# ACTTGGAACGATCCCAAATC -> CTTGGAACGATCCCAAATCG
# AGAAGATCCATTATCTGGCA -> GAAGATCCATTATCTGGCAC
# AGAAGCTAAGCTAACGGTCG -> GAAGCTAAGCTAACGGTCGT
# AGACGTAACTCCCGCTATTC -> GACGTAACTCCCGCTATTCA
# AGACTTCTCGCACCTTATTC -> GACTTCTCGCACCTTATTCC
# AGAGCTAAATGCACGGCGTG -> GAGCTAAATGCACGGCGTGG
# AGAGGGAACCGTAGTGCCAG -> GAGGGAACCGTAGTGCCAGC
# AGAGGGAGGACGACGGGGGG -> GAGGGAGGACGACGGGGGGC
# AGAGTTCAAGTCCGATACTG -> GAGTTCAAGTCCGATACTGC
# AGATAGAAGATCCATTATCT -> GATAGAAGATCCATTATCTG
# AGATATCAGGGGGGGTCGAG -> GATATCAGGGGGGGTCGAGA
# AGATCCATTATCTGGCACTG -> GATCCATTATCTGGCACTGG
# AGATCGGGGCGGGTCTGTCA -> GATCGGGGCGGGTCTGTCAC
# AGATCTAAAATTATCGCGTC -> GATCTAAAATTATCGCGTCC
# AGATGTCGGCAACCGCCCCG -> GATGTCGGCAACCGCCCCGC
# AGATTAATAATGTACGGCCT -> GATTAATAATGTACGGCCTT
# AGATTAGATCTAAAATTATC -> GATTAGATCTAAAATTATCG
# AGATTTGTCTCTCGGCAAAG -> GATTTGTCTCTCGGCAAAGA
# AGCACCTGCGGTGGAAGACG -> GCACCTGCGGTGGAAGACGT
# AGCAGGCTCGCCCAGGGGCC -> GCAGGCTCGCCCAGGGGCCG
# AGCCAGTGTGACTACTGAGC -> GCCAGTGTGACTACTGAGCG
# AGCCCATTGGATTGTCGCAA -> GCCCATTGGATTGTCGCAAG
# AGCCCGTGGTCCAAAGTCCG -> GCCCGTGGTCCAAAGTCCGC
# AGCGAAAGCAGGCTCGCCCA -> GCGAAAGCAGGCTCGCCCAG
# AGCGAATCATTGCATTCATA -> GCGAATCATTGCATTCATAG
# AGCGGGCAATATGGCACGTT -> GCGGGCAATATGGCACGTTC
# AGCTAAATGCACGGCGTGGA -> GCTAAATGCACGGCGTGGAA
# AGCTAACGGTCGTAACAATT -> GCTAACGGTCGTAACAATTG
# AGCTAAGCTAACGGTCGTAA -> GCTAAGCTAACGGTCGTAAC
# AGCTAGCTTAGATAGAAGAT -> GCTAGCTTAGATAGAAGATC
# AGCTATGGCAACGCAGTACT -> GCTATGGCAACGCAGTACTA
# AGCTATTGCGTTACCCCCCT -> GCTATTGCGTTACCCCCCTT
# AGCTGAACGTAGAAGCTAAG -> GCTGAACGTAGAAGCTAAGC
# AGCTGGATTTCTGACAGCAC -> GCTGGATTTCTGACAGCACC
# AGCTTAACAGTCACGTATAT -> GCTTAACAGTCACGTATATT
# AGCTTAGATAGAAGATCCAT -> GCTTAGATAGAAGATCCATT
# AGCTTCCACAAGTATACCGA -> GCTTCCACAAGTATACCGAG
# AGGAAGTTGGGAAGGTCGGA -> GGAAGTTGGGAAGGTCGGAC
# AGGACGACGGGGGGCTGGAC -> GGACGACGGGGGGCTGGACG
# AGGCCAATTGAGCCCGTGGT -> GGCCAATTGAGCCCGTGGTC
# AGGCTCGCCCAGGGGCCGCC -> GGCTCGCCCAGGGGCCGCCA
# AGGCTGTGTCATGCCGCCAT -> GGCTGTGTCATGCCGCCATA
# AGGGAACCGTAGTGCCAGCC -> GGGAACCGTAGTGCCAGCCC
# AGGGAGGACGACGGGGGGCT -> GGGAGGACGACGGGGGGCTG
# AGGGCTATTATAGGCTGTGT -> GGGCTATTATAGGCTGTGTC
# AGGGGCCGCCAGACTTCTCG -> GGGGCCGCCAGACTTCTCGC
# AGGGGGGGTCGAGATTTGTC -> GGGGGGGTCGAGATTTGTCT
# AGGGTTGTGGTATGTCCCGC -> GGGTTGTGGTATGTCCCGCA
# AGGTAGAGTTCAAGTCCGAT -> GGTAGAGTTCAAGTCCGATA
# AGGTCAACACGAAATGTGAC -> GGTCAACACGAAATGTGACA
# AGGTCGGACCCATCCTCAGA -> GGTCGGACCCATCCTCAGAT
# AGTACTATGCCTAACTTATT -> GTACTATGCCTAACTTATTG
# AGTATACCGAGCTGGATTTC -> GTATACCGAGCTGGATTTCT
# AGTATTGTGGGAGACGGTGA -> GTATTGTGGGAGACGGTGAG
# AGTCACGTATATTTTTCAAC -> GTCACGTATATTTTTCAACT
# AGTCCGATACTGCCTACGAA -> GTCCGATACTGCCTACGAAG
# AGTCCGCTCGCCACCCGAAC -> GTCCGCTCGCCACCCGAACT
# AGTCGCTTTTCTGCCTCAAT -> GTCGCTTTTCTGCCTCAATA
# AGTGCCAGCCCATTGGATTG -> GTGCCAGCCCATTGGATTGT
# AGTGTCCCTACTAGTATTGT -> GTGTCCCTACTAGTATTGTG
# AGTGTGACTACTGAGCGGGC -> GTGTGACTACTGAGCGGGCA
# AGTTCAAGTCCGATACTGCC -> GTTCAAGTCCGATACTGCCT
# AGTTCTTGAGCTATTGCGTT -> GTTCTTGAGCTATTGCGTTA
# AGTTGGGAAGGTCGGACCCA -> GTTGGGAAGGTCGGACCCAT
# AGTTTCCCGGACTCTGAGGA -> GTTTCCCGGACTCTGAGGAA
# ATAAGCTAGCTTAGATAGAA -> TAAGCTAGCTTAGATAGAAG
# ATAATGTACGGCCTTCTTTA -> TAATGTACGGCCTTCTTTAG
# ATACCGAGCTGGATTTCTGA -> TACCGAGCTGGATTTCTGAC
# ATACTGCCTACGAAGCGAAT -> TACTGCCTACGAAGCGAATC
# ATAGAAGATCCATTATCTGG -> TAGAAGATCCATTATCTGGC
# ATAGAGCTAAATGCACGGCG -> TAGAGCTAAATGCACGGCGT
# ATAGATTAATAATGTACGGC -> TAGATTAATAATGTACGGCC
# ATAGCCAGTGTGACTACTGA -> TAGCCAGTGTGACTACTGAG
# ATAGCTTAACAGTCACGTAT -> TAGCTTAACAGTCACGTATA
# ATAGGCTGTGTCATGCCGCC -> TAGGCTGTGTCATGCCGCCA
# ATAGGGCTATTATAGGCTGT -> TAGGGCTATTATAGGCTGTG
# ATAGTCGCTTTTCTGCCTCA -> TAGTCGCTTTTCTGCCTCAA
# ATAGTGTCCCTACTAGTATT -> TAGTGTCCCTACTAGTATTG
# ATATAGATTAATAATGTACG -> TATAGATTAATAATGTACGG
# ATATCAGGGGGGGTCGAGAT -> TATCAGGGGGGGTCGAGATT
# ATATGGCACGTTCACAGGTC -> TATGGCACGTTCACAGGTCA
# ATATTTTTCAACTGGGGCAG -> TATTTTTCAACTGGGGCAGC
# ATCAATTGAACTTCGTGGCT -> TCAATTGAACTTCGTGGCTG
# ATCAGGGGGGGTCGAGATTT -> TCAGGGGGGGTCGAGATTTG
# ATCATAGTCGCTTTTCTGCC -> TCATAGTCGCTTTTCTGCCT
# ATCATTGCATTCATAGGGCT -> TCATTGCATTCATAGGGCTA
# ATCCATTATCTGGCACTGGG -> TCCATTATCTGGCACTGGGG
# ATCCCAAATCGGGCTCAGCT -> TCCCAAATCGGGCTCAGCTT
# ATCCTCAGATTAGATCTAAA -> TCCTCAGATTAGATCTAAAA
# ATCGCGTCCGCTCCGCGTAG -> TCGCGTCCGCTCCGCGTAGG
# ATCGGGAGATCGGGGCGGGT -> TCGGGAGATCGGGGCGGGTC
# ATCGGGCTCAGCTTCCACAA -> TCGGGCTCAGCTTCCACAAG
# ATCGGGGCGGGTCTGTCACT -> TCGGGGCGGGTCTGTCACTT
# ATCTAAAATTATCGCGTCCG -> TCTAAAATTATCGCGTCCGC
# ATCTCTAGCTATGGCAACGC -> TCTCTAGCTATGGCAACGCA
# ATCTGGCACTGGGGACGCCG -> TCTGGCACTGGGGACGCCGC
# ATGCACGGCGTGGAAGGCCA -> TGCACGGCGTGGAAGGCCAA
# ATGCCGCCATAGCTTAACAG -> TGCCGCCATAGCTTAACAGT
# ATGCCTAACTTATTGATCAA -> TGCCTAACTTATTGATCAAT
# ATGCGTCAACGCTAATAGAG -> TGCGTCAACGCTAATAGAGC
# ATGGCAACGCAGTACTATGC -> TGGCAACGCAGTACTATGCC
# ATGGCACGTTCACAGGTCAA -> TGGCACGTTCACAGGTCAAC
# ATGTACGGCCTTCTTTAGAG -> TGTACGGCCTTCTTTAGAGG
# ATGTCCCGCACCAGATATCA -> TGTCCCGCACCAGATATCAG
# ATGTCGGCAACCGCCCCGCG -> TGTCGGCAACCGCCCCGCGT
# ATGTGACAACGGACATCGGG -> TGTGACAACGGACATCGGGA
# ATTAATAATGTACGGCCTTC -> TTAATAATGTACGGCCTTCT
# ATTAGATCTAAAATTATCGC -> TTAGATCTAAAATTATCGCG
# ATTATAGGCTGTGTCATGCC -> TTATAGGCTGTGTCATGCCG
# ATTATCGCGTCCGCTCCGCG -> TTATCGCGTCCGCTCCGCGT
# ATTATCTCTAGCTATGGCAA -> TTATCTCTAGCTATGGCAAC
# ATTATCTGGCACTGGGGACG -> TTATCTGGCACTGGGGACGC
# ATTCAACTGATTGTACATGC -> TTCAACTGATTGTACATGCG
# ATTCATAGGGCTATTATAGG -> TTCATAGGGCTATTATAGGC
# ATTCCGTTACCATAGCCAGT -> TTCCGTTACCATAGCCAGTG
# ATTCTTGCCTCGTAGCGAAA -> TTCTTGCCTCGTAGCGAAAG
# ATTGAACTTCGTGGCTGGAC -> TTGAACTTCGTGGCTGGACA
# ATTGAGCCCGTGGTCCAAAG -> TTGAGCCCGTGGTCCAAAGT
# ATTGATCAATTGAACTTCGT -> TTGATCAATTGAACTTCGTG
# ATTGCATTCATAGGGCTATT -> TTGCATTCATAGGGCTATTA
# ATTGCGTTACCCCCCTTTCT -> TTGCGTTACCCCCCTTTCTT
# ATTGGATTGTCGCAAGGGTT -> TTGGATTGTCGCAAGGGTTG
# ATTGTACATGCGTCAACGCT -> TTGTACATGCGTCAACGCTA
# ATTGTCGCAAGGGTTGTGGT -> TTGTCGCAAGGGTTGTGGTA
# ATTGTGGGAGACGGTGAGTG -> TTGTGGGAGACGGTGAGTGG
# ATTGTTGCCCATATAGATTA -> TTGTTGCCCATATAGATTAA
# ATTTCTGACAGCACCTGCGG -> TTTCTGACAGCACCTGCGGT
# ATTTGTCTCTCGGCAAAGAT -> TTTGTCTCTCGGCAAAGATG
# ATTTTTCAACTGGGGCAGCT -> TTTTTCAACTGGGGCAGCTG
# CAAAGATGTCGGCAACCGCC -> AAAGATGTCGGCAACCGCCC
# CAAAGTCCGCTCGCCACCCG -> AAAGTCCGCTCGCCACCCGA
# CAAATCGGGCTCAGCTTCCA -> AAATCGGGCTCAGCTTCCAC
# CAACACGAAATGTGACAACG -> AACACGAAATGTGACAACGG
# CAACCGCCCCGCGTGACATC -> AACCGCCCCGCGTGACATCA
# CAACGCAGTACTATGCCTAA -> AACGCAGTACTATGCCTAAC
# CAACGCTAATAGAGCTAAAT -> AACGCTAATAGAGCTAAATG
# CAACGGACATCGGGAGATCG -> AACGGACATCGGGAGATCGG
# CAACTGATTGTACATGCGTC -> AACTGATTGTACATGCGTCA
# CAACTGGGGCAGCTGAACGT -> AACTGGGGCAGCTGAACGTA
# CAAGAGGGAGGACGACGGGG -> AAGAGGGAGGACGACGGGGG
# CAAGGGTTGTGGTATGTCCC -> AAGGGTTGTGGTATGTCCCG
# CAAGTATACCGAGCTGGATT -> AAGTATACCGAGCTGGATTT
# CAAGTCCGATACTGCCTACG -> AAGTCCGATACTGCCTACGA
# CAATAAGCTAGCTTAGATAG -> AATAAGCTAGCTTAGATAGA
# CAATATGGCACGTTCACAGG -> AATATGGCACGTTCACAGGT
# CAATTGAACTTCGTGGCTGG -> AATTGAACTTCGTGGCTGGA
# CAATTGAGCCCGTGGTCCAA -> AATTGAGCCCGTGGTCCAAA
# CAATTGTTGCCCATATAGAT -> AATTGTTGCCCATATAGATT
# CACAAGTATACCGAGCTGGA -> ACAAGTATACCGAGCTGGAT
# CACAGGTCAACACGAAATGT -> ACAGGTCAACACGAAATGTG
# CACCAGATATCAGGGGGGGT -> ACCAGATATCAGGGGGGGTC
# CACCCGAACTGCCATTATCT -> ACCCGAACTGCCATTATCTC
# CACCTGCGGTGGAAGACGTA -> ACCTGCGGTGGAAGACGTAA
# CACCTTATTCCGTTACCATA -> ACCTTATTCCGTTACCATAG
# CACGAAATGTGACAACGGAC -> ACGAAATGTGACAACGGACA
# CACGGCGTGGAAGGCCAATT -> ACGGCGTGGAAGGCCAATTG
# CACGTATATTTTTCAACTGG -> ACGTATATTTTTCAACTGGG
# CACGTTCACAGGTCAACACG -> ACGTTCACAGGTCAACACGA
# CACTGGGGACGCCGCAAGAG -> ACTGGGGACGCCGCAAGAGG
# CACTTCTTTAGTTCTTGAGC -> ACTTCTTTAGTTCTTGAGCT
# CACTTGGAACGATCCCAAAT -> ACTTGGAACGATCCCAAATC
# CAGACTTCTCGCACCTTATT -> AGACTTCTCGCACCTTATTC
# CAGATATCAGGGGGGGTCGA -> AGATATCAGGGGGGGTCGAG
# CAGATTAGATCTAAAATTAT -> AGATTAGATCTAAAATTATC
# CAGCACCTGCGGTGGAAGAC -> AGCACCTGCGGTGGAAGACG
# CAGCCCATTGGATTGTCGCA -> AGCCCATTGGATTGTCGCAA
# CAGCTGAACGTAGAAGCTAA -> AGCTGAACGTAGAAGCTAAG
# CAGCTTCCACAAGTATACCG -> AGCTTCCACAAGTATACCGA
# CAGGCTCGCCCAGGGGCCGC -> AGGCTCGCCCAGGGGCCGCC
# CAGGGGCCGCCAGACTTCTC -> AGGGGCCGCCAGACTTCTCG
# CAGGGGGGGTCGAGATTTGT -> AGGGGGGGTCGAGATTTGTC
# CAGGTCAACACGAAATGTGA -> AGGTCAACACGAAATGTGAC
# CAGTACTATGCCTAACTTAT -> AGTACTATGCCTAACTTATT
# CAGTCACGTATATTTTTCAA -> AGTCACGTATATTTTTCAAC
# CAGTGTGACTACTGAGCGGG -> AGTGTGACTACTGAGCGGGC
# CAGTTTCCCGGACTCTGAGG -> AGTTTCCCGGACTCTGAGGA
# CATAGCCAGTGTGACTACTG -> ATAGCCAGTGTGACTACTGA
# CATAGCTTAACAGTCACGTA -> ATAGCTTAACAGTCACGTAT
# CATAGGGCTATTATAGGCTG -> ATAGGGCTATTATAGGCTGT
# CATAGTCGCTTTTCTGCCTC -> ATAGTCGCTTTTCTGCCTCA
# CATATAGATTAATAATGTAC -> ATATAGATTAATAATGTACG
# CATCATAGTCGCTTTTCTGC -> ATCATAGTCGCTTTTCTGCC
# CATCCTCAGATTAGATCTAA -> ATCCTCAGATTAGATCTAAA
# CATCGGGAGATCGGGGCGGG -> ATCGGGAGATCGGGGCGGGT
# CATGCCGCCATAGCTTAACA -> ATGCCGCCATAGCTTAACAG
# CATGCGTCAACGCTAATAGA -> ATGCGTCAACGCTAATAGAG
# CATTATCTCTAGCTATGGCA -> ATTATCTCTAGCTATGGCAA
# CATTATCTGGCACTGGGGAC -> ATTATCTGGCACTGGGGACG
# CATTCATAGGGCTATTATAG -> ATTCATAGGGCTATTATAGG
# CATTCTTGCCTCGTAGCGAA -> ATTCTTGCCTCGTAGCGAAA
# CATTGCATTCATAGGGCTAT -> ATTGCATTCATAGGGCTATT
# CATTGGATTGTCGCAAGGGT -> ATTGGATTGTCGCAAGGGTT
# CCAAAGTCCGCTCGCCACCC -> CAAAGTCCGCTCGCCACCCG
# CCAAATCGGGCTCAGCTTCC -> CAAATCGGGCTCAGCTTCCA
# CCAATTGAGCCCGTGGTCCA -> CAATTGAGCCCGTGGTCCAA
# CCACAAGTATACCGAGCTGG -> CACAAGTATACCGAGCTGGA
# CCACCCGAACTGCCATTATC -> CACCCGAACTGCCATTATCT
# CCAGACTTCTCGCACCTTAT -> CAGACTTCTCGCACCTTATT
# CCAGATATCAGGGGGGGTCG -> CAGATATCAGGGGGGGTCGA
# CCAGCCCATTGGATTGTCGC -> CAGCCCATTGGATTGTCGCA
# CCAGGGGCCGCCAGACTTCT -> CAGGGGCCGCCAGACTTCTC
# CCAGTGTGACTACTGAGCGG -> CAGTGTGACTACTGAGCGGG
# CCATAGCCAGTGTGACTACT -> CATAGCCAGTGTGACTACTG
# CCATAGCTTAACAGTCACGT -> CATAGCTTAACAGTCACGTA
# CCATATAGATTAATAATGTA -> CATATAGATTAATAATGTAC
# CCATCCTCAGATTAGATCTA -> CATCCTCAGATTAGATCTAA
# CCATTATCTCTAGCTATGGC -> CATTATCTCTAGCTATGGCA
# CCATTATCTGGCACTGGGGA -> CATTATCTGGCACTGGGGAC
# CCATTGGATTGTCGCAAGGG -> CATTGGATTGTCGCAAGGGT
# CCCAAATCGGGCTCAGCTTC -> CCAAATCGGGCTCAGCTTCC
# CCCAGGGGCCGCCAGACTTC -> CCAGGGGCCGCCAGACTTCT
# CCCATATAGATTAATAATGT -> CCATATAGATTAATAATGTA
# CCCATCCTCAGATTAGATCT -> CCATCCTCAGATTAGATCTA
# CCCATTGGATTGTCGCAAGG -> CCATTGGATTGTCGCAAGGG
# CCCCCCTTTCTTCGCAGTTT -> CCCCCTTTCTTCGCAGTTTC
# CCCCCTTTCTTCGCAGTTTC -> CCCCTTTCTTCGCAGTTTCC
# CCCCGCGTGACATCATAGTC -> CCCGCGTGACATCATAGTCG
# CCCCTTTCTTCGCAGTTTCC -> CCCTTTCTTCGCAGTTTCCC
# CCCGAACTGCCATTATCTCT -> CCGAACTGCCATTATCTCTA
# CCCGCACCAGATATCAGGGG -> CCGCACCAGATATCAGGGGG
# CCCGCGTGACATCATAGTCG -> CCGCGTGACATCATAGTCGC
# CCCGCTATTCAACTGATTGT -> CCGCTATTCAACTGATTGTA
# CCCGGACTCTGAGGAAGTTG -> CCGGACTCTGAGGAAGTTGG
# CCCGTGGTCCAAAGTCCGCT -> CCGTGGTCCAAAGTCCGCTC
# CCCTACTAGTATTGTGGGAG -> CCTACTAGTATTGTGGGAGA
# CCCTTTCTTCGCAGTTTCCC -> CCTTTCTTCGCAGTTTCCCG
# CCGAACTGCCATTATCTCTA -> CGAACTGCCATTATCTCTAG
# CCGAGCTGGATTTCTGACAG -> CGAGCTGGATTTCTGACAGC
# CCGATACTGCCTACGAAGCG -> CGATACTGCCTACGAAGCGA
# CCGCAAGAGGGAGGACGACG -> CGCAAGAGGGAGGACGACGG
# CCGCACCAGATATCAGGGGG -> CGCACCAGATATCAGGGGGG
# CCGCCAGACTTCTCGCACCT -> CGCCAGACTTCTCGCACCTT
# CCGCCATAGCTTAACAGTCA -> CGCCATAGCTTAACAGTCAC
# CCGCCCCGCGTGACATCATA -> CGCCCCGCGTGACATCATAG
# CCGCGTAGGTAGAGTTCAAG -> CGCGTAGGTAGAGTTCAAGT
# CCGCGTGACATCATAGTCGC -> CGCGTGACATCATAGTCGCT
# CCGCTATTCAACTGATTGTA -> CGCTATTCAACTGATTGTAC
# CCGCTCCGCGTAGGTAGAGT -> CGCTCCGCGTAGGTAGAGTT
# CCGCTCGCCACCCGAACTGC -> CGCTCGCCACCCGAACTGCC
# CCGGACTCTGAGGAAGTTGG -> CGGACTCTGAGGAAGTTGGG
# CCGTAGTGCCAGCCCATTGG -> CGTAGTGCCAGCCCATTGGA
# CCGTGGTCCAAAGTCCGCTC -> CGTGGTCCAAAGTCCGCTCG
# CCGTTACCATAGCCAGTGTG -> CGTTACCATAGCCAGTGTGA
# CCTAACTTATTGATCAATTG -> CTAACTTATTGATCAATTGA
# CCTACGAAGCGAATCATTGC -> CTACGAAGCGAATCATTGCA
# CCTACTAGTATTGTGGGAGA -> CTACTAGTATTGTGGGAGAC
# CCTCAATAAGCTAGCTTAGA -> CTCAATAAGCTAGCTTAGAT
# CCTCAGATTAGATCTAAAAT -> CTCAGATTAGATCTAAAATT
# CCTCGTAGCGAAAGCAGGCT -> CTCGTAGCGAAAGCAGGCTC
# CCTGCGGTGGAAGACGTAAC -> CTGCGGTGGAAGACGTAACT
# CCTTATTCCGTTACCATAGC -> CTTATTCCGTTACCATAGCC
# CCTTCTTTAGAGGGAACCGT -> CTTCTTTAGAGGGAACCGTA
# CCTTTCTTCGCAGTTTCCCG -> CTTTCTTCGCAGTTTCCCGG
# CGAAAGCAGGCTCGCCCAGG -> GAAAGCAGGCTCGCCCAGGG
# CGAAATGTGACAACGGACAT -> GAAATGTGACAACGGACATC
# CGAACTGCCATTATCTCTAG -> GAACTGCCATTATCTCTAGC
# CGAAGCGAATCATTGCATTC -> GAAGCGAATCATTGCATTCA
# CGAATCATTGCATTCATAGG -> GAATCATTGCATTCATAGGG
# CGACGGGGGGCTGGACGGAT -> GACGGGGGGCTGGACGGATA
# CGAGATTTGTCTCTCGGCAA -> GAGATTTGTCTCTCGGCAAA
# CGAGCTGGATTTCTGACAGC -> GAGCTGGATTTCTGACAGCA
# CGATACTGCCTACGAAGCGA -> GATACTGCCTACGAAGCGAA
# CGATCCCAAATCGGGCTCAG -> GATCCCAAATCGGGCTCAGC
# CGCAAGAGGGAGGACGACGG -> GCAAGAGGGAGGACGACGGG
# CGCAAGGGTTGTGGTATGTC -> GCAAGGGTTGTGGTATGTCC
# CGCACCAGATATCAGGGGGG -> GCACCAGATATCAGGGGGGG
# CGCACCTTATTCCGTTACCA -> GCACCTTATTCCGTTACCAT
# CGCAGTACTATGCCTAACTT -> GCAGTACTATGCCTAACTTA
# CGCAGTTTCCCGGACTCTGA -> GCAGTTTCCCGGACTCTGAG
# CGCCACCCGAACTGCCATTA -> GCCACCCGAACTGCCATTAT
# CGCCAGACTTCTCGCACCTT -> GCCAGACTTCTCGCACCTTA
# CGCCATAGCTTAACAGTCAC -> GCCATAGCTTAACAGTCACG
# CGCCCAGGGGCCGCCAGACT -> GCCCAGGGGCCGCCAGACTT
# CGCCCCGCGTGACATCATAG -> GCCCCGCGTGACATCATAGT
# CGCCGCAAGAGGGAGGACGA -> GCCGCAAGAGGGAGGACGAC
# CGCGTAGGTAGAGTTCAAGT -> GCGTAGGTAGAGTTCAAGTC
# CGCGTCCGCTCCGCGTAGGT -> GCGTCCGCTCCGCGTAGGTA
# CGCGTGACATCATAGTCGCT -> GCGTGACATCATAGTCGCTT
# CGCTAATAGAGCTAAATGCA -> GCTAATAGAGCTAAATGCAC
# CGCTATTCAACTGATTGTAC -> GCTATTCAACTGATTGTACA
# CGCTCCGCGTAGGTAGAGTT -> GCTCCGCGTAGGTAGAGTTC
# CGCTCGCCACCCGAACTGCC -> GCTCGCCACCCGAACTGCCA
# CGCTTTTCTGCCTCAATAAG -> GCTTTTCTGCCTCAATAAGC
# CGGACATCGGGAGATCGGGG -> GGACATCGGGAGATCGGGGC
# CGGACCCATCCTCAGATTAG -> GGACCCATCCTCAGATTAGA
# CGGACTCTGAGGAAGTTGGG -> GGACTCTGAGGAAGTTGGGA
# CGGATAGTGTCCCTACTAGT -> GGATAGTGTCCCTACTAGTA
# CGGCAAAGATGTCGGCAACC -> GGCAAAGATGTCGGCAACCG
# CGGCAACCGCCCCGCGTGAC -> GGCAACCGCCCCGCGTGACA
# CGGCCTTCTTTAGAGGGAAC -> GGCCTTCTTTAGAGGGAACC
# CGGCGTGGAAGGCCAATTGA -> GGCGTGGAAGGCCAATTGAG
# CGGGAGATCGGGGCGGGTCT -> GGGAGATCGGGGCGGGTCTG
# CGGGCAATATGGCACGTTCA -> GGGCAATATGGCACGTTCAC
# CGGGCTCAGCTTCCACAAGT -> GGGCTCAGCTTCCACAAGTA
# CGGGGCGGGTCTGTCACTTG -> GGGGCGGGTCTGTCACTTGG
# CGGGGGGCTGGACGGATAGT -> GGGGGGCTGGACGGATAGTG
# CGGGTCTGTCACTTGGAACG -> GGGTCTGTCACTTGGAACGA
# CGGTCGTAACAATTGTTGCC -> GGTCGTAACAATTGTTGCCC
# CGGTGGAAGACGTAACTCCC -> GGTGGAAGACGTAACTCCCG
# CGTAACAATTGTTGCCCATA -> GTAACAATTGTTGCCCATAT
# CGTAACTCCCGCTATTCAAC -> GTAACTCCCGCTATTCAACT
# CGTAGAAGCTAAGCTAACGG -> GTAGAAGCTAAGCTAACGGT
# CGTAGCGAAAGCAGGCTCGC -> GTAGCGAAAGCAGGCTCGCC
# CGTAGGTAGAGTTCAAGTCC -> GTAGGTAGAGTTCAAGTCCG
# CGTAGTGCCAGCCCATTGGA -> GTAGTGCCAGCCCATTGGAT
# CGTATATTTTTCAACTGGGG -> GTATATTTTTCAACTGGGGC
# CGTCAACGCTAATAGAGCTA -> GTCAACGCTAATAGAGCTAA
# CGTCCGCTCCGCGTAGGTAG -> GTCCGCTCCGCGTAGGTAGA
# CGTGACATCATAGTCGCTTT -> GTGACATCATAGTCGCTTTT
# CGTGGAAGGCCAATTGAGCC -> GTGGAAGGCCAATTGAGCCC
# CGTGGCTGGACACTTCTTTA -> GTGGCTGGACACTTCTTTAG
# CGTGGTCCAAAGTCCGCTCG -> GTGGTCCAAAGTCCGCTCGC
# CGTTACCATAGCCAGTGTGA -> GTTACCATAGCCAGTGTGAC
# CGTTACCCCCCTTTCTTCGC -> GTTACCCCCCTTTCTTCGCA
# CGTTCACAGGTCAACACGAA -> GTTCACAGGTCAACACGAAA
# CTAAAATTATCGCGTCCGCT -> TAAAATTATCGCGTCCGCTC
# CTAAATGCACGGCGTGGAAG -> TAAATGCACGGCGTGGAAGG
# CTAACGGTCGTAACAATTGT -> TAACGGTCGTAACAATTGTT
# CTAACTTATTGATCAATTGA -> TAACTTATTGATCAATTGAA
# CTAAGCTAACGGTCGTAACA -> TAAGCTAACGGTCGTAACAA
# CTAATAGAGCTAAATGCACG -> TAATAGAGCTAAATGCACGG
# CTACGAAGCGAATCATTGCA -> TACGAAGCGAATCATTGCAT
# CTACTAGTATTGTGGGAGAC -> TACTAGTATTGTGGGAGACG
# CTACTGAGCGGGCAATATGG -> TACTGAGCGGGCAATATGGC
# CTAGCTATGGCAACGCAGTA -> TAGCTATGGCAACGCAGTAC
# CTAGCTTAGATAGAAGATCC -> TAGCTTAGATAGAAGATCCA
# CTAGTATTGTGGGAGACGGT -> TAGTATTGTGGGAGACGGTG
# CTATGCCTAACTTATTGATC -> TATGCCTAACTTATTGATCA
# CTATGGCAACGCAGTACTAT -> TATGGCAACGCAGTACTATG
# CTATTATAGGCTGTGTCATG -> TATTATAGGCTGTGTCATGC
# CTATTCAACTGATTGTACAT -> TATTCAACTGATTGTACATG
# CTATTGCGTTACCCCCCTTT -> TATTGCGTTACCCCCCTTTC
# CTCAATAAGCTAGCTTAGAT -> TCAATAAGCTAGCTTAGATA
# CTCAGATTAGATCTAAAATT -> TCAGATTAGATCTAAAATTA
# CTCAGCTTCCACAAGTATAC -> TCAGCTTCCACAAGTATACC
# CTCCCGCTATTCAACTGATT -> TCCCGCTATTCAACTGATTG
# CTCCGCGTAGGTAGAGTTCA -> TCCGCGTAGGTAGAGTTCAA
# CTCGCACCTTATTCCGTTAC -> TCGCACCTTATTCCGTTACC
# CTCGCCACCCGAACTGCCAT -> TCGCCACCCGAACTGCCATT
# CTCGCCCAGGGGCCGCCAGA -> TCGCCCAGGGGCCGCCAGAC
# CTCGGCAAAGATGTCGGCAA -> TCGGCAAAGATGTCGGCAAC
# CTCGTAGCGAAAGCAGGCTC -> TCGTAGCGAAAGCAGGCTCG
# CTCTAGCTATGGCAACGCAG -> TCTAGCTATGGCAACGCAGT
# CTCTCGGCAAAGATGTCGGC -> TCTCGGCAAAGATGTCGGCA
# CTCTGAGGAAGTTGGGAAGG -> TCTGAGGAAGTTGGGAAGGT
# CTGAACGTAGAAGCTAAGCT -> TGAACGTAGAAGCTAAGCTA
# CTGACAGCACCTGCGGTGGA -> TGACAGCACCTGCGGTGGAA
# CTGAGCGGGCAATATGGCAC -> TGAGCGGGCAATATGGCACG
# CTGAGGAAGTTGGGAAGGTC -> TGAGGAAGTTGGGAAGGTCG
# CTGATTGTACATGCGTCAAC -> TGATTGTACATGCGTCAACG
# CTGCCATTATCTCTAGCTAT -> TGCCATTATCTCTAGCTATG
# CTGCCTACGAAGCGAATCAT -> TGCCTACGAAGCGAATCATT
# CTGCCTCAATAAGCTAGCTT -> TGCCTCAATAAGCTAGCTTA
# CTGCGGTGGAAGACGTAACT -> TGCGGTGGAAGACGTAACTC
# CTGGACACTTCTTTAGTTCT -> TGGACACTTCTTTAGTTCTT
# CTGGACGGATAGTGTCCCTA -> TGGACGGATAGTGTCCCTAC
# CTGGATTTCTGACAGCACCT -> TGGATTTCTGACAGCACCTG
# CTGGCACTGGGGACGCCGCA -> TGGCACTGGGGACGCCGCAA
# CTGGGGACGCCGCAAGAGGG -> TGGGGACGCCGCAAGAGGGA
# CTGGGGCAGCTGAACGTAGA -> TGGGGCAGCTGAACGTAGAA
# CTGTCACTTGGAACGATCCC -> TGTCACTTGGAACGATCCCA
# CTGTGTCATGCCGCCATAGC -> TGTGTCATGCCGCCATAGCT
# CTTAACAGTCACGTATATTT -> TTAACAGTCACGTATATTTT
# CTTAGATAGAAGATCCATTA -> TTAGATAGAAGATCCATTAT
# CTTATTCCGTTACCATAGCC -> TTATTCCGTTACCATAGCCA
# CTTATTGATCAATTGAACTT -> TTATTGATCAATTGAACTTC
# CTTCCACAAGTATACCGAGC -> TTCCACAAGTATACCGAGCT
# CTTCGCAGTTTCCCGGACTC -> TTCGCAGTTTCCCGGACTCT
# CTTCGTGGCTGGACACTTCT -> TTCGTGGCTGGACACTTCTT
# CTTCTCGCACCTTATTCCGT -> TTCTCGCACCTTATTCCGTT
# CTTCTTTAGAGGGAACCGTA -> TTCTTTAGAGGGAACCGTAG
# CTTCTTTAGTTCTTGAGCTA -> TTCTTTAGTTCTTGAGCTAT
# CTTGAGCTATTGCGTTACCC -> TTGAGCTATTGCGTTACCCC
# CTTGCCTCGTAGCGAAAGCA -> TTGCCTCGTAGCGAAAGCAG
# CTTGGAACGATCCCAAATCG -> TTGGAACGATCCCAAATCGG
# CTTTAGAGGGAACCGTAGTG -> TTTAGAGGGAACCGTAGTGC
# CTTTAGTTCTTGAGCTATTG -> TTTAGTTCTTGAGCTATTGC
# CTTTCTTCGCAGTTTCCCGG -> TTTCTTCGCAGTTTCCCGGA
# CTTTTCTGCCTCAATAAGCT -> TTTTCTGCCTCAATAAGCTA
# GAAAGCAGGCTCGCCCAGGG -> AAAGCAGGCTCGCCCAGGGG
# GAAATGTGACAACGGACATC -> AAATGTGACAACGGACATCG
# GAACCGTAGTGCCAGCCCAT -> AACCGTAGTGCCAGCCCATT
# GAACGATCCCAAATCGGGCT -> AACGATCCCAAATCGGGCTC
# GAACGTAGAAGCTAAGCTAA -> AACGTAGAAGCTAAGCTAAC
# GAACTGCCATTATCTCTAGC -> AACTGCCATTATCTCTAGCT
# GAACTTCGTGGCTGGACACT -> AACTTCGTGGCTGGACACTT
# GAAGACGTAACTCCCGCTAT -> AAGACGTAACTCCCGCTATT
# GAAGATCCATTATCTGGCAC -> AAGATCCATTATCTGGCACT
# GAAGCGAATCATTGCATTCA -> AAGCGAATCATTGCATTCAT
# GAAGCTAAGCTAACGGTCGT -> AAGCTAAGCTAACGGTCGTA
# GAAGGCCAATTGAGCCCGTG -> AAGGCCAATTGAGCCCGTGG
# GAAGGTCGGACCCATCCTCA -> AAGGTCGGACCCATCCTCAG
# GAAGTTGGGAAGGTCGGACC -> AAGTTGGGAAGGTCGGACCC
# GAATCATTGCATTCATAGGG -> AATCATTGCATTCATAGGGC
# GACAACGGACATCGGGAGAT -> ACAACGGACATCGGGAGATC
# GACACTTCTTTAGTTCTTGA -> ACACTTCTTTAGTTCTTGAG
# GACAGCACCTGCGGTGGAAG -> ACAGCACCTGCGGTGGAAGA
# GACATCATAGTCGCTTTTCT -> ACATCATAGTCGCTTTTCTG
# GACATCGGGAGATCGGGGCG -> ACATCGGGAGATCGGGGCGG
# GACCCATCCTCAGATTAGAT -> ACCCATCCTCAGATTAGATC
# GACGACGGGGGGCTGGACGG -> ACGACGGGGGGCTGGACGGA
# GACGCCGCAAGAGGGAGGAC -> ACGCCGCAAGAGGGAGGACG
# GACGGATAGTGTCCCTACTA -> ACGGATAGTGTCCCTACTAG
# GACGGGGGGCTGGACGGATA -> ACGGGGGGCTGGACGGATAG
# GACGTAACTCCCGCTATTCA -> ACGTAACTCCCGCTATTCAA
# GACTACTGAGCGGGCAATAT -> ACTACTGAGCGGGCAATATG
# GACTCTGAGGAAGTTGGGAA -> ACTCTGAGGAAGTTGGGAAG
# GACTTCTCGCACCTTATTCC -> ACTTCTCGCACCTTATTCCG
# GAGATCGGGGCGGGTCTGTC -> AGATCGGGGCGGGTCTGTCA
# GAGATTTGTCTCTCGGCAAA -> AGATTTGTCTCTCGGCAAAG
# GAGCCCGTGGTCCAAAGTCC -> AGCCCGTGGTCCAAAGTCCG
# GAGCGGGCAATATGGCACGT -> AGCGGGCAATATGGCACGTT
# GAGCTAAATGCACGGCGTGG -> AGCTAAATGCACGGCGTGGA
# GAGCTATTGCGTTACCCCCC -> AGCTATTGCGTTACCCCCCT
# GAGCTGGATTTCTGACAGCA -> AGCTGGATTTCTGACAGCAC
# GAGGAAGTTGGGAAGGTCGG -> AGGAAGTTGGGAAGGTCGGA
# GAGGACGACGGGGGGCTGGA -> AGGACGACGGGGGGCTGGAC
# GAGGGAACCGTAGTGCCAGC -> AGGGAACCGTAGTGCCAGCC
# GAGGGAGGACGACGGGGGGC -> AGGGAGGACGACGGGGGGCT
# GAGTTCAAGTCCGATACTGC -> AGTTCAAGTCCGATACTGCC
# GATACTGCCTACGAAGCGAA -> ATACTGCCTACGAAGCGAAT
# GATAGAAGATCCATTATCTG -> ATAGAAGATCCATTATCTGG
# GATAGTGTCCCTACTAGTAT -> ATAGTGTCCCTACTAGTATT
# GATATCAGGGGGGGTCGAGA -> ATATCAGGGGGGGTCGAGAT
# GATCAATTGAACTTCGTGGC -> ATCAATTGAACTTCGTGGCT
# GATCCATTATCTGGCACTGG -> ATCCATTATCTGGCACTGGG
# GATCCCAAATCGGGCTCAGC -> ATCCCAAATCGGGCTCAGCT
# GATCGGGGCGGGTCTGTCAC -> ATCGGGGCGGGTCTGTCACT
# GATCTAAAATTATCGCGTCC -> ATCTAAAATTATCGCGTCCG
# GATGTCGGCAACCGCCCCGC -> ATGTCGGCAACCGCCCCGCG
# GATTAATAATGTACGGCCTT -> ATTAATAATGTACGGCCTTC
# GATTAGATCTAAAATTATCG -> ATTAGATCTAAAATTATCGC
# GATTGTACATGCGTCAACGC -> ATTGTACATGCGTCAACGCT
# GATTGTCGCAAGGGTTGTGG -> ATTGTCGCAAGGGTTGTGGT
# GATTTCTGACAGCACCTGCG -> ATTTCTGACAGCACCTGCGG
# GATTTGTCTCTCGGCAAAGA -> ATTTGTCTCTCGGCAAAGAT
# GCAAAGATGTCGGCAACCGC -> CAAAGATGTCGGCAACCGCC
# GCAACCGCCCCGCGTGACAT -> CAACCGCCCCGCGTGACATC
# GCAACGCAGTACTATGCCTA -> CAACGCAGTACTATGCCTAA
# GCAAGAGGGAGGACGACGGG -> CAAGAGGGAGGACGACGGGG
# GCAAGGGTTGTGGTATGTCC -> CAAGGGTTGTGGTATGTCCC
# GCAATATGGCACGTTCACAG -> CAATATGGCACGTTCACAGG
# GCACCAGATATCAGGGGGGG -> CACCAGATATCAGGGGGGGT
# GCACCTGCGGTGGAAGACGT -> CACCTGCGGTGGAAGACGTA
# GCACCTTATTCCGTTACCAT -> CACCTTATTCCGTTACCATA
# GCACGGCGTGGAAGGCCAAT -> CACGGCGTGGAAGGCCAATT
# GCACGTTCACAGGTCAACAC -> CACGTTCACAGGTCAACACG
# GCACTGGGGACGCCGCAAGA -> CACTGGGGACGCCGCAAGAG
# GCAGCTGAACGTAGAAGCTA -> CAGCTGAACGTAGAAGCTAA
# GCAGGCTCGCCCAGGGGCCG -> CAGGCTCGCCCAGGGGCCGC
# GCAGTACTATGCCTAACTTA -> CAGTACTATGCCTAACTTAT
# GCAGTTTCCCGGACTCTGAG -> CAGTTTCCCGGACTCTGAGG
# GCATTCATAGGGCTATTATA -> CATTCATAGGGCTATTATAG
# GCCAATTGAGCCCGTGGTCC -> CCAATTGAGCCCGTGGTCCA
# GCCACCCGAACTGCCATTAT -> CCACCCGAACTGCCATTATC
# GCCAGACTTCTCGCACCTTA -> CCAGACTTCTCGCACCTTAT
# GCCAGCCCATTGGATTGTCG -> CCAGCCCATTGGATTGTCGC
# GCCAGTGTGACTACTGAGCG -> CCAGTGTGACTACTGAGCGG
# GCCATAGCTTAACAGTCACG -> CCATAGCTTAACAGTCACGT
# GCCATTATCTCTAGCTATGG -> CCATTATCTCTAGCTATGGC
# GCCCAGGGGCCGCCAGACTT -> CCCAGGGGCCGCCAGACTTC
# GCCCATATAGATTAATAATG -> CCCATATAGATTAATAATGT
# GCCCATTGGATTGTCGCAAG -> CCCATTGGATTGTCGCAAGG
# GCCCCGCGTGACATCATAGT -> CCCCGCGTGACATCATAGTC
# GCCCGTGGTCCAAAGTCCGC -> CCCGTGGTCCAAAGTCCGCT
# GCCGCAAGAGGGAGGACGAC -> CCGCAAGAGGGAGGACGACG
# GCCGCCAGACTTCTCGCACC -> CCGCCAGACTTCTCGCACCT
# GCCGCCATAGCTTAACAGTC -> CCGCCATAGCTTAACAGTCA
# GCCTAACTTATTGATCAATT -> CCTAACTTATTGATCAATTG
# GCCTACGAAGCGAATCATTG -> CCTACGAAGCGAATCATTGC
# GCCTCAATAAGCTAGCTTAG -> CCTCAATAAGCTAGCTTAGA
# GCCTCGTAGCGAAAGCAGGC -> CCTCGTAGCGAAAGCAGGCT
# GCCTTCTTTAGAGGGAACCG -> CCTTCTTTAGAGGGAACCGT
# GCGAAAGCAGGCTCGCCCAG -> CGAAAGCAGGCTCGCCCAGG
# GCGAATCATTGCATTCATAG -> CGAATCATTGCATTCATAGG
# GCGGGCAATATGGCACGTTC -> CGGGCAATATGGCACGTTCA
# GCGGGTCTGTCACTTGGAAC -> CGGGTCTGTCACTTGGAACG
# GCGGTGGAAGACGTAACTCC -> CGGTGGAAGACGTAACTCCC
# GCGTAGGTAGAGTTCAAGTC -> CGTAGGTAGAGTTCAAGTCC
# GCGTCAACGCTAATAGAGCT -> CGTCAACGCTAATAGAGCTA
# GCGTCCGCTCCGCGTAGGTA -> CGTCCGCTCCGCGTAGGTAG
# GCGTGACATCATAGTCGCTT -> CGTGACATCATAGTCGCTTT
# GCGTGGAAGGCCAATTGAGC -> CGTGGAAGGCCAATTGAGCC
# GCGTTACCCCCCTTTCTTCG -> CGTTACCCCCCTTTCTTCGC
# GCTAAATGCACGGCGTGGAA -> CTAAATGCACGGCGTGGAAG
# GCTAACGGTCGTAACAATTG -> CTAACGGTCGTAACAATTGT
# GCTAAGCTAACGGTCGTAAC -> CTAAGCTAACGGTCGTAACA
# GCTAATAGAGCTAAATGCAC -> CTAATAGAGCTAAATGCACG
# GCTAGCTTAGATAGAAGATC -> CTAGCTTAGATAGAAGATCC
# GCTATGGCAACGCAGTACTA -> CTATGGCAACGCAGTACTAT
# GCTATTATAGGCTGTGTCAT -> CTATTATAGGCTGTGTCATG
# GCTATTCAACTGATTGTACA -> CTATTCAACTGATTGTACAT
# GCTATTGCGTTACCCCCCTT -> CTATTGCGTTACCCCCCTTT
# GCTCAGCTTCCACAAGTATA -> CTCAGCTTCCACAAGTATAC
# GCTCCGCGTAGGTAGAGTTC -> CTCCGCGTAGGTAGAGTTCA
# GCTCGCCACCCGAACTGCCA -> CTCGCCACCCGAACTGCCAT
# GCTCGCCCAGGGGCCGCCAG -> CTCGCCCAGGGGCCGCCAGA
# GCTGAACGTAGAAGCTAAGC -> CTGAACGTAGAAGCTAAGCT
# GCTGGACACTTCTTTAGTTC -> CTGGACACTTCTTTAGTTCT
# GCTGGACGGATAGTGTCCCT -> CTGGACGGATAGTGTCCCTA
# GCTGGATTTCTGACAGCACC -> CTGGATTTCTGACAGCACCT
# GCTGTGTCATGCCGCCATAG -> CTGTGTCATGCCGCCATAGC
# GCTTAACAGTCACGTATATT -> CTTAACAGTCACGTATATTT
# GCTTAGATAGAAGATCCATT -> CTTAGATAGAAGATCCATTA
# GCTTCCACAAGTATACCGAG -> CTTCCACAAGTATACCGAGC
# GCTTTTCTGCCTCAATAAGC -> CTTTTCTGCCTCAATAAGCT
# GGAACCGTAGTGCCAGCCCA -> GAACCGTAGTGCCAGCCCAT
# GGAACGATCCCAAATCGGGC -> GAACGATCCCAAATCGGGCT
# GGAAGACGTAACTCCCGCTA -> GAAGACGTAACTCCCGCTAT
# GGAAGGCCAATTGAGCCCGT -> GAAGGCCAATTGAGCCCGTG
# GGAAGGTCGGACCCATCCTC -> GAAGGTCGGACCCATCCTCA
# GGAAGTTGGGAAGGTCGGAC -> GAAGTTGGGAAGGTCGGACC
# GGACACTTCTTTAGTTCTTG -> GACACTTCTTTAGTTCTTGA
# GGACATCGGGAGATCGGGGC -> GACATCGGGAGATCGGGGCG
# GGACCCATCCTCAGATTAGA -> GACCCATCCTCAGATTAGAT
# GGACGACGGGGGGCTGGACG -> GACGACGGGGGGCTGGACGG
# GGACGCCGCAAGAGGGAGGA -> GACGCCGCAAGAGGGAGGAC
# GGACGGATAGTGTCCCTACT -> GACGGATAGTGTCCCTACTA
# GGACTCTGAGGAAGTTGGGA -> GACTCTGAGGAAGTTGGGAA
# GGAGATCGGGGCGGGTCTGT -> GAGATCGGGGCGGGTCTGTC
# GGAGGACGACGGGGGGCTGG -> GAGGACGACGGGGGGCTGGA
# GGATAGTGTCCCTACTAGTA -> GATAGTGTCCCTACTAGTAT
# GGATTGTCGCAAGGGTTGTG -> GATTGTCGCAAGGGTTGTGG
# GGATTTCTGACAGCACCTGC -> GATTTCTGACAGCACCTGCG
# GGCAAAGATGTCGGCAACCG -> GCAAAGATGTCGGCAACCGC
# GGCAACCGCCCCGCGTGACA -> GCAACCGCCCCGCGTGACAT
# GGCAACGCAGTACTATGCCT -> GCAACGCAGTACTATGCCTA
# GGCAATATGGCACGTTCACA -> GCAATATGGCACGTTCACAG
# GGCACGTTCACAGGTCAACA -> GCACGTTCACAGGTCAACAC
# GGCACTGGGGACGCCGCAAG -> GCACTGGGGACGCCGCAAGA
# GGCAGCTGAACGTAGAAGCT -> GCAGCTGAACGTAGAAGCTA
# GGCCAATTGAGCCCGTGGTC -> GCCAATTGAGCCCGTGGTCC
# GGCCGCCAGACTTCTCGCAC -> GCCGCCAGACTTCTCGCACC
# GGCCTTCTTTAGAGGGAACC -> GCCTTCTTTAGAGGGAACCG
# GGCGGGTCTGTCACTTGGAA -> GCGGGTCTGTCACTTGGAAC
# GGCGTGGAAGGCCAATTGAG -> GCGTGGAAGGCCAATTGAGC
# GGCTATTATAGGCTGTGTCA -> GCTATTATAGGCTGTGTCAT
# GGCTCAGCTTCCACAAGTAT -> GCTCAGCTTCCACAAGTATA
# GGCTCGCCCAGGGGCCGCCA -> GCTCGCCCAGGGGCCGCCAG
# GGCTGGACACTTCTTTAGTT -> GCTGGACACTTCTTTAGTTC
# GGCTGGACGGATAGTGTCCC -> GCTGGACGGATAGTGTCCCT
# GGCTGTGTCATGCCGCCATA -> GCTGTGTCATGCCGCCATAG
# GGGAACCGTAGTGCCAGCCC -> GGAACCGTAGTGCCAGCCCA
# GGGAAGGTCGGACCCATCCT -> GGAAGGTCGGACCCATCCTC
# GGGACGCCGCAAGAGGGAGG -> GGACGCCGCAAGAGGGAGGA
# GGGAGATCGGGGCGGGTCTG -> GGAGATCGGGGCGGGTCTGT
# GGGAGGACGACGGGGGGCTG -> GGAGGACGACGGGGGGCTGG
# GGGCAATATGGCACGTTCAC -> GGCAATATGGCACGTTCACA
# GGGCAGCTGAACGTAGAAGC -> GGCAGCTGAACGTAGAAGCT
# GGGCCGCCAGACTTCTCGCA -> GGCCGCCAGACTTCTCGCAC
# GGGCGGGTCTGTCACTTGGA -> GGCGGGTCTGTCACTTGGAA
# GGGCTATTATAGGCTGTGTC -> GGCTATTATAGGCTGTGTCA
# GGGCTCAGCTTCCACAAGTA -> GGCTCAGCTTCCACAAGTAT
# GGGCTGGACGGATAGTGTCC -> GGCTGGACGGATAGTGTCCC
# GGGGACGCCGCAAGAGGGAG -> GGGACGCCGCAAGAGGGAGG
# GGGGCAGCTGAACGTAGAAG -> GGGCAGCTGAACGTAGAAGC
# GGGGCCGCCAGACTTCTCGC -> GGGCCGCCAGACTTCTCGCA
# GGGGCGGGTCTGTCACTTGG -> GGGCGGGTCTGTCACTTGGA
# GGGGCTGGACGGATAGTGTC -> GGGCTGGACGGATAGTGTCC
# GGGGGCTGGACGGATAGTGT -> GGGGCTGGACGGATAGTGTC
# GGGGGGCTGGACGGATAGTG -> GGGGGCTGGACGGATAGTGT
# GGGGGGGTCGAGATTTGTCT -> GGGGGGTCGAGATTTGTCTC
# GGGGGGTCGAGATTTGTCTC -> GGGGGTCGAGATTTGTCTCT
# GGGGGTCGAGATTTGTCTCT -> GGGGTCGAGATTTGTCTCTC
# GGGGTCGAGATTTGTCTCTC -> GGGTCGAGATTTGTCTCTCG
# GGGTCGAGATTTGTCTCTCG -> GGTCGAGATTTGTCTCTCGG
# GGGTCTGTCACTTGGAACGA -> GGTCTGTCACTTGGAACGAT
# GGGTTGTGGTATGTCCCGCA -> GGTTGTGGTATGTCCCGCAC
# GGTAGAGTTCAAGTCCGATA -> GTAGAGTTCAAGTCCGATAC
# GGTATGTCCCGCACCAGATA -> GTATGTCCCGCACCAGATAT
# GGTCAACACGAAATGTGACA -> GTCAACACGAAATGTGACAA
# GGTCCAAAGTCCGCTCGCCA -> GTCCAAAGTCCGCTCGCCAC
# GGTCGAGATTTGTCTCTCGG -> GTCGAGATTTGTCTCTCGGC
# GGTCGGACCCATCCTCAGAT -> GTCGGACCCATCCTCAGATT
# GGTCGTAACAATTGTTGCCC -> GTCGTAACAATTGTTGCCCA
# GGTCTGTCACTTGGAACGAT -> GTCTGTCACTTGGAACGATC
# GGTGGAAGACGTAACTCCCG -> GTGGAAGACGTAACTCCCGC
# GGTTGTGGTATGTCCCGCAC -> GTTGTGGTATGTCCCGCACC
# GTAACAATTGTTGCCCATAT -> TAACAATTGTTGCCCATATA
# GTAACTCCCGCTATTCAACT -> TAACTCCCGCTATTCAACTG
# GTACATGCGTCAACGCTAAT -> TACATGCGTCAACGCTAATA
# GTACGGCCTTCTTTAGAGGG -> TACGGCCTTCTTTAGAGGGA
# GTACTATGCCTAACTTATTG -> TACTATGCCTAACTTATTGA
# GTAGAAGCTAAGCTAACGGT -> TAGAAGCTAAGCTAACGGTC
# GTAGAGTTCAAGTCCGATAC -> TAGAGTTCAAGTCCGATACT
# GTAGCGAAAGCAGGCTCGCC -> TAGCGAAAGCAGGCTCGCCC
# GTAGGTAGAGTTCAAGTCCG -> TAGGTAGAGTTCAAGTCCGA
# GTAGTGCCAGCCCATTGGAT -> TAGTGCCAGCCCATTGGATT
# GTATACCGAGCTGGATTTCT -> TATACCGAGCTGGATTTCTG
# GTATATTTTTCAACTGGGGC -> TATATTTTTCAACTGGGGCA
# GTATGTCCCGCACCAGATAT -> TATGTCCCGCACCAGATATC
# GTATTGTGGGAGACGGTGAG -> TATTGTGGGAGACGGTGAGT
# GTCAACACGAAATGTGACAA -> TCAACACGAAATGTGACAAC
# GTCAACGCTAATAGAGCTAA -> TCAACGCTAATAGAGCTAAA
# GTCACGTATATTTTTCAACT -> TCACGTATATTTTTCAACTG
# GTCACTTGGAACGATCCCAA -> TCACTTGGAACGATCCCAAA
# GTCATGCCGCCATAGCTTAA -> TCATGCCGCCATAGCTTAAC
# GTCCAAAGTCCGCTCGCCAC -> TCCAAAGTCCGCTCGCCACC
# GTCCCGCACCAGATATCAGG -> TCCCGCACCAGATATCAGGG
# GTCCCTACTAGTATTGTGGG -> TCCCTACTAGTATTGTGGGA
# GTCCGATACTGCCTACGAAG -> TCCGATACTGCCTACGAAGC
# GTCCGCTCCGCGTAGGTAGA -> TCCGCTCCGCGTAGGTAGAG
# GTCCGCTCGCCACCCGAACT -> TCCGCTCGCCACCCGAACTG
# GTCGAGATTTGTCTCTCGGC -> TCGAGATTTGTCTCTCGGCA
# GTCGCAAGGGTTGTGGTATG -> TCGCAAGGGTTGTGGTATGT
# GTCGCTTTTCTGCCTCAATA -> TCGCTTTTCTGCCTCAATAA
# GTCGGACCCATCCTCAGATT -> TCGGACCCATCCTCAGATTA
# GTCGGCAACCGCCCCGCGTG -> TCGGCAACCGCCCCGCGTGA
# GTCGTAACAATTGTTGCCCA -> TCGTAACAATTGTTGCCCAT
# GTCTCTCGGCAAAGATGTCG -> TCTCTCGGCAAAGATGTCGG
# GTCTGTCACTTGGAACGATC -> TCTGTCACTTGGAACGATCC
# GTGACAACGGACATCGGGAG -> TGACAACGGACATCGGGAGA
# GTGACATCATAGTCGCTTTT -> TGACATCATAGTCGCTTTTC
# GTGACTACTGAGCGGGCAAT -> TGACTACTGAGCGGGCAATA
# GTGCCAGCCCATTGGATTGT -> TGCCAGCCCATTGGATTGTC
# GTGGAAGACGTAACTCCCGC -> TGGAAGACGTAACTCCCGCT
# GTGGAAGGCCAATTGAGCCC -> TGGAAGGCCAATTGAGCCCG
# GTGGCTGGACACTTCTTTAG -> TGGCTGGACACTTCTTTAGT
# GTGGTATGTCCCGCACCAGA -> TGGTATGTCCCGCACCAGAT
# GTGGTCCAAAGTCCGCTCGC -> TGGTCCAAAGTCCGCTCGCC
# GTGTCATGCCGCCATAGCTT -> TGTCATGCCGCCATAGCTTA
# GTGTCCCTACTAGTATTGTG -> TGTCCCTACTAGTATTGTGG
# GTGTGACTACTGAGCGGGCA -> TGTGACTACTGAGCGGGCAA
# GTTACCATAGCCAGTGTGAC -> TTACCATAGCCAGTGTGACT
# GTTACCCCCCTTTCTTCGCA -> TTACCCCCCTTTCTTCGCAG
# GTTCAAGTCCGATACTGCCT -> TTCAAGTCCGATACTGCCTA
# GTTCACAGGTCAACACGAAA -> TTCACAGGTCAACACGAAAT
# GTTCTTGAGCTATTGCGTTA -> TTCTTGAGCTATTGCGTTAC
# GTTGCCCATATAGATTAATA -> TTGCCCATATAGATTAATAA
# GTTGGGAAGGTCGGACCCAT -> TTGGGAAGGTCGGACCCATC
# GTTGTGGTATGTCCCGCACC -> TTGTGGTATGTCCCGCACCA
# GTTTCCCGGACTCTGAGGAA -> TTTCCCGGACTCTGAGGAAG
# TAAAATTATCGCGTCCGCTC -> AAAATTATCGCGTCCGCTCC
# TAAATGCACGGCGTGGAAGG -> AAATGCACGGCGTGGAAGGC
# TAACAATTGTTGCCCATATA -> AACAATTGTTGCCCATATAG
# TAACAGTCACGTATATTTTT -> AACAGTCACGTATATTTTTC
# TAACGGTCGTAACAATTGTT -> AACGGTCGTAACAATTGTTG
# TAACTCCCGCTATTCAACTG -> AACTCCCGCTATTCAACTGA
# TAACTTATTGATCAATTGAA -> AACTTATTGATCAATTGAAC
# TAAGCTAACGGTCGTAACAA -> AAGCTAACGGTCGTAACAAT
# TAAGCTAGCTTAGATAGAAG -> AAGCTAGCTTAGATAGAAGA
# TAATAATGTACGGCCTTCTT -> AATAATGTACGGCCTTCTTT
# TAATAGAGCTAAATGCACGG -> AATAGAGCTAAATGCACGGC
# TAATGTACGGCCTTCTTTAG -> AATGTACGGCCTTCTTTAGA
# TACATGCGTCAACGCTAATA -> ACATGCGTCAACGCTAATAG
# TACCATAGCCAGTGTGACTA -> ACCATAGCCAGTGTGACTAC
# TACCCCCCTTTCTTCGCAGT -> ACCCCCCTTTCTTCGCAGTT
# TACCGAGCTGGATTTCTGAC -> ACCGAGCTGGATTTCTGACA
# TACGAAGCGAATCATTGCAT -> ACGAAGCGAATCATTGCATT
# TACGGCCTTCTTTAGAGGGA -> ACGGCCTTCTTTAGAGGGAA
# TACTAGTATTGTGGGAGACG -> ACTAGTATTGTGGGAGACGG
# TACTATGCCTAACTTATTGA -> ACTATGCCTAACTTATTGAT
# TACTGAGCGGGCAATATGGC -> ACTGAGCGGGCAATATGGCA
# TACTGCCTACGAAGCGAATC -> ACTGCCTACGAAGCGAATCA
# TAGAAGATCCATTATCTGGC -> AGAAGATCCATTATCTGGCA
# TAGAAGCTAAGCTAACGGTC -> AGAAGCTAAGCTAACGGTCG
# TAGAGCTAAATGCACGGCGT -> AGAGCTAAATGCACGGCGTG
# TAGAGGGAACCGTAGTGCCA -> AGAGGGAACCGTAGTGCCAG
# TAGAGTTCAAGTCCGATACT -> AGAGTTCAAGTCCGATACTG
# TAGATAGAAGATCCATTATC -> AGATAGAAGATCCATTATCT
# TAGATCTAAAATTATCGCGT -> AGATCTAAAATTATCGCGTC
# TAGATTAATAATGTACGGCC -> AGATTAATAATGTACGGCCT
# TAGCCAGTGTGACTACTGAG -> AGCCAGTGTGACTACTGAGC
# TAGCGAAAGCAGGCTCGCCC -> AGCGAAAGCAGGCTCGCCCA
# TAGCTATGGCAACGCAGTAC -> AGCTATGGCAACGCAGTACT
# TAGCTTAACAGTCACGTATA -> AGCTTAACAGTCACGTATAT
# TAGCTTAGATAGAAGATCCA -> AGCTTAGATAGAAGATCCAT
# TAGGCTGTGTCATGCCGCCA -> AGGCTGTGTCATGCCGCCAT
# TAGGGCTATTATAGGCTGTG -> AGGGCTATTATAGGCTGTGT
# TAGGTAGAGTTCAAGTCCGA -> AGGTAGAGTTCAAGTCCGAT
# TAGTATTGTGGGAGACGGTG -> AGTATTGTGGGAGACGGTGA
# TAGTCGCTTTTCTGCCTCAA -> AGTCGCTTTTCTGCCTCAAT
# TAGTGCCAGCCCATTGGATT -> AGTGCCAGCCCATTGGATTG
# TAGTGTCCCTACTAGTATTG -> AGTGTCCCTACTAGTATTGT
# TAGTTCTTGAGCTATTGCGT -> AGTTCTTGAGCTATTGCGTT
# TATACCGAGCTGGATTTCTG -> ATACCGAGCTGGATTTCTGA
# TATAGATTAATAATGTACGG -> ATAGATTAATAATGTACGGC
# TATAGGCTGTGTCATGCCGC -> ATAGGCTGTGTCATGCCGCC
# TATATTTTTCAACTGGGGCA -> ATATTTTTCAACTGGGGCAG
# TATCAGGGGGGGTCGAGATT -> ATCAGGGGGGGTCGAGATTT
# TATCGCGTCCGCTCCGCGTA -> ATCGCGTCCGCTCCGCGTAG
# TATCTCTAGCTATGGCAACG -> ATCTCTAGCTATGGCAACGC
# TATCTGGCACTGGGGACGCC -> ATCTGGCACTGGGGACGCCG
# TATGCCTAACTTATTGATCA -> ATGCCTAACTTATTGATCAA
# TATGGCAACGCAGTACTATG -> ATGGCAACGCAGTACTATGC
# TATGGCACGTTCACAGGTCA -> ATGGCACGTTCACAGGTCAA
# TATGTCCCGCACCAGATATC -> ATGTCCCGCACCAGATATCA
# TATTATAGGCTGTGTCATGC -> ATTATAGGCTGTGTCATGCC
# TATTCAACTGATTGTACATG -> ATTCAACTGATTGTACATGC
# TATTCCGTTACCATAGCCAG -> ATTCCGTTACCATAGCCAGT
# TATTGATCAATTGAACTTCG -> ATTGATCAATTGAACTTCGT
# TATTGCGTTACCCCCCTTTC -> ATTGCGTTACCCCCCTTTCT
# TATTGTGGGAGACGGTGAGT -> ATTGTGGGAGACGGTGAGTG
# TATTTTTCAACTGGGGCAGC -> ATTTTTCAACTGGGGCAGCT
# TCAACACGAAATGTGACAAC -> CAACACGAAATGTGACAACG
# TCAACGCTAATAGAGCTAAA -> CAACGCTAATAGAGCTAAAT
# TCAACTGATTGTACATGCGT -> CAACTGATTGTACATGCGTC
# TCAACTGGGGCAGCTGAACG -> CAACTGGGGCAGCTGAACGT
# TCAAGTCCGATACTGCCTAC -> CAAGTCCGATACTGCCTACG
# TCAATAAGCTAGCTTAGATA -> CAATAAGCTAGCTTAGATAG
# TCAATTGAACTTCGTGGCTG -> CAATTGAACTTCGTGGCTGG
# TCACAGGTCAACACGAAATG -> CACAGGTCAACACGAAATGT
# TCACGTATATTTTTCAACTG -> CACGTATATTTTTCAACTGG
# TCACTTGGAACGATCCCAAA -> CACTTGGAACGATCCCAAAT
# TCAGATTAGATCTAAAATTA -> CAGATTAGATCTAAAATTAT
# TCAGCTTCCACAAGTATACC -> CAGCTTCCACAAGTATACCG
# TCAGGGGGGGTCGAGATTTG -> CAGGGGGGGTCGAGATTTGT
# TCATAGGGCTATTATAGGCT -> CATAGGGCTATTATAGGCTG
# TCATAGTCGCTTTTCTGCCT -> CATAGTCGCTTTTCTGCCTC
# TCATGCCGCCATAGCTTAAC -> CATGCCGCCATAGCTTAACA
# TCATTGCATTCATAGGGCTA -> CATTGCATTCATAGGGCTAT
# TCCAAAGTCCGCTCGCCACC -> CCAAAGTCCGCTCGCCACCC
# TCCACAAGTATACCGAGCTG -> CCACAAGTATACCGAGCTGG
# TCCATTATCTGGCACTGGGG -> CCATTATCTGGCACTGGGGA
# TCCCAAATCGGGCTCAGCTT -> CCCAAATCGGGCTCAGCTTC
# TCCCGCACCAGATATCAGGG -> CCCGCACCAGATATCAGGGG
# TCCCGCTATTCAACTGATTG -> CCCGCTATTCAACTGATTGT
# TCCCGGACTCTGAGGAAGTT -> CCCGGACTCTGAGGAAGTTG
# TCCCTACTAGTATTGTGGGA -> CCCTACTAGTATTGTGGGAG
# TCCGATACTGCCTACGAAGC -> CCGATACTGCCTACGAAGCG
# TCCGCGTAGGTAGAGTTCAA -> CCGCGTAGGTAGAGTTCAAG
# TCCGCTCCGCGTAGGTAGAG -> CCGCTCCGCGTAGGTAGAGT
# TCCGCTCGCCACCCGAACTG -> CCGCTCGCCACCCGAACTGC
# TCCGTTACCATAGCCAGTGT -> CCGTTACCATAGCCAGTGTG
# TCCTCAGATTAGATCTAAAA -> CCTCAGATTAGATCTAAAAT
# TCGAGATTTGTCTCTCGGCA -> CGAGATTTGTCTCTCGGCAA
# TCGCAAGGGTTGTGGTATGT -> CGCAAGGGTTGTGGTATGTC
# TCGCACCTTATTCCGTTACC -> CGCACCTTATTCCGTTACCA
# TCGCAGTTTCCCGGACTCTG -> CGCAGTTTCCCGGACTCTGA
# TCGCCACCCGAACTGCCATT -> CGCCACCCGAACTGCCATTA
# TCGCCCAGGGGCCGCCAGAC -> CGCCCAGGGGCCGCCAGACT
# TCGCGTCCGCTCCGCGTAGG -> CGCGTCCGCTCCGCGTAGGT
# TCGCTTTTCTGCCTCAATAA -> CGCTTTTCTGCCTCAATAAG
# TCGGACCCATCCTCAGATTA -> CGGACCCATCCTCAGATTAG
# TCGGCAAAGATGTCGGCAAC -> CGGCAAAGATGTCGGCAACC
# TCGGCAACCGCCCCGCGTGA -> CGGCAACCGCCCCGCGTGAC
# TCGGGAGATCGGGGCGGGTC -> CGGGAGATCGGGGCGGGTCT
# TCGGGCTCAGCTTCCACAAG -> CGGGCTCAGCTTCCACAAGT
# TCGGGGCGGGTCTGTCACTT -> CGGGGCGGGTCTGTCACTTG
# TCGTAACAATTGTTGCCCAT -> CGTAACAATTGTTGCCCATA
# TCGTAGCGAAAGCAGGCTCG -> CGTAGCGAAAGCAGGCTCGC
# TCGTGGCTGGACACTTCTTT -> CGTGGCTGGACACTTCTTTA
# TCTAAAATTATCGCGTCCGC -> CTAAAATTATCGCGTCCGCT
# TCTAGCTATGGCAACGCAGT -> CTAGCTATGGCAACGCAGTA
# TCTCGCACCTTATTCCGTTA -> CTCGCACCTTATTCCGTTAC
# TCTCGGCAAAGATGTCGGCA -> CTCGGCAAAGATGTCGGCAA
# TCTCTAGCTATGGCAACGCA -> CTCTAGCTATGGCAACGCAG
# TCTCTCGGCAAAGATGTCGG -> CTCTCGGCAAAGATGTCGGC
# TCTGACAGCACCTGCGGTGG -> CTGACAGCACCTGCGGTGGA
# TCTGAGGAAGTTGGGAAGGT -> CTGAGGAAGTTGGGAAGGTC
# TCTGCCTCAATAAGCTAGCT -> CTGCCTCAATAAGCTAGCTT
# TCTGGCACTGGGGACGCCGC -> CTGGCACTGGGGACGCCGCA
# TCTGTCACTTGGAACGATCC -> CTGTCACTTGGAACGATCCC
# TCTTCGCAGTTTCCCGGACT -> CTTCGCAGTTTCCCGGACTC
# TCTTGAGCTATTGCGTTACC -> CTTGAGCTATTGCGTTACCC
# TCTTGCCTCGTAGCGAAAGC -> CTTGCCTCGTAGCGAAAGCA
# TCTTTAGAGGGAACCGTAGT -> CTTTAGAGGGAACCGTAGTG
# TCTTTAGTTCTTGAGCTATT -> CTTTAGTTCTTGAGCTATTG
# TGAACGTAGAAGCTAAGCTA -> GAACGTAGAAGCTAAGCTAA
# TGAACTTCGTGGCTGGACAC -> GAACTTCGTGGCTGGACACT
# TGACAACGGACATCGGGAGA -> GACAACGGACATCGGGAGAT
# TGACAGCACCTGCGGTGGAA -> GACAGCACCTGCGGTGGAAG
# TGACATCATAGTCGCTTTTC -> GACATCATAGTCGCTTTTCT
# TGACTACTGAGCGGGCAATA -> GACTACTGAGCGGGCAATAT
# TGAGCCCGTGGTCCAAAGTC -> GAGCCCGTGGTCCAAAGTCC
# TGAGCGGGCAATATGGCACG -> GAGCGGGCAATATGGCACGT
# TGAGCTATTGCGTTACCCCC -> GAGCTATTGCGTTACCCCCC
# TGAGGAAGTTGGGAAGGTCG -> GAGGAAGTTGGGAAGGTCGG
# TGATCAATTGAACTTCGTGG -> GATCAATTGAACTTCGTGGC
# TGATTGTACATGCGTCAACG -> GATTGTACATGCGTCAACGC
# TGCACGGCGTGGAAGGCCAA -> GCACGGCGTGGAAGGCCAAT
# TGCATTCATAGGGCTATTAT -> GCATTCATAGGGCTATTATA
# TGCCAGCCCATTGGATTGTC -> GCCAGCCCATTGGATTGTCG
# TGCCATTATCTCTAGCTATG -> GCCATTATCTCTAGCTATGG
# TGCCCATATAGATTAATAAT -> GCCCATATAGATTAATAATG
# TGCCGCCATAGCTTAACAGT -> GCCGCCATAGCTTAACAGTC
# TGCCTAACTTATTGATCAAT -> GCCTAACTTATTGATCAATT
# TGCCTACGAAGCGAATCATT -> GCCTACGAAGCGAATCATTG
# TGCCTCAATAAGCTAGCTTA -> GCCTCAATAAGCTAGCTTAG
# TGCCTCGTAGCGAAAGCAGG -> GCCTCGTAGCGAAAGCAGGC
# TGCGGTGGAAGACGTAACTC -> GCGGTGGAAGACGTAACTCC
# TGCGTCAACGCTAATAGAGC -> GCGTCAACGCTAATAGAGCT
# TGCGTTACCCCCCTTTCTTC -> GCGTTACCCCCCTTTCTTCG
# TGGAACGATCCCAAATCGGG -> GGAACGATCCCAAATCGGGC
# TGGAAGACGTAACTCCCGCT -> GGAAGACGTAACTCCCGCTA
# TGGAAGGCCAATTGAGCCCG -> GGAAGGCCAATTGAGCCCGT
# TGGACACTTCTTTAGTTCTT -> GGACACTTCTTTAGTTCTTG
# TGGACGGATAGTGTCCCTAC -> GGACGGATAGTGTCCCTACT
# TGGATTGTCGCAAGGGTTGT -> GGATTGTCGCAAGGGTTGTG
# TGGATTTCTGACAGCACCTG -> GGATTTCTGACAGCACCTGC
# TGGCAACGCAGTACTATGCC -> GGCAACGCAGTACTATGCCT
# TGGCACGTTCACAGGTCAAC -> GGCACGTTCACAGGTCAACA
# TGGCACTGGGGACGCCGCAA -> GGCACTGGGGACGCCGCAAG
# TGGCTGGACACTTCTTTAGT -> GGCTGGACACTTCTTTAGTT
# TGGGAAGGTCGGACCCATCC -> GGGAAGGTCGGACCCATCCT
# TGGGGACGCCGCAAGAGGGA -> GGGGACGCCGCAAGAGGGAG
# TGGGGCAGCTGAACGTAGAA -> GGGGCAGCTGAACGTAGAAG
# TGGTATGTCCCGCACCAGAT -> GGTATGTCCCGCACCAGATA
# TGGTCCAAAGTCCGCTCGCC -> GGTCCAAAGTCCGCTCGCCA
# TGTACATGCGTCAACGCTAA -> GTACATGCGTCAACGCTAAT
# TGTACGGCCTTCTTTAGAGG -> GTACGGCCTTCTTTAGAGGG
# TGTCACTTGGAACGATCCCA -> GTCACTTGGAACGATCCCAA
# TGTCATGCCGCCATAGCTTA -> GTCATGCCGCCATAGCTTAA
# TGTCCCGCACCAGATATCAG -> GTCCCGCACCAGATATCAGG
# TGTCCCTACTAGTATTGTGG -> GTCCCTACTAGTATTGTGGG
# TGTCGCAAGGGTTGTGGTAT -> GTCGCAAGGGTTGTGGTATG
# TGTCGGCAACCGCCCCGCGT -> GTCGGCAACCGCCCCGCGTG
# TGTCTCTCGGCAAAGATGTC -> GTCTCTCGGCAAAGATGTCG
# TGTGACAACGGACATCGGGA -> GTGACAACGGACATCGGGAG
# TGTGACTACTGAGCGGGCAA -> GTGACTACTGAGCGGGCAAT
# TGTGGTATGTCCCGCACCAG -> GTGGTATGTCCCGCACCAGA
# TGTGTCATGCCGCCATAGCT -> GTGTCATGCCGCCATAGCTT
# TGTTGCCCATATAGATTAAT -> GTTGCCCATATAGATTAATA
# TTAACAGTCACGTATATTTT -> TAACAGTCACGTATATTTTT
# TTAATAATGTACGGCCTTCT -> TAATAATGTACGGCCTTCTT
# TTACCATAGCCAGTGTGACT -> TACCATAGCCAGTGTGACTA
# TTACCCCCCTTTCTTCGCAG -> TACCCCCCTTTCTTCGCAGT
# TTAGAGGGAACCGTAGTGCC -> TAGAGGGAACCGTAGTGCCA
# TTAGATAGAAGATCCATTAT -> TAGATAGAAGATCCATTATC
# TTAGATCTAAAATTATCGCG -> TAGATCTAAAATTATCGCGT
# TTAGTTCTTGAGCTATTGCG -> TAGTTCTTGAGCTATTGCGT
# TTATAGGCTGTGTCATGCCG -> TATAGGCTGTGTCATGCCGC
# TTATCGCGTCCGCTCCGCGT -> TATCGCGTCCGCTCCGCGTA
# TTATCTCTAGCTATGGCAAC -> TATCTCTAGCTATGGCAACG
# TTATCTGGCACTGGGGACGC -> TATCTGGCACTGGGGACGCC
# TTATTCCGTTACCATAGCCA -> TATTCCGTTACCATAGCCAG
# TTATTGATCAATTGAACTTC -> TATTGATCAATTGAACTTCG
# TTCAACTGATTGTACATGCG -> TCAACTGATTGTACATGCGT
# TTCAACTGGGGCAGCTGAAC -> TCAACTGGGGCAGCTGAACG
# TTCAAGTCCGATACTGCCTA -> TCAAGTCCGATACTGCCTAC
# TTCACAGGTCAACACGAAAT -> TCACAGGTCAACACGAAATG
# TTCATAGGGCTATTATAGGC -> TCATAGGGCTATTATAGGCT
# TTCCACAAGTATACCGAGCT -> TCCACAAGTATACCGAGCTG
# TTCCCGGACTCTGAGGAAGT -> TCCCGGACTCTGAGGAAGTT
# TTCCGTTACCATAGCCAGTG -> TCCGTTACCATAGCCAGTGT
# TTCGCAGTTTCCCGGACTCT -> TCGCAGTTTCCCGGACTCTG
# TTCGTGGCTGGACACTTCTT -> TCGTGGCTGGACACTTCTTT
# TTCTCGCACCTTATTCCGTT -> TCTCGCACCTTATTCCGTTA
# TTCTGACAGCACCTGCGGTG -> TCTGACAGCACCTGCGGTGG
# TTCTGCCTCAATAAGCTAGC -> TCTGCCTCAATAAGCTAGCT
# TTCTTCGCAGTTTCCCGGAC -> TCTTCGCAGTTTCCCGGACT
# TTCTTGAGCTATTGCGTTAC -> TCTTGAGCTATTGCGTTACC
# TTCTTGCCTCGTAGCGAAAG -> TCTTGCCTCGTAGCGAAAGC
# TTCTTTAGAGGGAACCGTAG -> TCTTTAGAGGGAACCGTAGT
# TTCTTTAGTTCTTGAGCTAT -> TCTTTAGTTCTTGAGCTATT
# TTGAACTTCGTGGCTGGACA -> TGAACTTCGTGGCTGGACAC
# TTGAGCCCGTGGTCCAAAGT -> TGAGCCCGTGGTCCAAAGTC
# TTGAGCTATTGCGTTACCCC -> TGAGCTATTGCGTTACCCCC
# TTGATCAATTGAACTTCGTG -> TGATCAATTGAACTTCGTGG
# TTGCATTCATAGGGCTATTA -> TGCATTCATAGGGCTATTAT
# TTGCCCATATAGATTAATAA -> TGCCCATATAGATTAATAAT
# TTGCCTCGTAGCGAAAGCAG -> TGCCTCGTAGCGAAAGCAGG
# TTGCGTTACCCCCCTTTCTT -> TGCGTTACCCCCCTTTCTTC
# TTGGAACGATCCCAAATCGG -> TGGAACGATCCCAAATCGGG
# TTGGATTGTCGCAAGGGTTG -> TGGATTGTCGCAAGGGTTGT
# TTGGGAAGGTCGGACCCATC -> TGGGAAGGTCGGACCCATCC
# TTGTACATGCGTCAACGCTA -> TGTACATGCGTCAACGCTAA
# TTGTCGCAAGGGTTGTGGTA -> TGTCGCAAGGGTTGTGGTAT
# TTGTCTCTCGGCAAAGATGT -> TGTCTCTCGGCAAAGATGTC
# TTGTGGTATGTCCCGCACCA -> TGTGGTATGTCCCGCACCAG
# TTGTTGCCCATATAGATTAA -> TGTTGCCCATATAGATTAAT
# TTTAGAGGGAACCGTAGTGC -> TTAGAGGGAACCGTAGTGCC
# TTTAGTTCTTGAGCTATTGC -> TTAGTTCTTGAGCTATTGCG
# TTTCAACTGGGGCAGCTGAA -> TTCAACTGGGGCAGCTGAAC
# TTTCCCGGACTCTGAGGAAG -> TTCCCGGACTCTGAGGAAGT
# TTTCTGACAGCACCTGCGGT -> TTCTGACAGCACCTGCGGTG
# TTTCTGCCTCAATAAGCTAG -> TTCTGCCTCAATAAGCTAGC
# TTTCTTCGCAGTTTCCCGGA -> TTCTTCGCAGTTTCCCGGAC
# TTTGTCTCTCGGCAAAGATG -> TTGTCTCTCGGCAAAGATGT
# TTTTCAACTGGGGCAGCTGA -> TTTCAACTGGGGCAGCTGAA
# TTTTCTGCCTCAATAAGCTA -> TTTCTGCCTCAATAAGCTAG
# TTTTTCAACTGGGGCAGCTG -> TTTTCAACTGGGGCAGCTGA

# %% [markdown]
# __CODE MARKDOWN CELL__
#
# problem10 contains class overlapGraph and a main
#
# class overlapGraph contains:
#
# def __ __init__ __(self, kmers) -- initializes necessary variables
#
# def __suffix__(self, pattern) -- last k − 1 nucleotides of k-mer
#
# def __prefix__(self, pattern) -- first k − 1 nucleotides of k-mer
#
# def __graph__(self) -- we form a graph having a node for each k-mer in Patterns
#
# def __print__(self) -- prints adjacency list
#
# __main__() reads from an input file and calls necessary methods

# %% [markdown]
# __INSPECTION MARKDOWN CELL__
#
# Junmo:
# Q8 ~ 12. Well written codes. They are readable and neat. I can easliy follow the codes. No other inspections are needed.
