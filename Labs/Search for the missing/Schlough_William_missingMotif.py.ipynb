# %%
# C:\Users\wwsch\anaconda3\python.exe
# Name: William Schlough (wschloug)
# Group Members: Junmo, Mikey, Wenyu

########################################################################
# FastAreader
# provided by Dr. B
########################################################################
import sys


class FastAreader:

    def __init__(self, fname=''):
        '''contructor: saves attribute fname '''

        self.fname = fname

    def doOpen(self):
        if self.fname is '':
            return sys.stdin
        else:
            return open(self.fname)

    def readFasta(self):

        header = ''
        sequence = ''

        with self.doOpen() as fileH:

            header = ''
            sequence = ''

            # skip to first fasta header
            line = fileH.readline()
            while not line.startswith('>'):
                line = fileH.readline()
            header = line[1:].rstrip()

            for line in fileH:
                if line.startswith('>'):
                    yield header, sequence
                    header = line[1:].rstrip()
                    sequence = ''
                else:
                    sequence += ''.join(line.rstrip().split()).upper()

        yield header, sequence

# %%
########################################################################
# CommandLine
# provided by Dr. B
########################################################################

class CommandLine():
    '''
    Handle the command line, usage and help requests.

    CommandLine uses argparse,
    it implements a standard command line argument parser with various argument options,
    a standard usage and help, and an error termination exception Usage.

    attributes:
    all arguments received from the commandline using .add_argument will be
    available within the .args attribute of an object instantiated from CommandLine.
    For example, if thisCommandLine is an object of the class, and requiredbool was
    set as an option using add_argument, then thisCommandLine.args.requiredbool will
    name that option.

    '''

    def __init__(self, inOpts=None):
        '''
        CommandLine constructor.

        Implement a parser to interpret the command line argv string using argparse.
        '''

        import argparse
        self.parser = argparse.ArgumentParser(
            description='Program prolog - a brief description of what this thing does',
            epilog='Program epilog - some other stuff you feel compelled to say',
            add_help=True,  # default is True
            prefix_chars='-',
            usage='python missingMotif.py -minMotif int -maxMotif int -cutoff int < input.fa > output.out'
        )

        # options as specified by assignment
        self.parser.add_argument('-minMotif', type=int, choices=range(3, 9), action='store', default=3,
                                 help='minimum motif size in integer format')
        self.parser.add_argument('-maxMotif', type=int, choices=range(3, 9), action='store', default=8,
                                 help='maximum motif size in integer format')
        self.parser.add_argument('-cutoff', type=int, action='store', default=0,
                                 help='z score cutoff in integer format')

        if inOpts is None:
            self.args = self.parser.parse_args()
        else:
            self.args = self.parser.parse_args(inOpts)


class Usage(Exception):
    '''
    Signal a Usage error, evoking a usage statement and eventual exit when raised.
    '''

    def __init__(self, msg):
        self.msg = msg

# %%
import math # needed for sqrt -- realized i could use **
########################################################################
# Genome
#
########################################################################
class Genome:
    '''

    class genome contains methods that are used to find the z-score, expected value, and count of all motifs

    setup --------------
    initialization
    z-score
    expected value
    motifcount / kmer list -- dict?

    way to get reverse compliment easily -- bme 160 method

    '''



    def __init__(self, seq, N, min, max, cutoff):
        '''


        seq -- input sequences taken from fastaReader
        N -- genome size (length of all sequences)
        min -- minimum motif size to look at (4?)
        max -- maximum motif size to look at (8)
        cutoff -- cutoff of z value (should be negative values -- more negative more deviation)

        '''

        self.seq = seq
        self.min = min
        self.max = max
        self.cutoff = cutoff

        self.kmerCounts = dict() # keep track of kmer + times found in seq (along with counting for reverse compliment too)

        self.N = N  # genome size

        for sequence in self.seq: # for each sequence
            for k in range(1, self.max+1): # for each motif
                for i in range(0, len(sequence) - k + 1): # find all motifs of that size
                    kmer = ''.join(sequence[i:i + k]) # kmer cut from i to k

                    # only look at top strand
                    if kmer in self.kmerCounts: # if kmer already exists
                        self.kmerCounts[kmer][0] += 1 # add one to the count
                    else:
                        self.kmerCounts[kmer] = [1]
                        self.kmerCounts[self.reverseSeq(kmer)] = self.kmerCounts[kmer] # set new key pointing to same

                    #if self.reverseSeq(kmer) in self.kmerCounts: # check if the reverse compliment is in dictionary
                        #self.kmerCounts[kmer] = self.kmerCounts[self.reverseSeq(kmer)]
                        #self.kmerCounts[kmer][0] += 1 # add one to the count of specified kmer

                    #elif kmer in self.kmerCounts: # else if its already in dictionary
                        #self.kmerCounts[kmer][0] += 1 # add 1 to the count of specified kmer

                    #else: # otherwise
                        #self.kmerCounts[kmer] = [1] # add it as a key with starting value 1 to dictionary

    def reverseSeq(self, sequence):
        '''

        used to find reverse compliment -- method taken from bme 160, very useful
        returns the reverse compliment

        https://www.w3schools.com/python/ref_string_translate.asp
        https://www.programiz.com/python-programming/methods/string/maketrans

        '''

        #(sequence.translate(str.maketrans("ATCG", "TAGC"))[::-1])
        return sequence.translate(str.maketrans("ATCG", "TAGC"))[::-1]

    def eVal(self, kmer):
        '''

        using markovian model -- left + right size + middle kmer are used to calculate escore
        calculates and returns the expected value of a specific motif appearing

        '''
        tail = len(kmer) - 1 # like middle
        left = kmer[:-1] # left kmer
        right = kmer[1:] # right kmer

        # consider counts of left side + right side of motif
        numerator = self.kmerCounts[left][0] * self.kmerCounts[right][0]

        # consider counts of middle part of motif
        denominator = self.kmerCounts[kmer[1:tail]][0]

        # divide the counts of left + right side of motif by the counts of middle part of motif
        return numerator / denominator

    def zScore(self, kmer):
        '''

        takes in -- a kmer that has eVal called on it to calculate the mean, calculates Pr(K),
                    then calculates the stand deviation, and lastly calculates a z-score
        returns a z-score

        For this assignment, we will use Z-scores.
        These will be negative since we are looking for underrepresented sequences (this cutoff needs to be a program option too)

        "A score that indicates how many standard deviations a value is above or below the mean."

        '''
        mean = self.eVal(kmer)
        N = self.N # "n = genome size (approximately)"
        p = mean / N # Pr(K) = E(K)/N -- N being length of genome, and we use eval() method for E(K)

        standardDev = math.sqrt(N * p * (1 - p))  # sqrt(np(1-p)


        zscore = (self.kmerCounts[kmer][0] - mean) / standardDev # calculate z score
        return zscore




    def kmerList(self):
        '''

        returns a sorted list containing the (kmer, reverse compliment, counts of both, e value, z score, motif size)
        the list is sorted first by motif size, and then by z score

        '''
        kmax = 8  # due to program requirements -- "We need only consider sequence motifs that are up to about 8 in length"
        kmerList = list()
        check = list()

        # check all keys
        for kmer in self.kmerCounts.keys():
            # kmer between min and max
            # reverse not yet added (using listcheck to see if kmer has been added yet or not)
            # zscore less than (but not including) cutoff
            if self.min <= len(kmer) <= self.max and \
                    self.reverseSeq(kmer) not in check and \
                    self.zScore(kmer) < self.cutoff:

                k = kmax - len(kmer) # max motif size
                # sequence: reverse     count      Expect Zscore
                kmerList.append([kmer,
                                 self.reverseSeq(kmer),
                                 self.kmerCounts[kmer][0],
                                 self.eVal(kmer),
                                 self.zScore(kmer),
                                 k]) # motif size
                check.append(kmer)

        # per program requirements -- "sorted by Zscore within motif-Size"
        # such that the longest motifs are at the beginning of the report and,
        # within motifs of a given size, print the most significant motifs first.
        # Print the k-mer pairs in alpha order.
        # ( AAA:TTT and not TTT:AAA)
        # kmerList sorted by (motif-size, then by z-score)
        return sorted(kmerList, key=lambda kmer:(kmer[5], kmer[4]))


def main(inFile, myCommandLine=None):
    '''
    Implement the Usage exception handler that can be raised from anywhere in process.

    used group member mikey's way of coding inFile argument into main
    '''
    if myCommandLine is None:
        myCommandLine = CommandLine()  # read options from the command line
    else:
        myCommandLine = CommandLine(myCommandLine)  # interpret the list passed from the caller of main as the commandline.

    seqList = []
    N = 0 # will keep track of genome size by counting length of each sequence passed by FastAreader,

    myReader = FastAreader(inFile) # <------  input .fa file here
    for head, seq in myReader.readFasta():
        seqList.append(seq)
        N += len(seq)

    myMotifs = Genome(seqList,
                      N, # then passed as a var in myMotifs = Genome() initialization
                      myCommandLine.args.minMotif,
                      myCommandLine.args.maxMotif,
                      myCommandLine.args.cutoff)

    kmerList = myMotifs.kmerList()
    print("N: {}".format(N))
    print("sequence:reverse \t\t count \t\t Expect \t\t Zscore")
    for kmer in kmerList:  # prints each kmer with respective data (in formatted order -- done through kmerList())
        print('{0:8}:{1:8} \t\t {2:0d} \t\t {3:0.2f} \t\t {4:0.2f}'.format(kmer[0], # kmer
                                                                           kmer[1][::-1], # reverse compliment kmer [::-1] to reverse the sequence to fit the output parameters
                                                                           kmer[2], # count
                                                                           kmer[3], # eValue
                                                                           kmer[4])) # z-score


if __name__ == "__main__":
    main(inFile='Arthrospira-platensis-NIES-39.fna',                     # <--------- put input filename here
         myCommandLine=['-minMotif= 3',
                        '-maxMotif= 8',
                        '-cutoff= -4']) # <------- put your min, max, and cutoff here
# Out:
# N: 6788435
# sequence:reverse 		 count 		 Expect 		 Zscore
# GCGATCGC:CGCTAGCG 		 7683 		 31752.94 		 -135.39
# AATTAATT:TTAATTAA 		 558 		 2580.47 		 -39.82
# AAAATTTT:TTTTAAAA 		 501 		 2185.49 		 -36.04
# TTAATTAA:AATTAATT 		 537 		 2205.76 		 -35.54
# AAATATTT:TTTATAAA 		 365 		 1705.30 		 -32.46
# ATAATTAT:TATTAATA 		 364 		 1681.01 		 -32.13
# TTTTAAAA:AAAATTTT 		 298 		 1251.69 		 -26.96
# CAAATTTG:GTTTAAAC 		 245 		 1158.42 		 -26.84
# TAATATTA:ATTATAAT 		 296 		 1222.71 		 -26.50
# TAAATTTA:ATTTAAAT 		 413 		 1380.29 		 -26.04
# GATTAATC:CTAATTAG 		 390 		 1342.07 		 -25.99
# TGATATCA:ACTATAGT 		 300 		 1184.38 		 -25.70
# TATTAATA:ATAATTAT 		 385 		 1310.43 		 -25.57
# ATCGCGAT:TAGCGCTA 		 294 		 1155.39 		 -25.34
# AATATATT:TTATATAA 		 255 		 1051.57 		 -24.57
# ATTTAAAT:TAAATTTA 		 195 		 945.67 		 -24.41
# GTTTAAAC:CAAATTTG 		 269 		 1057.29 		 -24.25
# CCCTAGGG:GGGATCCC 		 232 		 997.07 		 -24.23
# CAATATTG:GTTATAAC 		 230 		 971.23 		 -23.79
# ACAATTGT:TGTTAACA 		 115 		 750.77 		 -23.20
# CATTAATG:GTAATTAC 		 165 		 800.99 		 -22.47
# CTTTAAAG:GAAATTTC 		 260 		 935.23 		 -22.08
# TTAGCTAA:AATCGATT 		 226 		 865.22 		 -21.73
# TAAATTTT:ATTTAAAA 		 834 		 1736.84 		 -21.67
# GGTTAACC:CCAATTGG 		 191 		 798.36 		 -21.50
# TTGATCAA:AACTAGTT 		 225 		 851.57 		 -21.47
# TATTAATC:ATAATTAG 		 549 		 1326.16 		 -21.34
# AGTTAACT:TCAATTGA 		 174 		 760.13 		 -21.26
# AATTAATA:TTAATTAT 		 928 		 1838.89 		 -21.24
# AGATATCT:TCTATAGA 		 186 		 776.94 		 -21.20
# AAACGTTT:TTTGCAAA 		 89 		 610.72 		 -21.11
# GAATATTC:CTTATAAG 		 169 		 740.56 		 -21.00
# ATCATGAT:TAGTACTA 		 201 		 791.44 		 -20.99
# GATTAATT:CTAATTAA 		 976 		 1860.96 		 -20.52
# ATAATTAA:TATTAATT 		 1032 		 1925.60 		 -20.37
# TAAATTTC:ATTTAAAG 		 377 		 1030.37 		 -20.36
# TTTATAAA:AAATATTT 		 207 		 772.49 		 -20.35
# GCGATCGG:CGCTAGCC 		 1322 		 2283.15 		 -20.12
# ATATATAT:TATATATA 		 253 		 830.94 		 -20.05
# TATATATA:ATATATAT 		 162 		 675.77 		 -19.76
# TCAATTGA:AGTTAACT 		 151 		 654.34 		 -19.68
# TCGATCGC:AGCTAGCG 		 1220 		 2120.19 		 -19.55
# TTGTACAA:AACATGTT 		 95 		 550.76 		 -19.42
# GAAATTTC:CTTTAAAG 		 233 		 769.16 		 -19.33
# GGATATCC:CCTATAGG 		 162 		 652.30 		 -19.20
# ATAGCTAT:TATCGATA 		 150 		 629.24 		 -19.11
# TATCGATA:ATAGCTAT 		 147 		 624.39 		 -19.11
# ATTATAAT:TAATATTA 		 200 		 708.17 		 -19.10
# TTTGCAAA:AAACGTTT 		 133 		 590.67 		 -18.83
# ACGATCGC:TGCTAGCG 		 1187 		 2033.72 		 -18.78
# TTTTAAAC:AAAATTTG 		 518 		 1150.39 		 -18.65
# TAATATTT:ATTATAAA 		 737 		 1443.98 		 -18.61
# GCAATTGC:CGTTAACG 		 136 		 581.59 		 -18.48
# CCAATTGG:GGTTAACC 		 133 		 575.88 		 -18.46
# AAAATTTG:TTTTAAAC 		 856 		 1591.14 		 -18.43
# CTGATCAG:GACTAGTC 		 117 		 532.48 		 -18.01
# TTATATAA:AATATATT 		 192 		 650.74 		 -17.98
# AATCGATT:TTAGCTAA 		 141 		 568.86 		 -17.94
# CTATATAG:GATATATC 		 88 		 468.63 		 -17.58
# CATTAATC:GTAATTAG 		 478 		 1036.81 		 -17.36
# GCTATAGC:CGATATCG 		 130 		 528.57 		 -17.34
# TTATATAT:AATATATA 		 270 		 735.34 		 -17.16
# TCCTAGGA:AGGATCCT 		 61 		 407.10 		 -17.15
# CTTTAAAT:GAAATTTA 		 418 		 940.43 		 -17.04
# GAACGTTC:CTTGCAAG 		 34 		 354.42 		 -17.02
# GATATATC:CTATATAG 		 134 		 517.04 		 -16.85
# AAATATTG:TTTATAAC 		 686 		 1286.95 		 -16.75
# CAAATTTA:GTTTAAAT 		 669 		 1264.50 		 -16.75
# GTTTAAAG:CAAATTTC 		 467 		 994.39 		 -16.73
# GTAATTAA:CATTAATT 		 449 		 967.52 		 -16.67
# TATTAATG:ATAATTAC 		 503 		 1024.52 		 -16.29
# GAAATTTT:CTTTAAAA 		 713 		 1296.53 		 -16.21
# TAATATTG:ATTATAAC 		 555 		 1089.74 		 -16.20
# CTAATTAG:GATTAATC 		 98 		 434.63 		 -16.15
# TGTTAACA:ACAATTGT 		 124 		 470.63 		 -15.98
# TATATATT:ATATATAA 		 381 		 842.98 		 -15.91
# TTAATTAG:AATTAATC 		 484 		 979.13 		 -15.82
# AATTAATG:TTAATTAC 		 839 		 1437.68 		 -15.79
# GTAATTAC:CATTAATG 		 101 		 424.38 		 -15.70
# ATGATCAT:TACTAGTA 		 118 		 451.10 		 -15.68
# GAAATTTG:CTTTAAAC 		 464 		 943.94 		 -15.62
# GAATATTA:CTTATAAT 		 470 		 951.57 		 -15.61
# CTTTAAAA:GAAATTTT 		 571 		 1081.95 		 -15.53
# GGAATTCC:CCTTAAGG 		 127 		 459.42 		 -15.51
# CAATATTC:GTTATAAG 		 397 		 848.09 		 -15.49
# TGATATCC:ACTATAGG 		 420 		 878.96 		 -15.48
# TTTATAAT:AAATATTA 		 319 		 739.63 		 -15.47
# TTCATGAA:AAGTACTT 		 129 		 456.50 		 -15.33
# AGATATCA:TCTATAGT 		 492 		 959.26 		 -15.09
# GCCATGGC:CGGTACCG 		 105 		 409.19 		 -15.04
# CCCATGGG:GGGTACCC 		 109 		 409.19 		 -14.84
# GAATATTT:CTTATAAA 		 627 		 1123.78 		 -14.82
# ATTTAAAA:TAAATTTT 		 601 		 1087.97 		 -14.76
# CGATATCG:GCTATAGC 		 135 		 441.84 		 -14.60
# TTAGCTAT:AATCGATA 		 345 		 737.85 		 -14.46
# TCAATTGG:AGTTAACC 		 260 		 613.86 		 -14.28
# CTAATTAT:GATTAATA 		 440 		 854.76 		 -14.19
# TCCATGGA:AGGTACCT 		 40 		 271.41 		 -14.05
# GTTATAAC:CAATATTG 		 72 		 319.42 		 -13.84
# ACTATAGT:TGATATCA 		 76 		 325.81 		 -13.84
# TAGCGCTA:ATCGCGAT 		 116 		 387.19 		 -13.78
# ATTGCAAT:TAACGTTA 		 79 		 324.57 		 -13.63
# GTTGCAAC:CAACGTTG 		 98 		 351.72 		 -13.53
# GGTTAACT:CCAATTGA 		 402 		 779.01 		 -13.51
# ATAATTAC:TATTAATG 		 453 		 844.63 		 -13.48
# TGATATCG:ACTATAGC 		 361 		 723.40 		 -13.47
# CGATATCT:GCTATAGA 		 260 		 585.90 		 -13.46
# GTTTAAAT:CAAATTTA 		 578 		 999.93 		 -13.34
# CATCGATG:GTAGCTAC 		 73 		 304.48 		 -13.27
# GATATATG:CTATATAC 		 118 		 374.50 		 -13.25
# GCAATTGG:CGTTAACC 		 260 		 578.73 		 -13.25
# ACCTAGGT:TGGATCCA 		 69 		 295.51 		 -13.18
# TTGATCAT:AACTAGTA 		 292 		 619.79 		 -13.17
# TTCATGAT:AAGTACTA 		 279 		 601.07 		 -13.14
# CAACGTTG:GTTGCAAC 		 45 		 247.87 		 -12.89
# TATATATC:ATATATAG 		 281 		 591.10 		 -12.76
# ACCTAGGG:TGGATCCC 		 247 		 542.81 		 -12.70
# TTGATCAC:AACTAGTG 		 214 		 493.25 		 -12.57
# TGTTAACC:ACAATTGG 		 303 		 612.97 		 -12.52
# GTAGCTAC:CATCGATG 		 59 		 260.32 		 -12.48
# ATGTACAT:TACATGTA 		 48 		 240.75 		 -12.42
# GCAATTGT:CGTTAACA 		 342 		 660.79 		 -12.40
# CATATATT:GTATATAA 		 249 		 534.09 		 -12.34
# GTGATCAC:CACTAGTG 		 78 		 285.71 		 -12.29
# ACCATGGT:TGGTACCA 		 83 		 293.18 		 -12.28
# CGATATCC:GCTATAGG 		 253 		 536.85 		 -12.25
# ATATATAG:TATATATC 		 318 		 624.02 		 -12.25
# GATCGATC:CTAGCTAG 		 35 		 214.09 		 -12.24
# CCGATCGG:GGCTAGCC 		 9 		 164.17 		 -12.11
# AGAATTCT:TCTTAAGA 		 51 		 234.69 		 -11.99
# TTGATCAG:AACTAGTC 		 363 		 673.38 		 -11.96
# GGATATCT:CCTATAGA 		 393 		 711.89 		 -11.95
# TCAATTGT:AGTTAACA 		 386 		 700.90 		 -11.90
# CCCATGGC:GGGTACCG 		 169 		 409.19 		 -11.87
# CATATATG:GTATATAC 		 77 		 271.26 		 -11.80
# AGTTAACA:TCAATTGT 		 312 		 598.11 		 -11.70
# GGGCGGGG:CCCGCCCC 		 190 		 432.05 		 -11.65
# TTCGCGAA:AAGCGCTT 		 66 		 249.50 		 -11.62
# ATCGCGAA:TAGCGCTT 		 268 		 536.91 		 -11.61
# CCTATAGG:GGATATCC 		 76 		 262.36 		 -11.51
# TTAGCTAC:AATCGATG 		 224 		 474.59 		 -11.50
# CATCGATA:GTAGCTAT 		 196 		 436.02 		 -11.50
# ATGGCCAT:TACCGGTA 		 48 		 216.99 		 -11.47
# TTGGCCAA:AACCGGTT 		 41 		 204.51 		 -11.43
# AAGCGCTT:TTCGCGAA 		 47 		 212.41 		 -11.35
# TTTGCAAC:AAACGTTG 		 214 		 455.80 		 -11.33
# CAGATCTG:GTCTAGAC 		 70 		 248.20 		 -11.31
# CTGATCAT:GACTAGTA 		 242 		 490.10 		 -11.21
# AAACGTTA:TTTGCAAT 		 117 		 314.97 		 -11.15
# CCGATCGT:GGCTAGCA 		 12 		 146.23 		 -11.10
# TATCGATT:ATAGCTAA 		 326 		 595.98 		 -11.06
# TCGATCGA:AGCTAGCT 		 10 		 141.57 		 -11.06
# CCCGCCCA:GGGCGGGT 		 192 		 417.56 		 -11.04
# ACGATCGT:TGCTAGCA 		 5 		 130.26 		 -10.97
# TCAATTGC:AGTTAACG 		 345 		 616.90 		 -10.95
# GCTATAGG:CGATATCC 		 162 		 372.39 		 -10.90
# AATATATC:TTATATAG 		 443 		 737.36 		 -10.84
# CATCGATT:GTAGCTAA 		 197 		 416.18 		 -10.74
# GGGCGGGA:CCCGCCCT 		 217 		 442.97 		 -10.74
# GGCGCGCC:CCGCGCGG 		 66 		 227.97 		 -10.73
# CCGATCGA:GGCTAGCT 		 21 		 152.45 		 -10.65
# GTTATAAT:CAATATTA 		 244 		 475.61 		 -10.62
# GTCGCGAT:CAGCGCTA 		 235 		 461.97 		 -10.56
# CTGTACAG:GACATGTC 		 57 		 208.79 		 -10.50
# ACGATCGA:TGCTAGCT 		 14 		 135.79 		 -10.45
# CTGGCCAG:GACCGGTC 		 36 		 173.39 		 -10.43
# GTCATGAC:CAGTACTG 		 53 		 200.87 		 -10.43
# ATTGCAAA:TAACGTTT 		 221 		 437.86 		 -10.36
# TTTATAAG:AAATATTC 		 185 		 389.14 		 -10.35
# ACCATGGG:TGGTACCC 		 154 		 346.36 		 -10.34
# AAAGCTTT:TTTCGAAA 		 53 		 197.94 		 -10.30
# GCGGCCGC:CGCCGGCG 		 44 		 183.47 		 -10.30
# TAGATCTA:ATCTAGAT 		 48 		 189.62 		 -10.28
# TACCCAAC:ATGGGTTG 		 327 		 571.37 		 -10.22
# CCCTAGGA:GGGATCCT 		 380 		 637.11 		 -10.19
# ACCCAACT:TGGGTTGA 		 392 		 650.65 		 -10.14
# GATCGATT:CTAGCTAA 		 160 		 348.98 		 -10.12
# TAGCGCTT:ATCGCGAA 		 116 		 286.78 		 -10.08
# GTCGCGAC:CAGCGCTG 		 48 		 184.71 		 -10.06
# TGAATTCC:ACTTAAGG 		 120 		 289.48 		 -9.96
# CCATATGG:GGTATACC 		 21 		 137.67 		 -9.94
# AAACCTAC:TTTGGATG 		 258 		 473.92 		 -9.92
# TGGCGGGT:ACCGCCCA 		 418 		 674.70 		 -9.88
# TCTATAGA:AGATATCT 		 59 		 196.22 		 -9.80
# CTTATAAT:GAATATTA 		 185 		 372.59 		 -9.72
# CGTTAACA:GCAATTGT 		 119 		 282.28 		 -9.72
# GTTATAAA:CAATATTT 		 281 		 496.74 		 -9.68
# GTAATTAG:CATTAATC 		 229 		 429.48 		 -9.67
# AGCCGGCT:TCGGCCGA 		 18 		 125.80 		 -9.61
# ACCCGGGT:TGGGCCCA 		 47 		 173.00 		 -9.58
# TTATATAG:AATATATC 		 328 		 552.23 		 -9.54
# TTATATAC:AATATATG 		 141 		 307.70 		 -9.50
# CGTTAACG:GCAATTGC 		 46 		 169.31 		 -9.48
# CTTGCAAG:GAACGTTC 		 32 		 146.01 		 -9.44
# CTGATCAC:GACTAGTG 		 204 		 390.04 		 -9.42
# GACTAGTC:CTGATCAG 		 2 		 92.53 		 -9.41
# ATCATGAC:TAGTACTG 		 211 		 398.72 		 -9.40
# GTTATAAG:CAATATTC 		 102 		 250.23 		 -9.37
# TACCCTAC:ATGGGATG 		 144 		 308.35 		 -9.36
# TTCATGAC:AAGTACTG 		 140 		 302.81 		 -9.36
# CTAGCTAG:GATCGATC 		 33 		 145.12 		 -9.31
# CTTATAAG:GAATATTC 		 66 		 196.03 		 -9.29
# CGGCGGGT:GCCGCCCA 		 281 		 485.00 		 -9.26
# GTTGGGTC:CAACCCAG 		 148 		 311.46 		 -9.26
# GTATATAT:CATATATA 		 175 		 347.70 		 -9.26
# TTCCGGAA:AAGGCCTT 		 57 		 181.79 		 -9.26
# ACTATAGA:TGATATCT 		 106 		 252.84 		 -9.23
# CAGCGCTG:GTCGCGAC 		 27 		 133.73 		 -9.23
# ATCGCGAG:TAGCGCTC 		 127 		 281.73 		 -9.22
# TCACGTGA:AGTGCACT 		 4 		 91.86 		 -9.17
# GGTTAACG:CCAATTGC 		 192 		 367.66 		 -9.16
# CGTTAACT:GCAATTGA 		 186 		 358.75 		 -9.12
# CACTAGTG:GTGATCAC 		 5 		 92.53 		 -9.10
# GCTATAGT:CGATATCA 		 230 		 414.99 		 -9.08
# AACCGGTT:TTGGCCAA 		 50 		 167.50 		 -9.08
# GGTATACC:CCATATGG 		 43 		 155.67 		 -9.03
# TACCGGTA:ATGGCCAT 		 39 		 149.34 		 -9.03
# AGAATTCC:TCTTAAGG 		 165 		 328.36 		 -9.02
# ACAATTGG:TGTTAACC 		 427 		 657.54 		 -8.99
# CAACGTTC:GTTGCAAG 		 142 		 296.40 		 -8.97
# TGTATACA:ACATATGT 		 40 		 149.65 		 -8.96
# TATAAACC:ATATTTGG 		 293 		 490.90 		 -8.93
# GATCGATA:CTAGCTAT 		 195 		 365.62 		 -8.92
# GTGATCAT:CACTAGTA 		 190 		 359.00 		 -8.92
# TGAATTCA:ACTTAAGT 		 62 		 182.40 		 -8.91
# ACCATGGC:TGGTACCG 		 181 		 346.36 		 -8.89
# TCCATGGT:AGGTACCA 		 133 		 282.09 		 -8.88
# GTTGCAAG:CAACGTTC 		 93 		 226.62 		 -8.88
# TGCGGGTT:ACGCCCAA 		 315 		 516.66 		 -8.87
# TAACGTTC:ATTGCAAG 		 103 		 239.94 		 -8.84
# GTGCGTCC:CACGCAGG 		 104 		 240.07 		 -8.78
# ATCATGAG:TAGTACTC 		 164 		 320.77 		 -8.75
# CTGTACAA:GACATGTT 		 180 		 339.10 		 -8.64
# TCTATAGC:AGATATCG 		 167 		 322.05 		 -8.64
# CTAGCTAT:GATCGATA 		 152 		 302.18 		 -8.64
# TCGCGCGA:AGCGCGCT 		 25 		 118.90 		 -8.61
# CTCATGAG:GAGTACTC 		 32 		 130.01 		 -8.60
# GTATATAC:CATATATG 		 42 		 145.49 		 -8.58
# AGTATACT:TCATATGA 		 31 		 126.75 		 -8.50
# TTAGCTAG:AATCGATC 		 195 		 354.34 		 -8.47
# ATTGCAAC:TAACGTTG 		 183 		 337.87 		 -8.43
# ACTGCAGT:TGACGTCA 		 12 		 92.79 		 -8.39
# TCCCGGGA:AGGGCCCT 		 27 		 118.06 		 -8.38
# CCGCGCGG:GGCGCGCC 		 29 		 121.25 		 -8.38
# CTGCGTCA:GACGCAGT 		 117 		 248.61 		 -8.35
# ATGTACAG:TACATGTC 		 100 		 224.20 		 -8.29
# TTAGGGGC:AATCCCCG 		 188 		 340.18 		 -8.25
# CGGCGATC:GCCGCTAG 		 998 		 1294.27 		 -8.24
# GTAGCTAT:CATCGATA 		 240 		 404.73 		 -8.19
# CTTGCAAT:GAACGTTA 		 97 		 217.70 		 -8.18
# TAGGGGCT:ATCCCCGA 		 160 		 301.71 		 -8.16
# CCCTAGGC:GGGATCCG 		 125 		 255.01 		 -8.14
# GTGAAACA:CACTTTGT 		 90 		 206.45 		 -8.10
# AAACGTTG:TTTGCAAC 		 230 		 389.07 		 -8.06
# GTATATAG:CATATATC 		 131 		 261.12 		 -8.05
# AAGGCCTT:TTCCGGAA 		 15 		 92.12 		 -8.04
# CCTATAGT:GGATATCA 		 155 		 292.36 		 -8.03
# TCTCCCAT:AGAGGGTA 		 250 		 413.29 		 -8.03
# CACCGGTG:GTGGCCAC 		 43 		 136.69 		 -8.01
# GCACGTGC:CGTGCACG 		 4 		 71.94 		 -8.01
# ACATATGT:TGTATACA 		 7 		 77.17 		 -7.99
# TGCGTCAA:ACGCAGTT 		 149 		 282.44 		 -7.94
# GCCATGGA:CGGTACCT 		 189 		 333.25 		 -7.90
# TCTATAGG:AGATATCC 		 108 		 226.89 		 -7.89
# GAGATCTG:CTCTAGAC 		 73 		 178.18 		 -7.88
# CAGCGCTA:GTCGCGAT 		 109 		 227.55 		 -7.86
# GTAGCTAG:CATCGATC 		 85 		 194.36 		 -7.84
# AACCGGTG:TTGGCCAC 		 55 		 151.31 		 -7.83
# ACTCGAGT:TGAGCTCA 		 16 		 90.37 		 -7.82
# GCGGGTTG:CGCCCAAC 		 258 		 417.54 		 -7.81
# TTCGCGAC:AAGCGCTG 		 101 		 214.67 		 -7.76
# ATCCGGAT:TAGGCCTA 		 47 		 137.20 		 -7.70
# CTGGCCAT:GACCGGTA 		 88 		 193.97 		 -7.61
# CTCATGAA:GAGTACTT 		 125 		 243.62 		 -7.60
# TCCTAGGT:AGGATCCA 		 206 		 346.85 		 -7.56
# TAGATCTG:ATCTAGAC 		 106 		 216.94 		 -7.53
# GGGCGGGC:CCCGCCCG 		 80 		 181.32 		 -7.52
# TGTATACC:ACATATGG 		 60 		 152.63 		 -7.50
# TAACGTTA:ATTGCAAT 		 67 		 162.44 		 -7.49
# TTGGCCAT:AACCGGTA 		 102 		 210.66 		 -7.49
# CGAATTCG:GCTTAAGC 		 17 		 85.98 		 -7.44
# ACCTACAG:TGGATGTC 		 198 		 332.74 		 -7.39
# AAGATCTT:TTCTAGAA 		 21 		 91.47 		 -7.37
# TAGTACTA:ATCATGAT 		 41 		 122.46 		 -7.36
# GCCTAGGA:CGGATCCT 		 69 		 162.94 		 -7.36
# TTCTAGAA:AAGATCTT 		 20 		 88.83 		 -7.30
# TGAATTCT:ACTTAAGA 		 102 		 206.90 		 -7.29
# CAAGCTTG:GTTCGAAC 		 11 		 73.25 		 -7.27
# AGGCGATT:TCCGCTAA 		 341 		 504.14 		 -7.27
# TAACCCGC:ATTGGGCG 		 288 		 439.32 		 -7.22
# GGGTTTCC:CCCAAAGG 		 518 		 709.86 		 -7.20
# AGGCGATA:TCCGCTAT 		 373 		 539.72 		 -7.18
# GCTGCGCC:CGACGCGG 		 134 		 246.46 		 -7.16
# GAGCGCTC:CTCGCGAG 		 13 		 75.06 		 -7.16
# TCCCATTT:AGGGTAAA 		 325 		 481.45 		 -7.13
# GAGATCTA:CTCTAGAT 		 67 		 155.74 		 -7.11
# CGCGGGTT:GCGCCCAA 		 127 		 235.79 		 -7.08
# GGAATTCG:CCTTAAGC 		 99 		 198.74 		 -7.08
# TCTCGAGA:AGAGCTCT 		 12 		 71.96 		 -7.07
# CATATATA:GTATATAT 		 283 		 428.15 		 -7.01
# AGCAGCGT:TCGTCGCA 		 111 		 213.47 		 -7.01
# GTAGGGGA:CATCCCCT 		 263 		 403.96 		 -7.01
# GAGCGCTA:CTCGCGAT 		 79 		 170.48 		 -7.01
# AGGCGATG:TCCGCTAC 		 206 		 333.72 		 -6.99
# CGCGCGCC:GCGCGCGG 		 58 		 141.02 		 -6.99
# GTGGCCAC:CACCGGTG 		 18 		 80.76 		 -6.98
# TTGTACAT:AACATGTA 		 231 		 364.14 		 -6.98
# ACGGCCGC:TGCCGGCG 		 45 		 122.08 		 -6.98
# GGCGGGTG:CCGCCCAC 		 347 		 503.05 		 -6.96
# AGGGTGCA:TCCCACGT 		 100 		 197.72 		 -6.95
# TAGGGTGA:ATCCCACT 		 291 		 435.25 		 -6.91
# CGACGCAC:GCTGCGTG 		 70 		 155.92 		 -6.88
# ACTGGTGT:TGACCACA 		 134 		 240.49 		 -6.87
# TCCATGGG:AGGTACCC 		 208 		 333.25 		 -6.86
# TCGGCCGA:AGCCGGCT 		 15 		 73.98 		 -6.86
# GGATGGTG:CCTACCAC 		 190 		 310.81 		 -6.85
# AGACGCAC:TCTGCGTG 		 70 		 155.43 		 -6.85
# GGCGGGTA:CCGCCCAT 		 273 		 411.63 		 -6.83
# CAAGGTCT:GTTCCAGA 		 117 		 217.79 		 -6.83
# GTCATGAG:CAGTACTC 		 75 		 161.60 		 -6.81
# ATGTACAC:TACATGTG 		 53 		 130.91 		 -6.81
# GAGATCTC:CTCTAGAG 		 51 		 127.91 		 -6.80
# AACGCACC:TTGCGTGG 		 177 		 293.16 		 -6.78
# CGCGCGCG:GCGCGCGC 		 24 		 87.23 		 -6.77
# TAACGTTG:ATTGCAAC 		 105 		 200.66 		 -6.75
# TGGTACCA:ACCATGGT 		 12 		 67.12 		 -6.73
# AGCGTCAG:TCGCAGTC 		 173 		 286.27 		 -6.69
# TGCCGGCA:ACGGCCGT 		 22 		 82.91 		 -6.69
# TGCGCGCA:ACGCGCGT 		 22 		 82.77 		 -6.68
# AGCGTATT:TCGCATAA 		 61 		 139.96 		 -6.67
# AGATAATT:TCTATTAA 		 625 		 815.47 		 -6.67
# GTGTACAC:CACATGTG 		 15 		 71.18 		 -6.66
# ACACCGTC:TGTGGCAG 		 59 		 136.62 		 -6.64
# GCGCGCGC:CGCGCGCG 		 38 		 106.43 		 -6.63
# GGTATACT:CCATATGA 		 62 		 140.47 		 -6.62
# CCAACCTG:GGTTGGAC 		 202 		 320.42 		 -6.62
# ATCCGGAA:TAGGCCTT 		 75 		 157.93 		 -6.60
# TGTAATTT:ACATTAAA 		 308 		 447.10 		 -6.58
# GTGGCCAA:CACCGGTT 		 54 		 128.52 		 -6.57
# ACCCCAGT:TGGGGTCA 		 216 		 336.42 		 -6.57
# GCGCGCGA:CGCGCGCT 		 43 		 112.49 		 -6.55
# GGCTGCGC:CCGACGCG 		 69 		 148.64 		 -6.53
# CCGCAGCG:GGCGTCGC 		 98 		 186.69 		 -6.49
# GCCGCCCC:CGGCGGGG 		 339 		 481.35 		 -6.49
# TTCCGGAG:AAGGCCTC 		 37 		 102.48 		 -6.47
# TGTGCGTC:ACACGCAG 		 71 		 150.10 		 -6.46
# CAGCGATC:GTCGCTAG 		 883 		 1096.55 		 -6.45
# CGCCGGCG:GCGGCCGC 		 15 		 68.25 		 -6.45
# GAAAGGAA:CTTTCCTT 		 171 		 277.98 		 -6.42
# ACGTTCCC:TGCAAGGG 		 116 		 208.05 		 -6.38
# AGCGCGCT:TCGCGCGA 		 11 		 60.70 		 -6.38
# GTGGCCAG:CACCGGTC 		 49 		 118.34 		 -6.37
# ATTACTCT:TAATGAGA 		 173 		 279.34 		 -6.36
# CACCGGTA:GTGGCCAT 		 67 		 142.88 		 -6.35
# GCGTGTCT:CGCACAGA 		 26 		 84.04 		 -6.33
# GTAGATAA:CATCTATT 		 248 		 369.66 		 -6.33
# TCTGACGA:AGACTGCT 		 92 		 175.90 		 -6.33
# TGAGCTCA:ACTCGAGT 		 1 		 41.93 		 -6.32
# CCTGCAGG:GGACGTCC 		 22 		 77.59 		 -6.31
# GCCATAAC:CGGTATTG 		 229 		 345.96 		 -6.29
# ATCTAGAT:TAGATCTA 		 28 		 86.34 		 -6.28
# TTAGGTTG:AATCCAAC 		 248 		 368.36 		 -6.27
# CGGTACCG:GCCATGGC 		 20 		 73.86 		 -6.27
# AAGATCTC:TTCTAGAG 		 43 		 108.17 		 -6.27
# CTGTACAC:GACATGTG 		 53 		 121.91 		 -6.24
# CCGGCCGG:GGCCGGCC 		 11 		 58.89 		 -6.24
# CCCAACCA:GGGTTGGT 		 475 		 631.72 		 -6.24
# ACTTTCTT:TGAAAGAA 		 141 		 236.64 		 -6.22
# TCCCTACA:AGGGATGT 		 176 		 279.80 		 -6.21
# CCCCTGCC:GGGGACGG 		 114 		 202.24 		 -6.20
# CGGGTTTC:GCCCAAAG 		 410 		 556.22 		 -6.20
# TGAATTCG:ACTTAAGC 		 56 		 125.23 		 -6.19
# TAACCTAC:ATTGGATG 		 243 		 360.40 		 -6.18
# ACAATGGT:TGTTACCA 		 256 		 375.62 		 -6.17
# TAGTACTC:ATCATGAG 		 23 		 77.25 		 -6.17
# CTTGCAAA:GAACGTTT 		 188 		 293.68 		 -6.17
# CTGCGATC:GACGCTAG 		 524 		 685.39 		 -6.16
# CTCCTAAC:GAGGATTG 		 178 		 281.14 		 -6.15
# AAATCCTA:TTTAGGAT 		 403 		 546.82 		 -6.15
# GTAGGGTT:CATCCCAA 		 315 		 444.37 		 -6.14
# CTTGGTTT:GAACCAAA 		 359 		 495.58 		 -6.14
# CCGGAACG:GGCCTTGC 		 82 		 159.14 		 -6.11
# AGGTTGGT:TCCAACCA 		 233 		 346.80 		 -6.11
# ATGCGTCA:TACGCAGT 		 96 		 177.34 		 -6.11
# ATGCGATG:TACGCTAC 		 92 		 172.10 		 -6.11
# GAAAGGGG:CTTTCCCC 		 190 		 294.43 		 -6.09
# GGCGGGGA:CCGCCCCT 		 325 		 454.64 		 -6.08
# GGGGATTG:CCCCTAAC 		 257 		 374.48 		 -6.07
# ATAAACGT:TATTTGCA 		 111 		 195.94 		 -6.07
# GAAACCTG:CTTTGGAC 		 286 		 408.65 		 -6.07
# CGGGCGGG:GCCCGCCC 		 136 		 227.19 		 -6.05
# CAGGCCTA:GTCCGGAT 		 23 		 75.61 		 -6.05
# ATAATGCT:TATTACGA 		 281 		 402.12 		 -6.04
# GAGGGTGC:CTCCCACG 		 112 		 196.50 		 -6.03
# AGGCAGTG:TCCGTCAC 		 69 		 140.37 		 -6.02
# GACGCACT:CTGCGTGA 		 93 		 171.90 		 -6.02
# ACCCGGGA:TGGGCCCT 		 71 		 142.91 		 -6.02
# GCAAAAGA:CGTTTTCT 		 121 		 207.67 		 -6.01
# CGAGAGTA:GCTCTCAT 		 92 		 169.96 		 -5.98
# TAACTGCG:ATTGACGC 		 138 		 228.31 		 -5.98
# TTGGAATG:AACCTTAC 		 155 		 249.28 		 -5.97
# GGCGCGCT:CCGCGCGA 		 53 		 117.64 		 -5.96
# AGCTATCG:TCGATAGC 		 110 		 192.67 		 -5.96
# TGGATCCA:ACCTAGGT 		 5 		 44.63 		 -5.93
# AAGATCTG:TTCTAGAC 		 78 		 150.67 		 -5.92
# TGTTGGGG:ACAACCCC 		 393 		 529.18 		 -5.92
# ACAACAGT:TGTTGTCA 		 176 		 273.84 		 -5.91
# GGTTGAGC:CCAACTCG 		 143 		 233.29 		 -5.91
# AAAATGTT:TTTTACAA 		 414 		 552.97 		 -5.91
# CAGGTGGT:GTCCACCA 		 190 		 290.72 		 -5.91
# ACGGCCGT:TGCCGGCA 		 28 		 81.23 		 -5.91
# GGCGGGTC:CCGCCCAG 		 181 		 279.65 		 -5.90
# TTCATTAC:AAGTAATG 		 140 		 229.09 		 -5.89
# CAGGCCTG:GTCCGGAC 		 26 		 77.88 		 -5.88
# CCAAGGCA:GGTTCCGT 		 199 		 300.96 		 -5.88
# AGACTACA:TCTGATGT 		 103 		 182.34 		 -5.88
# GAGTAACC:CTCATTGG 		 150 		 241.24 		 -5.87
# GCGCGCGG:CGCGCGCC 		 51 		 113.59 		 -5.87
# CGCGTCAG:GCGCAGTC 		 71 		 140.19 		 -5.84
# GGCGCGCA:CCGCGCGT 		 69 		 137.37 		 -5.83
# TACCGGTT:ATGGCCAA 		 85 		 158.16 		 -5.82
# GTCAACCA:CAGTTGGT 		 177 		 272.98 		 -5.81
# CGGGAATC:GCCCTTAG 		 164 		 257.04 		 -5.80
# CGGGAGAG:GCCCTCTC 		 145 		 233.45 		 -5.79
# AGGCGGGT:TCCGCCCA 		 244 		 352.64 		 -5.79
# CAGATATC:GTCTATAG 		 298 		 415.78 		 -5.78
# AAGGGGAT:TTCCCCTA 		 251 		 360.62 		 -5.77
# TAGGCCTA:ATCCGGAT 		 24 		 73.40 		 -5.77
# CTCGCGAA:GAGCGCTT 		 65 		 130.92 		 -5.76
# AAACCGTT:TTTGGCAA 		 236 		 342.58 		 -5.76
# GTGTCCCG:CACAGGGC 		 36 		 90.88 		 -5.76
# ACCTAGGC:TGGATCCG 		 71 		 138.83 		 -5.76
# CGTATGAT:GCATACTA 		 35 		 89.37 		 -5.75
# GATGGTTA:CTACCAAT 		 396 		 528.07 		 -5.75
# TAGCGTAT:ATCGCATA 		 39 		 95.02 		 -5.75
# ACCACTGT:TGGTGACA 		 136 		 221.38 		 -5.74
# AAGGACAT:TTCCTGTA 		 80 		 150.28 		 -5.73
# CTAGGTTG:GATCCAAC 		 227 		 331.32 		 -5.73
# ATCCGGAG:TAGGCCTC 		 35 		 89.02 		 -5.73
# TGGACAAG:ACCTGTTC 		 117 		 197.23 		 -5.71
# GTTTTGCC:CAAAACGG 		 337 		 459.33 		 -5.71
# TCGGCCGC:AGCCGGCG 		 55 		 116.50 		 -5.70
# AAATAGGA:TTTATCCT 		 251 		 358.92 		 -5.70
# AGGTCTGA:TCCAGACT 		 161 		 251.18 		 -5.69
# GACGTTCC:CTGCAAGG 		 107 		 184.17 		 -5.69
# GGTTGGGA:CCAACCCT 		 406 		 537.86 		 -5.69
# TTTTTTCC:AAAAAAGG 		 635 		 795.18 		 -5.68
# TGCCGGCG:ACGGCCGC 		 26 		 75.23 		 -5.68
# AGGTTGGA:TCCAACCT 		 150 		 237.38 		 -5.67
# CCGGCCGT:GGCCGGCA 		 22 		 69.16 		 -5.67
# GGTATCAA:CCATAGTT 		 315 		 432.84 		 -5.66
# GGTACAAA:CCATGTTT 		 154 		 242.13 		 -5.66
# TGGGTTTA:ACCCAAAT 		 675 		 838.89 		 -5.66
# CAGGGTGC:GTCCCACG 		 118 		 197.51 		 -5.66
# CCCCGGGG:GGGGCCCC 		 21 		 67.47 		 -5.66
# GCCCCTAT:CGGGGATA 		 151 		 238.09 		 -5.64
# AACGTTCA:TTGCAAGT 		 100 		 174.37 		 -5.63
# ATGCGATA:TACGCTAT 		 97 		 170.53 		 -5.63
# CCGGAAAG:GGCCTTTC 		 201 		 298.09 		 -5.62
# TACCATCC:ATGGTAGG 		 224 		 325.42 		 -5.62
# GAAGGCGG:CTTCCGCC 		 169 		 259.49 		 -5.62
# GCCTGTTA:CGGACAAT 		 101 		 175.32 		 -5.61
# AAGATGGT:TTCTACCA 		 280 		 390.58 		 -5.60
# GAAATAAG:CTTTATTC 		 138 		 220.92 		 -5.58
# TCCTGGGA:AGGACCCT 		 227 		 327.86 		 -5.57
# GCATATCA:CGTATAGT 		 117 		 194.59 		 -5.56
# ACTAGTCC:TGATCAGG 		 2 		 34.74 		 -5.55
# CTAGGGGC:GATCCCCG 		 165 		 253.32 		 -5.55
# CTTGCCTA:GAACGGAT 		 72 		 136.86 		 -5.54
# CCGGGGTT:GGCCCCAA 		 218 		 316.55 		 -5.54
# AAAAGTTT:TTTTCAAA 		 520 		 662.47 		 -5.54
# TCGCTGCG:AGCGACGC 		 150 		 234.82 		 -5.54
# GTGTGGAA:CACACCTT 		 123 		 201.51 		 -5.53
# ATCCGGAC:TAGGCCTG 		 21 		 65.85 		 -5.53
# GATCGATG:CTAGCTAC 		 167 		 255.32 		 -5.53
# GCCTTATA:CGGAATAT 		 77 		 143.12 		 -5.53
# ACAGAAAT:TGTCTTTA 		 329 		 445.65 		 -5.53
# CCGCGATC:GGCGCTAG 		 396 		 522.23 		 -5.52
# ATTGAACC:TAACTTGG 		 328 		 444.19 		 -5.51
# TACCCCGA:ATGGGGCT 		 169 		 256.71 		 -5.47
# CTCCTTTC:GAGGAAAG 		 91 		 160.29 		 -5.47
# GGGCATGA:CCCGTACT 		 90 		 158.90 		 -5.47
# CTTGCTCA:GAACGAGT 		 167 		 253.94 		 -5.46
# ACCATTAT:TGGTAATA 		 372 		 493.15 		 -5.46
# ACGGAACT:TGCCTTGA 		 128 		 206.33 		 -5.45
# ACGGTTTC:TGCCAAAG 		 233 		 332.38 		 -5.45
# AATTGCTA:TTAACGAT 		 480 		 615.21 		 -5.45
# ATCTCTTT:TAGAGAAA 		 169 		 256.23 		 -5.45
# GGACTTAG:CCTGAATC 		 115 		 190.11 		 -5.45
# TGTTTATT:ACAAATAA 		 431 		 559.88 		 -5.45
# GTCGCGAG:CAGCGCTC 		 55 		 112.65 		 -5.43
# CAAGGCAT:GTTCCGTA 		 172 		 259.38 		 -5.43
# CGGAAGTC:GCCTTCAG 		 125 		 202.01 		 -5.42
# AGGGTGCT:TCCCACGA 		 133 		 211.79 		 -5.41
# CCTTGGGC:GGAACCCG 		 167 		 252.90 		 -5.40
# CGGAACGG:GCCTTGCC 		 87 		 153.85 		 -5.39
# GGCAATTG:CCGTTAAC 		 264 		 367.04 		 -5.38
# GACCATCG:CTGGTAGC 		 107 		 178.89 		 -5.38
# AGAAACCT:TCTTTGGA 		 343 		 457.99 		 -5.37
# CATATGTC:GTATACAG 		 8 		 43.37 		 -5.37
# ACCGTGAT:TGGCACTA 		 138 		 217.02 		 -5.36
# AAGGTCTA:TTCCAGAT 		 109 		 181.16 		 -5.36
# CACCCTAA:GTGGGATT 		 291 		 397.67 		 -5.35
# GAAGCTTT:CTTCGAAA 		 38 		 88.25 		 -5.35
# GACTTTTC:CTGAAAAG 		 203 		 294.75 		 -5.34
# GTTGTTTC:CAACAAAG 		 180 		 267.38 		 -5.34
# ATCCATGC:TAGGTACG 		 85 		 150.52 		 -5.34
# ACGAACCT:TGCTTGGA 		 43 		 95.04 		 -5.34
# TGACATTC:ACTGTAAG 		 152 		 233.55 		 -5.34
# AACACTTA:TTGTGAAT 		 101 		 170.65 		 -5.33
# TCCTGGAA:AGGACCTT 		 238 		 335.66 		 -5.33
# ATGTGACA:TACACTGT 		 41 		 92.17 		 -5.33
# CTCCCGAT:GAGGGCTA 		 178 		 264.61 		 -5.32
# TCTGCAGA:AGACGTCT 		 11 		 47.71 		 -5.32
# GGTGAAAA:CCACTTTT 		 467 		 596.76 		 -5.31
# AGGTTCTG:TCCAAGAC 		 288 		 393.31 		 -5.31
# GCGCAGCA:CGCGTCGT 		 79 		 142.32 		 -5.31
# GCCCGGGT:CGGGCCCA 		 34 		 82.05 		 -5.30
# ACCCCTAC:TGGGGATG 		 429 		 553.83 		 -5.30
# CGTATACT:GCATATGA 		 17 		 57.06 		 -5.30
# TGGTCACG:ACCAGTGC 		 97 		 165.05 		 -5.30
# GAAGGCAG:CTTCCGTC 		 88 		 153.57 		 -5.29
# TTGCGTCA:AACGCAGT 		 226 		 320.46 		 -5.28
# CGAGGTGA:GCTCCACT 		 83 		 146.91 		 -5.27
# CTCGCGAG:GAGCGCTC 		 25 		 68.70 		 -5.27
# AAAGTACG:TTTCATGC 		 45 		 96.88 		 -5.27
# CACCAGAT:GTGGTCTA 		 211 		 302.58 		 -5.27
# AGATGGTT:TCTACCAA 		 317 		 425.57 		 -5.26
# ATAGGGTG:TATCCCAC 		 195 		 283.62 		 -5.26
# TTTGGGTT:AAACCCAA 		 683 		 835.01 		 -5.26
# ATAAACCT:TATTTGGA 		 368 		 483.55 		 -5.25
# TGTTTGAC:ACAAACTG 		 228 		 322.33 		 -5.25
# GTAAGCGA:CATTCGCT 		 123 		 196.59 		 -5.25
# CCATACGG:GGTATGCC 		 85 		 149.04 		 -5.25
# GCTGACAA:CGACTGTT 		 159 		 240.21 		 -5.24
# CATATAAG:GTATATTC 		 142 		 219.53 		 -5.23
# TATCCATG:ATAGGTAC 		 157 		 237.66 		 -5.23
# CTCCGGAG:GAGGCCTC 		 18 		 57.77 		 -5.23
# AAAGCTTG:TTTCGAAC 		 63 		 120.41 		 -5.23
# GCCTAGGC:CGGATCCG 		 23 		 65.22 		 -5.23
# AGTGTAAT:TCACATTA 		 114 		 184.95 		 -5.22
# GAGCGCTG:CTCGCGAC 		 48 		 100.19 		 -5.21
# ACCGTACC:TGGCATGG 		 53 		 106.87 		 -5.21
# TGTATACG:ACATATGC 		 21 		 62.00 		 -5.21
# GCAGTGGG:CGTCACCC 		 115 		 185.97 		 -5.20
# GATCAGCG:CTAGTCGC 		 70 		 129.12 		 -5.20
# ACCCAACG:TGGGTTGC 		 216 		 307.17 		 -5.20
# CCCCGGGT:GGGGCCCA 		 54 		 108.04 		 -5.20
# CGGGGCGG:GCCCCGCC 		 170 		 252.52 		 -5.19
# TTCTAGAT:AAGATCTA 		 39 		 87.58 		 -5.19
# AAAATAGG:TTTTATCC 		 470 		 596.80 		 -5.19
# TTGTACAC:AACATGTG 		 125 		 198.00 		 -5.19
# CTCAAGTC:GAGTTCAG 		 130 		 204.10 		 -5.19
# TCGGATTT:AGCCTAAA 		 436 		 558.53 		 -5.18
# ATCCCATT:TAGGGTAA 		 331 		 439.71 		 -5.18
# GCACCCTT:CGTGGGAA 		 90 		 154.41 		 -5.18
# GGTACTTG:CCATGAAC 		 94 		 159.45 		 -5.18
# GAATCATG:CTTAGTAC 		 199 		 286.72 		 -5.18
# ACCACAAT:TGGTGTTA 		 291 		 393.72 		 -5.18
# CTTCCATC:GAAGGTAG 		 169 		 251.01 		 -5.18
# CAGATTTG:GTCTAAAC 		 341 		 450.85 		 -5.17
# ACGGTGTC:TGCCACAG 		 51 		 103.68 		 -5.17
# TGTCCAAT:ACAGGTTA 		 149 		 226.87 		 -5.17
# GGGGCCCC:CCCCGGGG 		 10 		 44.46 		 -5.17
# ACTTCCGT:TGAAGGCA 		 146 		 223.15 		 -5.16
# CGGCAGGG:GCCGTCCC 		 46 		 96.69 		 -5.16
# TCGGCTCC:AGCCGAGG 		 101 		 167.75 		 -5.15
# GCCCAACC:CGGGTTGG 		 163 		 243.40 		 -5.15
# CCCCCTTG:GGGGGAAC 		 224 		 315.53 		 -5.15
# GCAACCTA:CGTTGGAT 		 156 		 234.96 		 -5.15
# CTTTAGAG:GAAATCTC 		 143 		 219.16 		 -5.14
# CCCCTACC:GGGGATGG 		 392 		 507.91 		 -5.14
# GAAGGTCA:CTTCCAGT 		 125 		 197.20 		 -5.14
# TGAGCCGT:ACTCGGCA 		 87 		 149.95 		 -5.14
# GTAGGGAA:CATCCCTT 		 216 		 305.87 		 -5.14
# TGTGGTTT:ACACCAAA 		 331 		 438.62 		 -5.14
# ACACCTGT:TGTGGACA 		 105 		 172.42 		 -5.13
# GGGAATCC:CCCTTAGG 		 192 		 277.51 		 -5.13
# CCTTAAGG:GGAATTCC 		 5 		 35.57 		 -5.13
# ACTCCAAA:TGAGGTTT 		 298 		 400.54 		 -5.12
# TAGCAGTT:ATCGTCAA 		 474 		 599.40 		 -5.12
# ATGGAATA:TACCTTAT 		 162 		 241.58 		 -5.12
# TAAGTTGA:ATTCAACT 		 214 		 303.13 		 -5.12
# GAAGAGTA:CTTCTCAT 		 79 		 139.37 		 -5.11
# GTGGATAA:CACCTATT 		 193 		 278.23 		 -5.11
# AATTCCCA:TTAAGGGT 		 823 		 983.01 		 -5.10
# TGCGCGCG:ACGCGCGC 		 38 		 84.97 		 -5.10
# CTCTTTTC:GAGAAAAG 		 119 		 189.07 		 -5.10
# CCAGTTTG:GGTCAAAC 		 280 		 379.22 		 -5.10
# ACGGGTTT:TGCCCAAA 		 322 		 427.22 		 -5.09
# TGTACAAT:ACATGTTA 		 137 		 210.90 		 -5.09
# TCCGTCTA:AGGCAGAT 		 66 		 122.23 		 -5.09
# GCACTGCC:CGTGACGG 		 67 		 123.46 		 -5.08
# CTGCCAAA:GACGGTTT 		 364 		 474.67 		 -5.08
# GCAGCGTC:CGTCGCAG 		 86 		 147.66 		 -5.07
# ACGCTTCT:TGCGAAGA 		 73 		 131.08 		 -5.07
# TTCTGATC:AAGACTAG 		 138 		 211.80 		 -5.07
# CAACGCAG:GTTGCGTC 		 50 		 100.91 		 -5.07
# TTCGCACT:AAGCGTGA 		 101 		 166.29 		 -5.06
# GAACAATA:CTTGTTAT 		 207 		 293.68 		 -5.06
# CGGCGCCG:GCCGCGGC 		 17 		 54.23 		 -5.06
# CGCCTTGC:GCGGAACG 		 54 		 105.99 		 -5.05
# CTTGACCG:GAACTGGC 		 175 		 255.68 		 -5.05
# GCGTCAGC:CGCAGTCG 		 186 		 268.66 		 -5.04
# CGGGCATC:GCCCGTAG 		 60 		 113.77 		 -5.04
# TAGGTTGA:ATCCAACT 		 472 		 594.87 		 -5.04
# CGGATCCG:GCCTAGGC 		 11 		 44.63 		 -5.03
# CTCGCCGT:GAGCGGCA 		 86 		 147.03 		 -5.03
# GGGGTGAA:CCCCACTT 		 360 		 468.88 		 -5.03
# ATGGTCAC:TACCAGTG 		 118 		 186.67 		 -5.03
# CTGGCGAT:GACCGCTA 		 409 		 523.95 		 -5.02
# TACTCCAA:ATGAGGTT 		 140 		 213.35 		 -5.02
# TGGGTGAT:ACCCACTA 		 387 		 499.19 		 -5.02
# GGGAGAGA:CCCTCTCT 		 204 		 289.35 		 -5.02
# AAGACCTT:TTCTGGAA 		 122 		 191.40 		 -5.02
# TCCCATAT:AGGGTATA 		 215 		 302.00 		 -5.01
# CGCCCCTC:GCGGGGAG 		 95 		 157.89 		 -5.01
# AAGGAGAG:TTCCTCTC 		 103 		 167.83 		 -5.00
# ATGATTAA:TACTAATT 		 667 		 809.29 		 -5.00
# GTACGGTA:CATGCCAT 		 23 		 62.55 		 -5.00
# GACACCCG:CTGTGGGC 		 74 		 131.22 		 -4.99
# CCTCATAT:GGAGTATA 		 111 		 177.47 		 -4.99
# GCAGCGTT:CGTCGCAA 		 135 		 206.72 		 -4.99
# ACACATAA:TGTGTATT 		 101 		 165.08 		 -4.99
# CTCGAAGT:GAGCTTCA 		 67 		 122.00 		 -4.98
# ACTTTTCG:TGAAAAGC 		 172 		 250.79 		 -4.98
# CAGCGCTT:GTCGCGAA 		 104 		 168.54 		 -4.97
# TAATTTTC:ATTAAAAG 		 598 		 732.50 		 -4.97
# GACTTATC:CTGAATAG 		 139 		 211.23 		 -4.97
# CCTGCAGC:GGACGTCG 		 18 		 54.71 		 -4.96
# GCAGCCAC:CGTCGGTG 		 176 		 255.25 		 -4.96
# CAGCGAGT:GTCGCTCA 		 131 		 201.33 		 -4.96
# GGTTTCAG:CCAAAGTC 		 271 		 365.79 		 -4.96
# CGTTTATT:GCAAATAA 		 243 		 333.27 		 -4.94
# GAACTGGG:CTTGACCC 		 165 		 241.78 		 -4.94
# CTCGCACT:GAGCGTGA 		 158 		 233.39 		 -4.94
# CGGGTTTT:GCCCAAAA 		 522 		 647.55 		 -4.93
# AGGATCCT:TCCTAGGA 		 6 		 35.27 		 -4.93
# TTCCGGAC:AAGGCCTG 		 33 		 75.80 		 -4.92
# CCAACCAG:GGTTGGTC 		 233 		 321.05 		 -4.91
# GTGATAAG:CACTATTC 		 75 		 131.18 		 -4.91
# ACCAGTTT:TGGTCAAA 		 422 		 535.47 		 -4.90
# ATCCCAAC:TAGGGTTG 		 306 		 404.62 		 -4.90
# CCGGATTC:GGCCTAAG 		 106 		 169.86 		 -4.90
# CCTCTTAC:GGAGAATG 		 31 		 72.80 		 -4.90
# CAGTGGTG:GTCACCAC 		 193 		 274.02 		 -4.89
# AAATTGCA:TTTAACGT 		 329 		 430.51 		 -4.89
# CTGATGCC:GACTACGG 		 205 		 288.00 		 -4.89
# TATGCATA:ATACGTAT 		 20 		 56.82 		 -4.88
# ACCTGAAG:TGGACTTC 		 124 		 191.57 		 -4.88
# GGGGCGGA:CCCCGCCT 		 204 		 286.59 		 -4.88
# TAAGATGC:ATTCTACG 		 85 		 143.39 		 -4.88
# GACCTTGT:CTGGAACA 		 59 		 110.13 		 -4.87
# CCCGTTAC:GGGCAATG 		 99 		 160.70 		 -4.87
# CGTCTCGA:GCAGAGCT 		 42 		 87.52 		 -4.87
# ACTTAAGT:TGAATTCA 		 12 		 44.43 		 -4.87
# AAGCGATA:TTCGCTAT 		 250 		 339.66 		 -4.86
# GGGTTGGG:CCCAACCC 		 514 		 636.71 		 -4.86
# GCCAACCT:CGGTTGGA 		 255 		 345.31 		 -4.86
# GCACGTGG:CGTGCACC 		 9 		 39.57 		 -4.86
# CGAGACGG:GCTCTGCC 		 72 		 126.61 		 -4.85
# GGACATTA:CCTGTAAT 		 132 		 200.66 		 -4.85
# GTAATAAA:CATTATTT 		 298 		 394.17 		 -4.84
# ATGTTCTA:TACAAGAT 		 143 		 213.79 		 -4.84
# CATGGAAT:GTACCTTA 		 148 		 219.76 		 -4.84
# AGGTGCGT:TCCACGCA 		 161 		 235.22 		 -4.84
# ACCTTGGT:TGGAACCA 		 153 		 225.69 		 -4.84
# GTCTAGAT:CAGATCTA 		 17 		 51.81 		 -4.84
# CCGAATGC:GGCTTACG 		 81 		 137.64 		 -4.83
# TGGGGTAC:ACCCCATG 		 95 		 155.11 		 -4.83
# ACTGCGTC:TGACGCAG 		 71 		 124.94 		 -4.83
# TTGGGACT:AACCCTGA 		 223 		 307.52 		 -4.82
# CTTGCCTG:GAACGGAC 		 68 		 121.01 		 -4.82
# TGAATAGG:ACTTATCC 		 135 		 203.76 		 -4.82
# CTTAACAC:GAATTGTG 		 75 		 129.83 		 -4.81
# TCGTCTCG:AGCAGAGC 		 58 		 107.99 		 -4.81
# TCCTTATT:AGGAATAA 		 158 		 231.11 		 -4.81
# TGGCAGTT:ACCGTCAA 		 375 		 480.29 		 -4.80
# GTGCAACA:CACGTTGT 		 94 		 153.50 		 -4.80
# AAGAGTAG:TTCTCATC 		 83 		 139.72 		 -4.80
# CGCCCCTG:GCGGGGAC 		 113 		 176.70 		 -4.79
# TCCCGGGG:AGGGCCCC 		 44 		 89.25 		 -4.79
# TTTCATAT:AAAGTATA 		 178 		 254.36 		 -4.79
# TGAAGAAG:ACTTCTTC 		 191 		 269.53 		 -4.78
# CACCCTGA:GTGGGACT 		 199 		 278.88 		 -4.78
# CTCCACAC:GAGGTGTG 		 45 		 90.48 		 -4.78
# CAAGCAGG:GTTCGTCC 		 112 		 175.21 		 -4.78
# CATCCTTG:GTAGGAAC 		 114 		 177.63 		 -4.77
# TCTCGACA:AGAGCTGT 		 110 		 172.74 		 -4.77
# GGCACTTC:CCGTGAAG 		 69 		 121.62 		 -4.77
# CGGTTTCA:GCCAAAGT 		 230 		 314.56 		 -4.77
# AGAGATTT:TCTCTAAA 		 402 		 509.60 		 -4.77
# TGACAGGA:ACTGTCCT 		 136 		 204.06 		 -4.76
# GCTGCAGC:CGACGTCG 		 9 		 38.57 		 -4.76
# TTGCCAAC:AACGGTTG 		 287 		 379.78 		 -4.76
# TTTTCGCT:AAAAGCGA 		 298 		 392.13 		 -4.75
# GCCATCCC:CGGTAGGG 		 187 		 264.25 		 -4.75
# TCTTTCAC:AGAAAGTG 		 120 		 184.50 		 -4.75
# ACAGCGAA:TGTCGCTT 		 136 		 203.76 		 -4.75
# CCTGTAAT:GGACATTA 		 216 		 297.93 		 -4.75
# AAAACCTA:TTTTGGAT 		 422 		 531.35 		 -4.74
# GACGGCTC:CTGCCGAG 		 72 		 125.03 		 -4.74
# CATCACAA:GTAGTGTT 		 179 		 254.64 		 -4.74
# GATTATTA:CTAATAAT 		 553 		 676.25 		 -4.74
# TATAGGGC:ATATCCCG 		 82 		 137.59 		 -4.74
# ACGTTGCT:TGCAACGA 		 47 		 92.56 		 -4.74
# TAAAGGAT:ATTTCCTA 		 198 		 276.78 		 -4.74
# TCAGGAGG:AGTCCTCC 		 183 		 259.21 		 -4.73
# ACCGACTT:TGGCTGAA 		 145 		 214.26 		 -4.73
# GTTGTAAA:CAACATTT 		 244 		 329.83 		 -4.73
# GCTTGTGA:CGAACACT 		 70 		 122.24 		 -4.73
# CCAATCTG:GGTTAGAC 		 161 		 233.13 		 -4.72
# AAGTTATG:TTCAATAC 		 247 		 333.21 		 -4.72
# CTGAATGA:GACTTACT 		 130 		 196.06 		 -4.72
# TGCGCTTT:ACGCGAAA 		 104 		 164.48 		 -4.72
# TTCCATCA:AAGGTAGT 		 351 		 451.17 		 -4.72
# TAAGCTTT:ATTCGAAA 		 33 		 73.40 		 -4.72
# ACCTTTAT:TGGAAATA 		 276 		 366.23 		 -4.72
# ATATCTCA:TATAGAGT 		 176 		 250.53 		 -4.71
# GATGATGG:CTACTACC 		 478 		 592.61 		 -4.71
# CGCGATCG:GCGCTAGC 		 1844 		 2057.51 		 -4.71
# TATCAAGG:ATAGTTCC 		 247 		 332.79 		 -4.70
# TGGTTTAT:ACCAAATA 		 450 		 561.43 		 -4.70
# CTACGGGC:GATGCCCG 		 61 		 110.39 		 -4.70
# CCTTCCGG:GGAAGGCC 		 141 		 208.83 		 -4.69
# AATTCCTA:TTAAGGAT 		 408 		 514.35 		 -4.69
# AGGGTATT:TCCCATAA 		 331 		 427.99 		 -4.69
# CTCGGAAC:GAGCCTTG 		 121 		 184.72 		 -4.69
# CGTCTGTG:GCAGACAC 		 75 		 128.03 		 -4.69
# AGCGCAGA:TCGCGTCT 		 52 		 98.51 		 -4.69
# AGCTGCGC:TCGACGCG 		 33 		 73.03 		 -4.68
# AGGGGGCG:TCCCCCGC 		 187 		 262.91 		 -4.68
# GCCACCCA:CGGTGGGT 		 270 		 358.61 		 -4.68
# TAGATCTT:ATCTAGAA 		 78 		 131.70 		 -4.68
# GAAGCTTC:CTTCGAAG 		 10 		 39.34 		 -4.68
# TTAAACCC:AATTTGGG 		 687 		 821.03 		 -4.68
# AGGATGTT:TCCTACAA 		 220 		 301.16 		 -4.68
# CCCCATTC:GGGGTAAG 		 281 		 371.05 		 -4.68
# AAAACAGT:TTTTGTCA 		 357 		 456.88 		 -4.67
# CAAGGCAC:GTTCCGTG 		 65 		 115.07 		 -4.67
# CAATAGGG:GTTATCCC 		 216 		 296.24 		 -4.66
# ACGTGAGG:TGCACTCC 		 16 		 48.44 		 -4.66
# GCATAATG:CGTATTAC 		 78 		 131.42 		 -4.66
# CTTATTAA:GAATAATT 		 226 		 307.69 		 -4.66
# GCCATATG:CGGTATAC 		 18 		 51.37 		 -4.66
# AAAACCGA:TTTTGGCT 		 482 		 595.56 		 -4.65
# TGATGTGA:ACTACACT 		 301 		 393.18 		 -4.65
# AAACGTTC:TTTGCAAG 		 365 		 465.24 		 -4.65
# GACCGTCA:CTGGCAGT 		 96 		 153.59 		 -4.65
# CCCCGGGC:GGGGCCCG 		 18 		 51.24 		 -4.64
# TGTTCGTT:ACAAGCAA 		 74 		 126.16 		 -4.64
# GGCAGCGT:CCGTCGCA 		 52 		 97.90 		 -4.64
# TTTCAACG:AAAGTTGC 		 143 		 210.23 		 -4.64
# TTTTTGCT:AAAAACGA 		 543 		 662.24 		 -4.63
# GCGTCCTC:CGCAGGAG 		 35 		 75.16 		 -4.63
# GACAATTA:CTGTTAAT 		 494 		 608.23 		 -4.63
# GAAAAGCC:CTTTTCGG 		 327 		 422.14 		 -4.63
# TAAGTCTC:ATTCAGAG 		 142 		 208.92 		 -4.63
# GAGGTTGG:CTCCAACC 		 230 		 311.71 		 -4.63
# GGGCGTTC:CCCGCAAG 		 54 		 100.36 		 -4.63
# GCCACTAG:CGGTGATC 		 109 		 169.18 		 -4.63
# GCCAGGTA:CGGTCCAT 		 119 		 181.28 		 -4.63
# CCTTGCCT:GGAACGGA 		 86 		 140.90 		 -4.62
# ATGGAGCT:TACCTCGA 		 38 		 79.09 		 -4.62
# AGAATTCG:TCTTAAGC 		 87 		 142.05 		 -4.62
# TGTAATGA:ACATTACT 		 114 		 175.09 		 -4.62
# TGACCACT:ACTGGTGA 		 170 		 241.78 		 -4.62
# AGAATCAT:TCTTAGTA 		 320 		 413.83 		 -4.61
# GAGGGGTC:CTCCCCAG 		 79 		 131.96 		 -4.61
# TAAATCGC:ATTTAGCG 		 264 		 350.24 		 -4.61
# AATCGCAT:TTAGCGTA 		 218 		 297.44 		 -4.61
# ACGCGCGT:TGCGCGCA 		 3 		 26.88 		 -4.61
# AGGGCCCT:TCCCGGGA 		 1 		 23.09 		 -4.60
# GATTTCGC:CTAAAGCG 		 171 		 242.58 		 -4.60
# AGAGTGTA:TCTCACAT 		 58 		 105.09 		 -4.59
# TGCCCAAC:ACGGGTTG 		 132 		 196.32 		 -4.59
# TACCGAAT:ATGGCTTA 		 153 		 221.29 		 -4.59
# AAATTGTT:TTTAACAA 		 544 		 662.11 		 -4.59
# GAATCCCG:CTTAGGGC 		 85 		 139.12 		 -4.59
# GATATGTC:CTATACAG 		 120 		 181.86 		 -4.59
# ATTCGAAT:TAAGCTTA 		 7 		 33.58 		 -4.59
# GTCTACTC:CAGATGAG 		 71 		 121.57 		 -4.59
# CCTACATC:GGATGTAG 		 148 		 215.27 		 -4.59
# GCTCTTAA:CGAGAATT 		 46 		 89.33 		 -4.58
# CTGTTAAG:GACAATTC 		 170 		 241.17 		 -4.58
# CACACGGT:GTGTGCCA 		 22 		 56.42 		 -4.58
# CGCAACAA:GCGTTGTT 		 144 		 210.46 		 -4.58
# GCCATGCG:CGGTACGC 		 90 		 145.18 		 -4.58
# TGGGTGCG:ACCCACGC 		 250 		 333.65 		 -4.58
# TCTAAGGA:AGATTCCT 		 135 		 199.71 		 -4.58
# ATTGTCCT:TAACAGGA 		 279 		 366.68 		 -4.58
# GAATCCTG:CTTAGGAC 		 123 		 185.32 		 -4.58
# CCGCGCGA:GGCGCGCT 		 70 		 120.07 		 -4.57
# TGGTCAGC:ACCAGTCG 		 254 		 338.00 		 -4.57
# AGGGTTAT:TCCCAATA 		 267 		 352.81 		 -4.57
# GTTAGGGA:CAATCCCT 		 224 		 303.53 		 -4.57
# GAATCCGC:CTTAGGCG 		 78 		 130.05 		 -4.56
# CCGTTCCT:GGCAAGGA 		 86 		 139.99 		 -4.56
# GGAGTGAG:CCTCACTC 		 77 		 128.78 		 -4.56
# TTTTGATT:AAAACTAA 		 856 		 1000.13 		 -4.56
# CACGGTTA:GTGCCAAT 		 119 		 180.18 		 -4.56
# CGGTTGCC:GCCAACGG 		 97 		 153.28 		 -4.55
# CAAAGTAC:GTTTCATG 		 83 		 136.01 		 -4.55
# GTGTAATG:CACATTAC 		 60 		 106.93 		 -4.54
# ACAAGAGC:TGTTCTCG 		 46 		 88.67 		 -4.53
# CTCAGGCA:GAGTCCGT 		 54 		 99.03 		 -4.53
# GCATATGC:CGTATACG 		 11 		 39.37 		 -4.52
# TACTCTTG:ATGAGAAC 		 86 		 139.37 		 -4.52
# GACCCTGC:CTGGGACG 		 49 		 92.44 		 -4.52
# AGGTAGGG:TCCATCCC 		 163 		 231.74 		 -4.52
# CAAAACTC:GTTTTGAG 		 466 		 574.20 		 -4.52
# ACGTGCAT:TGCACGTA 		 23 		 57.13 		 -4.52
# CACTCCAA:GTGAGGTT 		 112 		 171.05 		 -4.52
# GAGGGGTG:CTCCCCAC 		 127 		 189.07 		 -4.51
# CCTTCCGA:GGAAGGCT 		 108 		 166.17 		 -4.51
# GAGCGATA:CTCGCTAT 		 119 		 179.44 		 -4.51
# GGGTAACC:CCCATTGG 		 40 		 80.45 		 -4.51
# ACCTACCA:TGGATGGT 		 241 		 321.90 		 -4.51
# AGCGGGTT:TCGCCCAA 		 255 		 337.88 		 -4.51
# CACACCCC:GTGTGGGG 		 121 		 181.79 		 -4.51
# GGCATTCA:CCGTAAGT 		 149 		 215.07 		 -4.51
# TCCATCTC:AGGTAGAG 		 184 		 256.09 		 -4.50
# GTCCCGTA:CAGGGCAT 		 45 		 86.99 		 -4.50
# AGAGCTCT:TCTCGAGA 		 8 		 34.39 		 -4.50
# CTCTAGAG:GAGATCTC 		 6 		 31.08 		 -4.50
# GTTAATAA:CAATTATT 		 436 		 540.59 		 -4.50
# AGGGTCGA:TCCCAGCT 		 87 		 140.22 		 -4.49
# CTATTGCC:GATAACGG 		 199 		 273.19 		 -4.49
# GAAGATGG:CTTCTACC 		 287 		 373.75 		 -4.49
# CGGAAAGA:GCCTTTCT 		 156 		 222.99 		 -4.49
# TGTAGGGT:ACATCCCA 		 341 		 434.38 		 -4.48
# TACCTATT:ATGGATAA 		 206 		 281.05 		 -4.48
# TTGGTTAT:AACCAATA 		 420 		 522.14 		 -4.47
# AATACCGT:TTATGGCA 		 114 		 172.71 		 -4.47
# GCCAAAAG:CGGTTTTC 		 292 		 378.94 		 -4.47
# CAGGAGAC:GTCCTCTG 		 92 		 145.90 		 -4.46
# TTAAACGG:AATTTGCC 		 232 		 310.60 		 -4.46
# AACCCGTG:TTGGGCAC 		 119 		 178.60 		 -4.46
# CTACGTGA:GATGCACT 		 1 		 21.85 		 -4.46
# GGGAGCCG:CCCTCGGC 		 110 		 167.75 		 -4.46
# GAGCAAGC:CTCGTTCG 		 100 		 155.62 		 -4.46
# CGAATCTT:GCTTAGAA 		 93 		 147.02 		 -4.45
# CCAGCTGG:GGTCGACC 		 2 		 23.68 		 -4.45
# TCACCAGG:AGTGGTCC 		 171 		 240.00 		 -4.45
# GGCGTTGT:CCGCAACA 		 126 		 186.84 		 -4.45
# ATACGTCT:TATGCAGA 		 25 		 59.26 		 -4.45
# TACAGTGC:ATGTCACG 		 53 		 96.74 		 -4.45
# TGGATTCG:ACCTAAGC 		 90 		 143.21 		 -4.45
# GTAGAATC:CATCTTAG 		 171 		 239.82 		 -4.44
# GACGGAAG:CTGCCTTC 		 148 		 212.83 		 -4.44
# CCTTGGTA:GGAACCAT 		 133 		 195.06 		 -4.44
# CAGCAAGG:GTCGTTCC 		 171 		 239.72 		 -4.44
# GGATACGC:CCTATGCG 		 50 		 92.74 		 -4.44
# GGGGTTAC:CCCCAATG 		 168 		 236.18 		 -4.44
# CCGGCCGA:GGCCGGCT 		 30 		 66.00 		 -4.43
# ACATAATT:TGTATTAA 		 300 		 387.20 		 -4.43
# GACCGGTA:CTGGCCAT 		 24 		 57.62 		 -4.43
# GTTCTGCA:CAAGACGT 		 95 		 149.08 		 -4.43
# TACTTTTG:ATGAAAAC 		 250 		 330.50 		 -4.43
# AGTCTCCT:TCAGAGGA 		 113 		 170.84 		 -4.43
# TCAGCGTA:AGTCGCAT 		 57 		 101.61 		 -4.43
# GGAATGCT:CCTTACGA 		 180 		 249.92 		 -4.42
# ACGCCCTT:TGCGGGAA 		 39 		 78.07 		 -4.42
# AAAGTCTA:TTTCAGAT 		 214 		 289.16 		 -4.42
# TGAGAGTT:ACTCTCAA 		 350 		 443.02 		 -4.42
# GGTAGACG:CCATCTGC 		 70 		 117.98 		 -4.42
# GTCCATGA:CAGGTACT 		 113 		 170.68 		 -4.42
# GTTACGAT:CAATGCTA 		 96 		 150.09 		 -4.42
# GATAGGAA:CTATCCTT 		 155 		 220.46 		 -4.41
# AGGGAACG:TCCCTTGC 		 111 		 168.14 		 -4.41
# CGAGTAAC:GCTCATTG 		 58 		 102.56 		 -4.40
# GTGGTAGG:CACCATCC 		 153 		 217.95 		 -4.40
# CATACGTC:GTATGCAG 		 16 		 45.75 		 -4.40
# TTGGCCAG:AACCGGTC 		 128 		 188.31 		 -4.39
# GTCGATTC:CAGCTAAG 		 89 		 141.21 		 -4.39
# TTCCAAGA:AAGGTTCT 		 199 		 271.37 		 -4.39
# CAGGGCGG:GTCCCGCC 		 134 		 195.41 		 -4.39
# AACATGGA:TTGTACCT 		 128 		 188.25 		 -4.39
# TCGAAAGC:AGCTTTCG 		 74 		 122.62 		 -4.39
# CCGCAAGC:GGCGTTCG 		 85 		 136.22 		 -4.39
# CGTTCCTA:GCAAGGAT 		 43 		 82.97 		 -4.39
# GCATATGG:CGTATACC 		 36 		 73.62 		 -4.38
# GACCTGGT:CTGGACCA 		 134 		 195.26 		 -4.38
# AAATAATT:TTTATTAA 		 853 		 990.86 		 -4.38
# TCACAGAC:AGTGTCTG 		 135 		 196.31 		 -4.38
# GGTTGGAA:CCAACCTT 		 188 		 258.22 		 -4.37
# TCTAATCA:AGATTAGT 		 251 		 330.40 		 -4.37
# AGCCGGCA:TCGGCCGT 		 58 		 102.13 		 -4.37
# GAGCGATG:CTCGCTAC 		 51 		 93.14 		 -4.37
# TAAGAACG:ATTCTTGC 		 25 		 58.32 		 -4.36
# AAGGCATT:TTCCGTAA 		 325 		 413.74 		 -4.36
# ATACACCT:TATGTGGA 		 120 		 178.24 		 -4.36
# TGACAGAC:ACTGTCTG 		 97 		 150.51 		 -4.36
# GGGAATGC:CCCTTACG 		 299 		 384.52 		 -4.36
# AACGCCTT:TTGCGGAA 		 124 		 182.98 		 -4.36
# GGAAGAGA:CCTTCTCT 		 124 		 182.97 		 -4.36
# CCCATTCC:GGGTAAGG 		 289 		 373.20 		 -4.36
# TAAGCGTT:ATTCGCAA 		 120 		 178.13 		 -4.36
# AAGTTTGT:TTCAAACA 		 207 		 279.83 		 -4.35
# TCGATTTA:AGCTAAAT 		 274 		 356.16 		 -4.35
# TGCGACAT:ACGCTGTA 		 57 		 100.68 		 -4.35
# GTGTAACT:CACATTGA 		 104 		 158.79 		 -4.35
# CTGCCTTT:GACGGAAA 		 232 		 308.32 		 -4.35
# CACCGGGT:GTGGCCCA 		 224 		 299.17 		 -4.35
# GCGGTTTC:CGCCAAAG 		 298 		 383.03 		 -4.34
# TAATCATC:ATTAGTAG 		 692 		 816.09 		 -4.34
# TTCGCTAT:AAGCGATA 		 206 		 278.47 		 -4.34
# GTAGGTAC:CATCCATG 		 48 		 88.92 		 -4.34
# GTCCCGAA:CAGGGCTT 		 155 		 219.22 		 -4.34
# CTATCGGC:GATAGCCG 		 119 		 176.62 		 -4.34
# CTACTTAG:GATGAATC 		 67 		 113.07 		 -4.33
# TCTAATTT:AGATTAAA 		 530 		 639.40 		 -4.33
# GGAATCTG:CCTTAGAC 		 142 		 203.74 		 -4.33
# GTGATATA:CACTATAT 		 151 		 214.32 		 -4.33
# ATGTCTGT:TACAGACA 		 129 		 188.35 		 -4.32
# ATGAAGCG:TACTTCGC 		 174 		 241.15 		 -4.32
# GTGACTTA:CACTGAAT 		 101 		 154.77 		 -4.32
# AGGATATA:TCCTATAT 		 296 		 380.17 		 -4.32
# CTCAAGAC:GAGTTCTG 		 142 		 203.55 		 -4.31
# GTACATTT:CATGTAAA 		 107 		 161.89 		 -4.31
# GGCTCCTT:CCGAGGAA 		 114 		 170.23 		 -4.31
# GGCAAGGC:CCGTTCCG 		 68 		 114.02 		 -4.31
# ACTTGAGT:TGAACTCA 		 191 		 260.56 		 -4.31
# AACATATA:TTGTATAT 		 215 		 288.14 		 -4.31
# CAGGGAAA:GTCCCTTT 		 409 		 505.89 		 -4.31
# GATAACGT:CTATTGCA 		 74 		 121.48 		 -4.31
# ACTAGCGT:TGATCGCA 		 44 		 83.32 		 -4.31
# ACATTCGT:TGTAAGCA 		 40 		 78.03 		 -4.30
# ACGCTACT:TGCGATGA 		 71 		 117.69 		 -4.30
# GTTCCGGG:CAAGGCCC 		 265 		 344.93 		 -4.30
# ATAATGCA:TATTACGT 		 107 		 161.73 		 -4.30
# ATTCCAGG:TAAGGTCC 		 223 		 297.16 		 -4.30
# TATAGCTT:ATATCGAA 		 223 		 297.13 		 -4.30
# AAAGCTGA:TTTCGACT 		 420 		 517.78 		 -4.30
# ATAATCAT:TATTAGTA 		 604 		 719.22 		 -4.30
# GGCACTCC:CCGTGAGG 		 69 		 115.09 		 -4.30
# TTAATTGG:AATTAACC 		 553 		 663.67 		 -4.30
# AGCGATCA:TCGCTAGT 		 128 		 186.61 		 -4.29
# CGCATGCG:GCGTACGC 		 1 		 20.35 		 -4.29
# AGGAGCCA:TCCTCGGT 		 186 		 254.38 		 -4.29
# GGCATAGC:CCGTATCG 		 91 		 142.06 		 -4.28
# ACAGAGTC:TGTCTCAG 		 87 		 137.17 		 -4.28
# ACTTCAAT:TGAAGTTA 		 287 		 369.30 		 -4.28
# AGCATGCT:TCGTACGA 		 2 		 22.15 		 -4.28
# GGTGTATG:CCACATAC 		 68 		 113.64 		 -4.28
# ATGAGGTT:TACTCCAA 		 191 		 260.03 		 -4.28
# TTCACCCG:AAGTGGGC 		 161 		 225.24 		 -4.28
# TATGAATT:ATACTTAA 		 222 		 295.58 		 -4.28
# AACACAGA:TTGTGTCT 		 179 		 246.13 		 -4.28
# GAAATAGT:CTTTATCA 		 318 		 403.99 		 -4.28
# TCCTTCCG:AGGAAGGC 		 103 		 156.52 		 -4.28
# AAAGGTCA:TTTCCAGT 		 192 		 261.13 		 -4.28
# TATCCCTT:ATAGGGAA 		 197 		 266.80 		 -4.27
# CGCCAACC:GCGGTTGG 		 319 		 404.96 		 -4.27
# GGCATTCG:CCGTAAGC 		 71 		 117.25 		 -4.27
# GGACGGTA:CCTGCCAT 		 99 		 151.59 		 -4.27
# AGACAAAT:TCTGTTTA 		 252 		 329.44 		 -4.27
# ATGCCAGG:TACGGTCC 		 97 		 149.04 		 -4.26
# CTTTCGAT:GAAAGCTA 		 112 		 167.01 		 -4.26
# TGCTAAAT:ACGATTTA 		 343 		 431.40 		 -4.26
# TAATTCGC:ATTAAGCG 		 192 		 260.70 		 -4.26
# CGTACATC:GCATGTAG 		 23 		 54.36 		 -4.25
# GAGAGTAC:CTCTCATG 		 53 		 94.24 		 -4.25
# TAATTGAC:ATTAACTG 		 476 		 578.13 		 -4.25
# ATAAATGT:TATTTACA 		 212 		 283.50 		 -4.25
# CTCCGTTC:GAGGCAAG 		 57 		 99.30 		 -4.24
# TACGATGA:ATGCTACT 		 94 		 145.09 		 -4.24
# CCAGGATG:GGTCCTAC 		 151 		 212.84 		 -4.24
# GATACCCA:CTATGGGT 		 256 		 333.38 		 -4.24
# GACCTTTT:CTGGAAAA 		 135 		 194.02 		 -4.24
# CCTGACCT:GGACTGGA 		 147 		 208.12 		 -4.24
# CGCTGCGA:GCGACGCT 		 113 		 167.89 		 -4.24
# CCGATAGC:GGCTATCG 		 195 		 263.80 		 -4.24
# CCGCTACT:GGCGATGA 		 112 		 166.65 		 -4.23
# CTGGTCAG:GACCAGTC 		 218 		 290.10 		 -4.23
# GATTTCTA:CTAAAGAT 		 323 		 408.56 		 -4.23
# ACCGATTT:TGGCTAAA 		 331 		 417.47 		 -4.23
# CATAGGGT:GTATCCCA 		 108 		 161.84 		 -4.23
# TGTCTAGG:ACAGATCC 		 105 		 158.23 		 -4.23
# TTCATGCT:AAGTACGA 		 141 		 200.97 		 -4.23
# TCGATAGC:AGCTATCG 		 128 		 185.61 		 -4.23
# CTGTGTAT:GACACATA 		 82 		 130.22 		 -4.23
# TGCCTGAC:ACGGACTG 		 57 		 99.03 		 -4.22
# GAATACAT:CTTATGTA 		 93 		 143.62 		 -4.22
# TCTGCGTT:AGACGCAA 		 58 		 100.29 		 -4.22
# TTGCTTAC:AACGAATG 		 99 		 150.86 		 -4.22
# GAGTGGTC:CTCACCAG 		 59 		 101.55 		 -4.22
# TTGCAATG:AACGTTAC 		 67 		 111.60 		 -4.22
# TACACTTC:ATGTGAAG 		 73 		 119.06 		 -4.22
# GCTTAACA:CGAATTGT 		 108 		 161.66 		 -4.22
# AAAGGAAG:TTTCCTTC 		 148 		 209.00 		 -4.22
# TATAATGC:ATATTACG 		 165 		 228.81 		 -4.22
# AACCGTGG:TTGGCACC 		 130 		 187.80 		 -4.22
# CCGGGTTC:GGCCCAAG 		 259 		 336.27 		 -4.21
# ACATTATT:TGTAATAA 		 227 		 299.98 		 -4.21
# ACATTGTC:TGTAACAG 		 100 		 151.92 		 -4.21
# TCAATGCA:AGTTACGT 		 88 		 137.37 		 -4.21
# GACAGCGT:CTGTCGCA 		 46 		 84.74 		 -4.21
# GCTTATTA:CGAATAAT 		 212 		 282.77 		 -4.21
# CTGATACG:GACTATGC 		 69 		 113.91 		 -4.21
# GACGCATG:CTGCGTAC 		 24 		 55.25 		 -4.20
# TAACGGCT:ATTGCCGA 		 232 		 305.46 		 -4.20
# CACCCAAA:GTGGGTTT 		 493 		 595.50 		 -4.20
# ATACGATG:TATGCTAC 		 56 		 97.46 		 -4.20
# GTCCGGAC:CAGGCCTG 		 8 		 31.61 		 -4.20
# ATCAAGGT:TAGTTCCA 		 256 		 332.56 		 -4.20
# CCCTGAAC:GGGACTTG 		 156 		 217.93 		 -4.20
# GGTCTCGC:CCAGAGCG 		 81 		 128.56 		 -4.19
# ACATATGC:TGTATACG 		 24 		 55.12 		 -4.19
# GTTATTTA:CAATAAAT 		 394 		 486.42 		 -4.19
# GATTAGAC:CTAATCTG 		 127 		 183.78 		 -4.19
# CCACTGCT:GGTGACGA 		 244 		 318.73 		 -4.19
# TTAGTTGG:AATCAACC 		 203 		 272.03 		 -4.19
# ACCCCGCT:TGGGGCGA 		 115 		 169.42 		 -4.18
# CTTTGGTC:GAAACCAG 		 218 		 289.02 		 -4.18
# GGAGAGTA:CCTCTCAT 		 186 		 252.34 		 -4.18
# CAGTCACC:GTCAGTGG 		 151 		 211.77 		 -4.18
# TGTTCCGT:ACAAGGCA 		 112 		 165.74 		 -4.17
# GGTGTAAG:CCACATTC 		 89 		 138.04 		 -4.17
# TTAAAAGG:AATTTTCC 		 209 		 278.66 		 -4.17
# TAGCTAGA:ATCGATCT 		 119 		 174.05 		 -4.17
# ATAACCTT:TATTGGAA 		 205 		 274.06 		 -4.17
# GCGGAAAC:CGCCTTTG 		 337 		 422.74 		 -4.17
# CTTCCCAT:GAAGGGTA 		 266 		 343.24 		 -4.17
# ATAAGATG:TATTCTAC 		 87 		 135.53 		 -4.17
# GCGCGCGT:CGCGCGCA 		 23 		 53.49 		 -4.17
# ACTTTCAA:TGAAAGTT 		 266 		 343.21 		 -4.17
# ATACACTT:TATGTGAA 		 83 		 130.60 		 -4.17
# ACCGTATG:TGGCATAC 		 54 		 94.48 		 -4.16
# AAGGGGCG:TTCCCCGC 		 164 		 226.69 		 -4.16
# TCCATGAA:AGGTACTT 		 158 		 219.71 		 -4.16
# AACAGTGA:TTGTCACT 		 156 		 217.36 		 -4.16
# CAGCAATC:GTCGTTAG 		 215 		 285.28 		 -4.16
# GTGTTGAG:CACAACTC 		 108 		 160.75 		 -4.16
# GCCATGTC:CGGTACAG 		 98 		 148.70 		 -4.16
# GCCGACTC:CGGCTGAG 		 105 		 157.07 		 -4.15
# CGGACTTA:GCCTGAAT 		 113 		 166.63 		 -4.15
# ACCGGAGT:TGGCCTCA 		 183 		 248.44 		 -4.15
# CTCAGCCC:GAGTCGGG 		 133 		 190.26 		 -4.15
# GGAACAAG:CCTTGTTC 		 159 		 220.64 		 -4.15
# GCTTAAGT:CGAATTCA 		 14 		 40.34 		 -4.15
# CTAGGGTG:GATCCCAC 		 246 		 320.17 		 -4.15
# GCCTCTTA:CGGAGAAT 		 53 		 92.96 		 -4.14
# CTCAAAGT:GAGTTTCA 		 229 		 300.87 		 -4.14
# GAGGATTA:CTCCTAAT 		 323 		 406.38 		 -4.14
# AGGATTTT:TCCTAAAA 		 611 		 722.14 		 -4.14
# ATACTTTT:TATGAAAA 		 303 		 384.02 		 -4.13
# ACTAGTGA:TGATCACT 		 5 		 26.13 		 -4.13
# GTTTTTCA:CAAAAAGT 		 428 		 522.45 		 -4.13
# GATATTCC:CTATAAGG 		 377 		 466.20 		 -4.13
# CGGAACCT:GCCTTGGA 		 194 		 260.61 		 -4.13
# GTCTGTGG:CAGACACC 		 228 		 299.39 		 -4.13
# CTATACCC:GATATGGG 		 155 		 215.53 		 -4.12
# GGGTAAAC:CCCATTTG 		 321 		 403.81 		 -4.12
# ACGAAATA:TGCTTTAT 		 105 		 156.55 		 -4.12
# TGGTCTCT:ACCAGAGA 		 119 		 173.19 		 -4.12
# TGGCTATT:ACCGATAA 		 524 		 627.08 		 -4.12
# GAGTACTC:CTCATGAG 		 20 		 48.72 		 -4.12
# TTGTAAGC:AACATTCG 		 136 		 193.17 		 -4.11
# CTCATACC:GAGTATGG 		 98 		 148.01 		 -4.11
# CTTTCTTC:GAAAGAAG 		 175 		 238.44 		 -4.11
# TCAACCAT:AGTTGGTA 		 337 		 421.31 		 -4.11
# AAGGCCTA:TTCCGGAT 		 45 		 82.23 		 -4.11
# ACGCCACA:TGCGGTGT 		 58 		 98.79 		 -4.10
# AAGTCGCA:TTCAGCGT 		 93 		 141.87 		 -4.10
# CCATGCCT:GGTACGGA 		 97 		 146.69 		 -4.10
# ACACTTGT:TGTGAACA 		 46 		 83.48 		 -4.10
# ATTGCCTT:TAACGGAA 		 344 		 428.94 		 -4.10
# GACCGGTT:CTGGCCAA 		 29 		 61.02 		 -4.10
# TAAAGGGC:ATTTCCCG 		 80 		 126.01 		 -4.10
# GCTAAAGA:CGATTTCT 		 238 		 310.17 		 -4.10
# CCCTGCCA:GGGACGGT 		 198 		 264.67 		 -4.10
# TACCTACT:ATGGATGA 		 219 		 288.62 		 -4.10
# TAGGGAAC:ATCCCTTG 		 255 		 329.36 		 -4.10
# AATCAGGA:TTAGTCCT 		 504 		 604.76 		 -4.10
# GACCACTA:CTGGTGAT 		 131 		 187.03 		 -4.10
# TCATATGG:AGTATACC 		 28 		 59.63 		 -4.10
# TTCCTCTC:AAGGAGAG 		 162 		 223.19 		 -4.10
# TAGGCTTT:ATCCGAAA 		 334 		 417.69 		 -4.09
# AGAAACGT:TCTTTGCA 		 52 		 91.06 		 -4.09
# ACGTCTCA:TGCAGAGT 		 37 		 71.65 		 -4.09
# AATGCGGA:TTACGCCT 		 202 		 269.14 		 -4.09
# GGCAGCAG:CCGTCGTC 		 134 		 190.38 		 -4.09
# TGAGTACT:ACTCATGA 		 3 		 22.29 		 -4.09
# ACGGTCAT:TGCCAGTA 		 122 		 176.23 		 -4.09
# TAACCAGA:ATTGGTCT 		 276 		 352.71 		 -4.08
# CTGCGGCG:GACGCCGC 		 89 		 136.77 		 -4.08
# ACCGGGTC:TGGCCCAG 		 172 		 234.53 		 -4.08
# CCTGCAGA:GGACGTCT 		 29 		 60.85 		 -4.08
# AATGTCCT:TTACAGGA 		 120 		 173.81 		 -4.08
# CCCCATCC:GGGGTAGG 		 188 		 252.91 		 -4.08
# TGAAGACC:ACTTCTGG 		 112 		 164.31 		 -4.08
# GTTCAAGG:CAAGTTCC 		 143 		 200.78 		 -4.08
# CATAACCT:GTATTGGA 		 216 		 284.76 		 -4.07
# CGCTCTTA:GCGAGAAT 		 34 		 67.45 		 -4.07
# TTATGGTG:AATACCAC 		 306 		 386.02 		 -4.07
# TAACAAGC:ATTGTTCG 		 129 		 184.28 		 -4.07
# ...
# TCGCCC  :AGCGGG   		 4298 		 4632.97 		 -4.92
# CGAGGC  :GCTCCG   		 1203 		 1386.04 		 -4.92
# ACTCCG  :TGAGGC   		 1972 		 2202.60 		 -4.91
# CACAGT  :GTGTCA   		 2169 		 2410.04 		 -4.91
# TGAGCC  :ACTCGG   		 2458 		 2712.52 		 -4.89
# GTCTGG  :CAGACC   		 2924 		 3199.75 		 -4.88
# GCGAAC  :CGCTTG   		 1422 		 1617.26 		 -4.86
# CATTTA  :GTAAAT   		 4232 		 4559.39 		 -4.85
# GGCTTA  :CCGAAT   		 3083 		 3363.79 		 -4.84
# GGCCTC  :CCGGAG   		 359 		 462.94 		 -4.83
# TGTCAT  :ACAGTA   		 2354 		 2600.14 		 -4.83
# ATAGCA  :TATCGT   		 4081 		 4397.79 		 -4.78
# TTGTTT  :AACAAA   		 5667 		 6035.70 		 -4.75
# GGATGC  :CCTACG   		 2197 		 2430.75 		 -4.74
# GGGTCA  :CCCAGT   		 3827 		 4131.09 		 -4.73
# ATGTCG  :TACAGC   		 1775 		 1985.55 		 -4.73
# TCTCAT  :AGAGTA   		 2283 		 2519.78 		 -4.72
# GTTGGA  :CAACCT   		 2995 		 3264.28 		 -4.71
# GTGGTA  :CACCAT   		 2883 		 3147.38 		 -4.71
# CGTCTT  :GCAGAA   		 1266 		 1444.57 		 -4.70
# CCACTC  :GGTGAG   		 1915 		 2131.90 		 -4.70
# CTCCTT  :GAGGAA   		 2221 		 2452.87 		 -4.68
# TGGGAC  :ACCCTG   		 2266 		 2499.74 		 -4.68
# GTAAGG  :CATTCC   		 1634 		 1833.87 		 -4.67
# CATCAC  :GTAGTG   		 3686 		 3980.13 		 -4.66
# AAGCGC  :TTCGCG   		 1995 		 2213.84 		 -4.65
# AGCGGC  :TCGCCG   		 1949 		 2165.21 		 -4.65
# CGCGTG  :GCGCAC   		 406 		 510.46 		 -4.62
# TTGGCT  :AACCGA   		 6567 		 6951.82 		 -4.62
# CCATTA  :GGTAAT   		 5377 		 5725.59 		 -4.61
# CAAGAG  :GTTCTC   		 1937 		 2149.03 		 -4.57
# GATAAC  :CTATTG   		 4109 		 4412.08 		 -4.56
# TTGAGT  :AACTCA   		 5659 		 6012.61 		 -4.56
# CTGGAG  :GACCTC   		 2567 		 2806.96 		 -4.53
# GAGAGG  :CTCTCC   		 2546 		 2784.49 		 -4.52
# GCATTG  :CGTAAC   		 2982 		 3239.00 		 -4.52
# GAATAC  :CTTATG   		 2425 		 2657.64 		 -4.51
# AGTTGG  :TCAACC   		 4878 		 5202.94 		 -4.51
# ATTCTG  :TAAGAC   		 4688 		 5005.96 		 -4.50
# GGGACC  :CCCTGG   		 824 		 963.52 		 -4.50
# CTAGCG  :GATCGC   		 1366 		 1542.49 		 -4.49
# TGCGGT  :ACGCCA   		 2312 		 2538.23 		 -4.49
# ATCTCG  :TAGAGC   		 2497 		 2731.62 		 -4.49
# TGTTTT  :ACAAAA   		 5693 		 6040.91 		 -4.48
# CTGACT  :GACTGA   		 3027 		 3283.13 		 -4.47
# TGTCTC  :ACAGAG   		 1887 		 2090.68 		 -4.46
# ATCGGA  :TAGCCT   		 3067 		 3323.27 		 -4.45
# TGACCT  :ACTGGA   		 3199 		 3460.39 		 -4.44
# TGTCCC  :ACAGGG   		 2577 		 2812.41 		 -4.44
# ACACTG  :TGTGAC   		 1462 		 1641.89 		 -4.44
# GTAGAG  :CATCTC   		 1894 		 2097.29 		 -4.44
# AGCCCC  :TCGGGG   		 2851 		 3098.00 		 -4.44
# TCGCAG  :AGCGTC   		 2389 		 2613.95 		 -4.40
# ATGTGC  :TACACG   		 1219 		 1380.37 		 -4.34
# AAGAGA  :TTCTCT   		 1988 		 2191.14 		 -4.34
# TCTAAT  :AGATTA   		 4650 		 4954.13 		 -4.32
# GGAGAC  :CCTCTG   		 2295 		 2510.39 		 -4.30
# AAAGAT  :TTTCTA   		 4323 		 4613.42 		 -4.28
# CAAGTA  :GTTCAT   		 2054 		 2257.16 		 -4.28
# CGTGAT  :GCACTA   		 1721 		 1906.73 		 -4.25
# CCAGGC  :GGTCCG   		 1873 		 2065.79 		 -4.24
# GTGTTG  :CACAAC   		 2536 		 2758.28 		 -4.23
# CTGAGG  :GACTCC   		 3008 		 3248.67 		 -4.22
# GGTTGT  :CCAACA   		 3479 		 3736.97 		 -4.22
# TAACCC  :ATTGGG   		 5823 		 6153.48 		 -4.21
# GAGCGT  :CTCGCA   		 769 		 895.03 		 -4.21
# ATAATA  :TATTAT   		 5780 		 6108.98 		 -4.21
# CCTTCT  :GGAAGA   		 2959 		 3196.80 		 -4.21
# CGTAAT  :GCATTA   		 1874 		 2064.57 		 -4.19
# TCGCTG  :AGCGAC   		 3478 		 3733.44 		 -4.18
# ATGGGT  :TACCCA   		 3919 		 4189.37 		 -4.18
# CGTGAA  :GCACTT   		 1285 		 1442.31 		 -4.14
# GCTGAG  :CGACTC   		 2612 		 2832.19 		 -4.14
# AGGTGG  :TCCACC   		 3436 		 3686.01 		 -4.12
# TTGCGT  :AACGCA   		 1454 		 1619.47 		 -4.11
# CGAGTG  :GCTCAC   		 938 		 1072.49 		 -4.11
# CCTTAT  :GGAATA   		 2656 		 2875.86 		 -4.10
# ACTACA  :TGATGT   		 2644 		 2861.68 		 -4.07
# AGTCTA  :TCAGAT   		 2604 		 2819.87 		 -4.07
# AGAGTG  :TCTCAC   		 1493 		 1658.56 		 -4.07
# GACGGC  :CTGCCG   		 1961 		 2148.46 		 -4.04
# TTGGGA  :AACCCT   		 6974 		 7319.73 		 -4.04
# TTTCCT  :AAAGGA   		 6002 		 6323.26 		 -4.04
# TGAAAC  :ACTTTG   		 4176 		 4444.98 		 -4.04
# TTGCCT  :AACGGA   		 2986 		 3214.72 		 -4.03
# TGGTAA  :ACCATT   		 5545 		 5853.11 		 -4.03
# GCACGC  :CGTGCG   		 527 		 627.65 		 -4.02
# ACCAAC  :TGGTTG   		 4326 		 4597.15 		 -4.00
# GGACC   :CCTGG    		 3403 		 7769.39 		 -49.57
# CATCG   :GTAGC    		 9063 		 14591.93 		 -45.82
# AATCG   :TTAGC    		 13892 		 19771.92 		 -41.88
# GCGAA   :CGCTT    		 8835 		 12739.33 		 -34.62
# CGATA   :GCTAT    		 12823 		 16974.72 		 -31.91
# CCGAT   :GGCTA    		 13262 		 17294.70 		 -30.70
# GGCAC   :CCGTG    		 4515 		 6497.91 		 -24.61
# TCATT   :AGTAA    		 15065 		 18239.44 		 -23.54
# GATTG   :CTAAC    		 14762 		 17855.90 		 -23.18
# ATCGT   :TAGCA    		 7878 		 10113.57 		 -22.25
# GCGAG   :CGCTC    		 7622 		 9771.93 		 -21.76
# GGCGT   :CCGCA    		 5720 		 7584.85 		 -21.42
# GATGG   :CTACC    		 16132 		 18997.21 		 -20.82
# ATTGG   :TAACC    		 19598 		 22630.94 		 -20.19
# TGCTT   :ACGAA    		 12650 		 14990.40 		 -19.14
# ATGGG   :TACCC    		 15564 		 18098.96 		 -18.87
# TTGAA   :AACTT    		 19467 		 22197.00 		 -18.35
# AGCGG   :TCGCC    		 8808 		 10633.61 		 -17.72
# GCTGG   :CGACC    		 11310 		 13338.68 		 -17.58
# TCTCA   :AGAGT    		 12423 		 14502.31 		 -17.28
# TGGTT   :ACCAA    		 21509 		 24130.09 		 -16.90
# GTCGC   :CAGCG    		 9037 		 10776.92 		 -16.77
# GCCTA   :CGGAT    		 8140 		 9774.36 		 -16.54
# TCCGC   :AGGCG    		 8954 		 10633.81 		 -16.30
# TTGCG   :AACGC    		 9207 		 10879.25 		 -16.05
# TCGTT   :AGCAA    		 7541 		 9027.64 		 -15.66
# TAAGA   :ATTCT    		 7677 		 9174.07 		 -15.64
# CTCCG   :GAGGC    		 7184 		 8611.56 		 -15.39
# CAAAT   :GTTTA    		 24516 		 27041.59 		 -15.39
# CAGGC   :GTCCG    		 7833 		 9316.71 		 -15.38
# ATGAG   :TACTC    		 10129 		 11793.01 		 -15.34
# GGTTG   :CCAAC    		 17399 		 19499.34 		 -15.06
# TCCTT   :AGGAA    		 11199 		 12904.94 		 -15.03
# CCTGC   :GGACG    		 7540 		 8955.50 		 -14.97
# TGTTT   :ACAAA    		 18654 		 20802.60 		 -14.92
# TTTTA   :AAAAT    		 27847 		 30436.88 		 -14.88
# GACAG   :CTGTC    		 9751 		 11323.61 		 -14.79
# CGGGG   :GCCCC    		 10920 		 12545.13 		 -14.52
# TAGTT   :ATCAA    		 16799 		 18775.98 		 -14.45
# GCCAG   :CGGTC    		 11340 		 12978.29 		 -14.39
# GAGTG   :CTCAC    		 6776 		 8057.17 		 -14.28
# TCCTA   :AGGAT    		 11962 		 13597.80 		 -14.04
# TATTA   :ATAAT    		 21319 		 23398.65 		 -13.62
# TGTAA   :ACATT    		 11332 		 12851.61 		 -13.42
# TCACA   :AGTGT    		 8625 		 9954.13 		 -13.33
# AGGGA   :TCCCT    		 13590 		 15225.56 		 -13.27
# GGGAC   :CCCTG    		 8574 		 9875.96 		 -13.11
# TGGCG   :ACCGC    		 17357 		 19094.47 		 -12.59
# GAAGG   :CTTCC    		 10176 		 11519.62 		 -12.53
# CTGCG   :GACGC    		 7005 		 8129.90 		 -12.48
# TGACT   :ACTGA    		 13047 		 14549.30 		 -12.47
# CCCTT   :GGGAA    		 12037 		 13483.16 		 -12.47
# GTTTG   :CAAAC    		 17629 		 19356.64 		 -12.44
# TGACA   :ACTGT    		 11721 		 13144.07 		 -12.42
# GCTCC   :CGAGG    		 5723 		 6705.73 		 -12.01
# GAATC   :CTTAG    		 12885 		 14319.78 		 -12.00
# ATAGG   :TATCC    		 12792 		 14188.84 		 -11.74
# CTTGC   :GAACG    		 7398 		 8465.85 		 -11.61
# TTCCT   :AAGGA    		 17452 		 19046.74 		 -11.57
# GGAGG   :CCTCC    		 10771 		 12016.46 		 -11.37
# CAGGG   :GTCCC    		 12229 		 13541.86 		 -11.29
# AGTTC   :TCAAG    		 12612 		 13925.89 		 -11.15
# GTGCT   :CACGA    		 7571 		 8584.14 		 -10.94
# TTATT   :AATAA    		 25399 		 27181.64 		 -10.83
# TGCCG   :ACGGC    		 7149 		 8124.58 		 -10.83
# CAAGT   :GTTCA    		 10858 		 12041.75 		 -10.80
# AAGAG   :TTCTC    		 8287 		 9297.83 		 -10.49
# GCTTA   :CGAAT    		 9280 		 10333.98 		 -10.38
# TTGGA   :AACCT    		 14736 		 16027.62 		 -10.21
# CGGAT   :GCCTA    		 9496 		 10538.26 		 -10.16
# TCTGT   :AGACA    		 12589 		 13775.01 		 -10.12
# GACTG   :CTGAC    		 9860 		 10906.16 		 -10.03
# GCTCG   :CGAGC    		 3485 		 4122.86 		 -9.94
# TAACA   :ATTGT    		 13576 		 14773.77 		 -9.87
# CTTTT   :GAAAA    		 20419 		 21875.16 		 -9.86
# CGGGC   :GCCCG    		 4962 		 5699.29 		 -9.77
# TGAAA   :ACTTT    		 20288 		 21692.42 		 -9.55
# ACTGA   :TGACT    		 13083 		 14215.76 		 -9.51
# CTAAT   :GATTA    		 19713 		 21087.73 		 -9.48
# CCACG   :GGTGC    		 4636 		 5327.50 		 -9.48
# TCTCT   :AGAGA    		 10186 		 11187.61 		 -9.48
# ATAAC   :TATTG    		 15353 		 16566.97 		 -9.44
# GAGGG   :CTCCC    		 10980 		 12003.92 		 -9.35
# GCACC   :CGTGG    		 9314 		 10246.35 		 -9.22
# GTGGG   :CACCC    		 12510 		 13575.30 		 -9.15
# CCTAA   :GGATT    		 14860 		 15998.08 		 -9.01
# TTGGT   :AACCA    		 20753 		 22088.18 		 -9.00
# CTTCG   :GAAGC    		 6344 		 7101.33 		 -8.99
# GGGCT   :CCCGA    		 10646 		 11605.84 		 -8.92
# CATTT   :GTAAA    		 19412 		 20692.25 		 -8.91
# CTCAG   :GAGTC    		 11058 		 12029.19 		 -8.86
# TTTTT   :AAAAA    		 39769 		 41565.01 		 -8.84
# TATGC   :ATACG    		 7990 		 8811.64 		 -8.76
# AGGTG   :TCCAC    		 11321 		 12287.37 		 -8.73
# GGGGG   :CCCCC    		 19361 		 20583.70 		 -8.54
# TAGCG   :ATCGC    		 9807 		 10677.44 		 -8.43
# TTTGA   :AAACT    		 27550 		 28981.65 		 -8.43
# CGTCT   :GCAGA    		 5637 		 6285.54 		 -8.18
# TCTAT   :AGATA    		 12607 		 13548.66 		 -8.10
# GGGTC   :CCCAG    		 10243 		 11095.03 		 -8.10
# TTCCA   :AAGGT    		 17202 		 18276.69 		 -7.96
# TGGGT   :ACCCA    		 19092 		 20208.39 		 -7.86
# GATAG   :CTATC    		 14519 		 15463.35 		 -7.60
# CCGTT   :GGCAA    		 11158 		 11952.38 		 -7.27
# CAGCC   :GTCGG    		 14924 		 15838.00 		 -7.27
# TCATA   :AGTAT    		 12547 		 13373.60 		 -7.15
# TCTGA   :AGACT    		 15314 		 16221.98 		 -7.14
# TCTTT   :AGAAA    		 15235 		 16135.49 		 -7.10
# TTGTT   :AACAA    		 19998 		 21017.86 		 -7.05
# CTGCC   :GACGG    		 8643 		 9301.86 		 -6.84
# ACTCG   :TGAGC    		 7415 		 8021.75 		 -6.78
# CCACT   :GGTGA    		 10567 		 11285.36 		 -6.77
# GTAAC   :CATTG    		 9803 		 10480.52 		 -6.62
# CACCC   :GTGGG    		 15533 		 16379.35 		 -6.62
# CATAC   :GTATG    		 6557 		 7114.29 		 -6.61
# TCTGC   :AGACG    		 9527 		 10190.59 		 -6.58
# GTTCT   :CAAGA    		 12158 		 12898.51 		 -6.53
# ATCTG   :TAGAC    		 14846 		 15661.81 		 -6.53
# GCTAC   :CGATG    		 11032 		 11736.38 		 -6.51
# GTCAT   :CAGTA    		 10726 		 11418.23 		 -6.48
# GTCTC   :CAGAG    		 8055 		 8647.93 		 -6.38
# TTGAT   :AACTA    		 29339 		 30432.59 		 -6.28
# TAGCC   :ATCGG    		 16584 		 17394.27 		 -6.15
# ACGGA   :TGCCT    		 7840 		 8379.35 		 -5.90
# GTGAC   :CACTG    		 7375 		 7898.01 		 -5.89
# GTTGC   :CAACG    		 10173 		 10778.32 		 -5.84
# TCACT   :AGTGA    		 9083 		 9628.18 		 -5.56
# GTGAG   :CACTC    		 7664 		 8157.25 		 -5.46
# ATTCT   :TAAGA    		 16690 		 17405.92 		 -5.43
# CCTTT   :GGAAA    		 15615 		 16296.22 		 -5.34
# CTTTC   :GAAAG    		 13814 		 14453.24 		 -5.32
# TTCTC   :AAGAG    		 15130 		 15789.77 		 -5.26
# GGGAT   :CCCTA    		 17173 		 17868.51 		 -5.21
# ACAAA   :TGTTT    		 18900 		 19624.28 		 -5.18
# AATAG   :TTATC    		 18394 		 19104.58 		 -5.15
# ATACA   :TATGT    		 9535 		 10042.57 		 -5.07
# GGTAG   :CCATC    		 14776 		 15400.26 		 -5.04
# ACACA   :TGTGT    		 6289 		 6659.83 		 -4.55
# AAGTA   :TTCAT    		 10658 		 11136.19 		 -4.54
# TGTCT   :ACAGA    		 9559 		 10011.85 		 -4.53
# CCTGG   :GGACC    		 12837 		 13357.89 		 -4.51
# GAGGT   :CTCCA    		 10918 		 11395.33 		 -4.48
# GACGC   :CTGCG    		 5169 		 5498.40 		 -4.44
# TAGGT   :ATCCA    		 12974 		 13486.78 		 -4.42
# ATACG   :TATGC    		 4488 		 4792.28 		 -4.40
# CTTCA   :GAAGT    		 11732 		 12214.31 		 -4.37
# GCGTA   :CGCAT    		 3835 		 4112.48 		 -4.33
# TGCGA   :ACGCT    		 12332 		 12820.50 		 -4.32
# CCGAG   :GGCTC    		 7194 		 7566.78 		 -4.29
# CGACT   :GCTGA    		 8729 		 9135.03 		 -4.25
# GGTGG   :CCACC    		 17983 		 18558.72 		 -4.23
# GGAAG   :CCTTC    		 14818 		 15338.33 		 -4.21
# GCTTG   :CGAAC    		 12232 		 12695.39 		 -4.12
# ATGTA   :TACAT    		 8264 		 8646.35 		 -4.11
# ACTAA   :TGATT    		 14735 		 15234.30 		 -4.05
# TCCCA   :AGGGT    		 19716 		 20285.78 		 -4.01
# AATT    :TTAA     		 63152 		 238046.70 		 -364.92
# TTAA    :AATT     		 48147 		 187075.82 		 -325.73
# GATC    :CTAG     		 23788 		 125581.41 		 -289.94
# ATAT    :TATA     		 38836 		 142572.49 		 -277.67
# TATA    :ATAT     		 25709 		 120235.52 		 -275.05
# GGCC    :CCGG     		 5285 		 81006.26 		 -267.65
# AGCT    :TCGA     		 17723 		 102300.79 		 -266.45
# TCGA    :AGCT     		 16403 		 89064.21 		 -245.09
# CTAG    :GATC     		 19074 		 90748.08 		 -239.53
# CCGG    :GGCC     		 19992 		 91391.55 		 -237.79
# GCGC    :CGCG     		 12500 		 74580.72 		 -228.58
# GATT    :CTAA     		 81252 		 172899.51 		 -223.27
# CATG    :GTAC     		 14644 		 72991.50 		 -217.14
# CGCG    :GCGC     		 10550 		 64826.00 		 -214.20
# TGCA    :ACGT     		 14835 		 71405.07 		 -212.82
# TTAT    :AATA     		 79791 		 163315.23 		 -209.21
# AATA    :TTAT     		 86183 		 169179.40 		 -204.35
# CATT    :GTAA     		 62232 		 131815.72 		 -193.55
# GTAC    :CATG     		 9454 		 52286.92 		 -188.04
# CTAA    :GATT     		 63232 		 130294.94 		 -187.60
# ATAG    :TATC     		 56081 		 113746.12 		 -172.43
# ATAC    :TATG     		 39444 		 86340.47 		 -160.62
# AGCG    :TCGC     		 36028 		 81435.56 		 -160.08
# TATG    :ATAC     		 45630 		 93681.22 		 -158.09
# CCGA    :GGCT     		 43071 		 90220.38 		 -158.03
# GTAA    :CATT     		 50477 		 98902.07 		 -155.12
# GATA    :CTAT     		 69757 		 122879.40 		 -152.93
# GCGG    :CGCC     		 42319 		 82559.36 		 -140.91
# TGCC    :ACGG     		 37812 		 76054.31 		 -139.45
# ACGT    :TGCA     		 6771 		 31050.67 		 -138.10
# TGCG    :ACGC     		 33048 		 68036.05 		 -134.81
# GCGT    :CGCA     		 20440 		 48122.56 		 -126.64
# AGCA    :TCGT     		 49952 		 85468.09 		 -122.26
# TCGT    :AGCA     		 25187 		 52588.05 		 -119.95
# CATC    :GTAG     		 59965 		 95741.19 		 -116.45
# GGCT    :CCGA     		 58692 		 91032.99 		 -107.92
# CTAC    :GATG     		 44376 		 68883.51 		 -93.85
# TCGC    :AGCG     		 55623 		 81501.36 		 -91.20
# CCGT    :GGCA     		 33347 		 53270.71 		 -86.66
# CGCC    :GCGG     		 53206 		 72465.94 		 -71.93
# GCTC    :CGAG     		 24078 		 37822.35 		 -70.87
# GGGC    :CCCG     		 31694 		 45591.72 		 -65.31
# TTCG    :AAGC     		 35886 		 47028.51 		 -51.56
# TGGA    :ACCT     		 48893 		 61046.62 		 -49.41
# GGTC    :CCAG     		 37413 		 47997.78 		 -48.49
# GGAT    :CCTA     		 54789 		 66391.64 		 -45.25
# TAAG    :ATTC     		 38576 		 48352.37 		 -44.62
# TGAA    :ACTT     		 61724 		 73426.39 		 -43.42
# GGAC    :CCTG     		 30282 		 37444.43 		 -37.12
# ATTC    :TAAG     		 62736 		 71342.03 		 -32.39
# AGAT    :TCTA     		 56220 		 63659.82 		 -29.63
# CACT    :GTGA     		 33586 		 39443.61 		 -29.58
# CCAG    :GGTC     		 55217 		 60415.91 		 -21.25
# CGAG    :GCTC     		 27527 		 31193.81 		 -20.81
# CGTG    :GCAC     		 15855 		 18686.45 		 -20.74
# TCTT    :AGAA     		 47986 		 52401.32 		 -19.36
# GTGT    :CACA     		 26736 		 29960.97 		 -18.67
# GTTC    :CAAG     		 46490 		 50448.73 		 -17.69
# ACAT    :TGTA     		 38830 		 42366.76 		 -17.24
# TCTA    :AGAT     		 48762 		 52417.16 		 -16.03
# CGTA    :GCAT     		 18614 		 20537.86 		 -13.44
# TAGT    :ATCA     		 48628 		 51484.41 		 -12.64
# CGGG    :GCCC     		 42519 		 45148.26 		 -12.42
# CAGT    :GTCA     		 48538 		 51323.45 		 -12.34
# ATTG    :TAAC     		 78228 		 81627.39 		 -11.97
# TTGG    :AACC     		 80224 		 83267.28 		 -10.61
# GTGA    :CACT     		 39961 		 41841.07 		 -9.22
# TTTT    :AAAA     		 128918 		 132207.43 		 -9.14
# CCTT    :GGAA     		 48464 		 50432.54 		 -8.80
# TGTT    :ACAA     		 61806 		 63893.43 		 -8.30
# AGGT    :TCCA     		 50537 		 52292.78 		 -7.71
# GCAA    :CGTT     		 49538 		 51200.84 		 -7.38
# CCTG    :GGAC     		 48675 		 50290.07 		 -7.23
# ACCG    :TGGC     		 41880 		 43375.36 		 -7.20
# TCAG    :AGTC     		 58929 		 60393.94 		 -5.99
# TCAT    :AGTA     		 57772 		 59165.99 		 -5.76
# AGAG    :TCTC     		 38524 		 39582.20 		 -5.33
# AACC    :TTGG     		 81351 		 82855.34 		 -5.26
# CCCT    :GGGA     		 53236 		 54430.16 		 -5.14
# TTTA    :AAAT     		 94403 		 95818.09 		 -4.60
# AGTA    :TCAT     		 42417 		 43351.58 		 -4.50
# CTT     :GAA      		 201776 		 248234.29 		 -95.00
# AGG     :TCC      		 191352 		 214766.71 		 -51.34
# TCC     :AGG      		 207354 		 226527.26 		 -40.97
# GAA     :CTT      		 242367 		 261827.51 		 -38.79
# ACA     :TGT      		 175177 		 189825.42 		 -34.10
# GTG     :CAC      		 139396 		 150813.14 		 -29.73
# AGA     :TCT      		 198822 		 208631.31 		 -21.81
# GAG     :CTC      		 160761 		 165754.11 		 -12.42
# GTC     :CAG      		 145821 		 149421.45 		 -9.42

# %% [markdown]
# __CODE MARKDOWN CELL__
#
# __Schlough_William_missingMotif.ipynb__ contains ----------------- 3 classes - FastAreader, CommandLine, and Genome -- along with a main
#
# __FastAreader__ and __CommandLine__ were provided by Dr. B, and only CommandLine was slightly changed to fit the program requirements
#
# __Genome__ contains class genome contains methods that are used to find the z-score, expected value, and count of all motifs, along with a sorted list that can be printed to an output file
#
# def __ __init__ __(self, seq, N, min, max, cutoff) -- initialization of user inputs occurs here
#
# def __reverseSeq__(self) -- quick way to get reverse compliment - taken from BME 160
#
# def __eVal__(self, kmer) -- using markovian model -- left + right size + middle kmer are used to calculate eScore, calculates and returns the expected value of a specific motif appearing
#
# def __zScore__(self, kmer) -- takes in -- a kmer that has eVal called on it to calculate the mean, calculates Pr(K), then calculates the stand deviation, and lastly calculates a z-score and returns that z-score
#
# def __kmerList__(self) -- returns a sorted list containing the (kmer, reverse compliment, counts of both, e value, z score, motif size), the list is sorted first by motif size, and then by z score
#
# __main__ -- for this assignment, we print the sorted list in order of motif size, then by zScore. (variable N is used to keep track of genome length, and is then passed onto Genome() instantiation, becoming self.N)

# %% [markdown]
# __INSPECTION MARKDOWN CELL__
#
# DoneBy: Junmo Sung
#
# It was well explained with the markdown cells and docstrings.
# But it seems there isn't a code for the case of denominator of 0 (if there is, I cannot find the explanation about it).
# Other than that it is well written and the outcomes look fine.
#
#
#
# Inpsector: Michael
# Inspectee: Will
#
# Change counting method to not have to count the reverse strand by using the ditionary structre where the reverse complement motifs point to the same value.
#
# Don't have to check if std != 0 in your zscore function since it can't be with the way you've counted your motifs
#
# Rest looks good, definitely stealing your reverse complement method
